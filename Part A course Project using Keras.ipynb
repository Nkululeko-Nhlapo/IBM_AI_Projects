# %% [markdown]
# **Part A**

# %% [markdown]
# Creating the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error as the loss function.
#
# A. Build a baseline model (5 marks)
#
# Using the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Using the adam optimizer and the mean squared error as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_splithelper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing Concrete data for evaluation

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')#importing the data using pandas
concrete_data.head() #Checking the first five items from the dataset
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# The data must be splited between the independent variable and dependent variable, that will be *(cement, blast furnance, fly slag,
# water, superplasticizer, coarse aggregate, fine aggregate, and age)* and the dependent variable that will be *(Strenght)*

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# We have to get the number of columns of the **predictors** variable as the number of inputs to the deep learning model

# %%
n_cols = predictors.shape[1] # number of predictors

# %% [markdown]
# **Then we have to import keras library and as per video lesson, the model have two classes.**

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# define classification model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# <h3> Now we have to randomly split a data into training data and 30% of the data randomly chosen as test data using
#     Scikit-learn.<h3> <h3> Therefore we have to import sklearn library to select train_test_split  <h3>
#     <h2> Evaluating the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. Using the mean_squared_error function from Scikit-learn <h3>

# %% [markdown]
# **First let's import the mean_sqaure_error function from the scikit_learn library, Evaluating the model on the test data using "evaluate"**

# %%
from sklearn.model_selection import train_test_split #importing the sklearn library for train_test_split
from sklearn.metrics import mean_squared_error#importing the mean_sqaure_error function from the sklearn library

# %%
MSE=np.zeros(50)
for i in range(50):
    X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42) #test size is set to 30%
    model=regression_model() #Call the function to create a model
    model.fit(X_train, y_train, epochs=50, verbose=2) #we then need to fit the x-train data along with y_train data and  fit it on a model
    print("Evaluate on test data")
    results=model.evaluate(X_test, y_test)
    print("test loss, test acc:", results) 
    target_predicted= model.predict(X_test)
    MSE[i]=mean_squared_error(y_test, target_predicted)
    print("Test set MSE for {} cycle:{}".format(i+1,MSE[i]))
# Out:
# Epoch 1/50
#  - 1s - loss: 113387.7001
# Epoch 2/50
#  - 0s - loss: 44775.5589
# Epoch 3/50
#  - 0s - loss: 11586.3721
# Epoch 4/50
#  - 0s - loss: 6043.3382
# Epoch 5/50
#  - 0s - loss: 5459.7882
# Epoch 6/50
#  - 0s - loss: 5056.5677
# Epoch 7/50
#  - 0s - loss: 4746.8157
# Epoch 8/50
#  - 0s - loss: 4473.2223
# Epoch 9/50
#  - 0s - loss: 4215.3868
# Epoch 10/50
#  - 0s - loss: 3973.9965
# Epoch 11/50
#  - 0s - loss: 3753.2715
# Epoch 12/50
#  - 0s - loss: 3550.3556
# Epoch 13/50
#  - 0s - loss: 3376.3936
# Epoch 14/50
#  - 0s - loss: 3203.8673
# Epoch 15/50
#  - 0s - loss: 3040.8519
# Epoch 16/50
#  - 0s - loss: 2890.9595
# Epoch 17/50
#  - 0s - loss: 2749.3581
# Epoch 18/50
#  - 0s - loss: 2615.1887
# Epoch 19/50
#  - 0s - loss: 2488.2798
# Epoch 20/50
#  - 0s - loss: 2366.6540
# Epoch 21/50
#  - 0s - loss: 2250.7087
# Epoch 22/50
#  - 0s - loss: 2151.0278
# Epoch 23/50
#  - 0s - loss: 2039.7093
# Epoch 24/50
#  - 0s - loss: 1951.4792
# Epoch 25/50
#  - 0s - loss: 1851.1983
# Epoch 26/50
#  - 0s - loss: 1762.4458
# Epoch 27/50
#  - 0s - loss: 1683.1005
# Epoch 28/50
#  - 0s - loss: 1603.0290
# Epoch 29/50
#  - 0s - loss: 1531.2274
# Epoch 30/50
#  - 0s - loss: 1457.0956
# Epoch 31/50
#  - 0s - loss: 1391.5660
# Epoch 32/50
#  - 0s - loss: 1326.8510
# Epoch 33/50
#  - 0s - loss: 1264.9265
# Epoch 34/50
#  - 0s - loss: 1207.8298
# Epoch 35/50
#  - 0s - loss: 1151.3156
# Epoch 36/50
#  - 0s - loss: 1101.3108
# Epoch 37/50
#  - 0s - loss: 1047.3015
# Epoch 38/50
#  - 0s - loss: 998.4377
# Epoch 39/50
#  - 0s - loss: 958.7041
# Epoch 40/50
#  - 0s - loss: 909.3288
# Epoch 41/50
#  - 0s - loss: 866.8904
# Epoch 42/50
#  - 0s - loss: 825.9746
# Epoch 43/50
#  - 0s - loss: 793.8338
# Epoch 44/50
#  - 0s - loss: 757.7509
# Epoch 45/50
#  - 0s - loss: 716.3055
# Epoch 46/50
#  - 0s - loss: 685.3242
# Epoch 47/50
#  - 0s - loss: 653.9773
# Epoch 48/50
#  - 0s - loss: 622.2123
# Epoch 49/50
#  - 0s - loss: 594.6113
# Epoch 50/50
#  - 0s - loss: 569.5611
# Evaluate on test data
# 309/309 [==============================] - 0s 323us/step
# test loss, test acc: 495.03240275460155
# Test set MSE for 1 cycle:495.03239087147705
# Epoch 1/50
#  - 1s - loss: 45677.5431
# Epoch 2/50
#  - 0s - loss: 10232.3173
# Epoch 3/50
#  - 0s - loss: 1246.2606
# Epoch 4/50
#  - 0s - loss: 962.2143
# Epoch 5/50
#  - 0s - loss: 858.2966
# Epoch 6/50
#  - 0s - loss: 810.6552
# Epoch 7/50
#  - 0s - loss: 759.0134
# Epoch 8/50
#  - 0s - loss: 713.0440
# Epoch 9/50
#  - 0s - loss: 675.1737
# Epoch 10/50
#  - 0s - loss: 633.7443
# Epoch 11/50
#  - 0s - loss: 600.1823
# Epoch 12/50
#  - 0s - loss: 569.7524
# Epoch 13/50
#  - 0s - loss: 539.8719
# Epoch 14/50
#  - 0s - loss: 515.2799
# Epoch 15/50
#  - 0s - loss: 492.0808
# Epoch 16/50
#  - 0s - loss: 476.6179
# Epoch 17/50
#  - 0s - loss: 456.0055
# Epoch 18/50
#  - 0s - loss: 439.1928
# Epoch 19/50
#  - 0s - loss: 422.6282
# Epoch 20/50
#  - 0s - loss: 409.0326
# Epoch 21/50
#  - 0s - loss: 396.9845
# Epoch 22/50
#  - 0s - loss: 385.5776
# Epoch 23/50
#  - 0s - loss: 375.2771
# Epoch 24/50
#  - 0s - loss: 367.2808
# Epoch 25/50
#  - 0s - loss: 357.3448
# Epoch 26/50
#  - 0s - loss: 348.3678
# Epoch 27/50
#  - 0s - loss: 342.1197
# Epoch 28/50
#  - 0s - loss: 333.4175
# Epoch 29/50
#  - 0s - loss: 325.6211
# Epoch 30/50
#  - 0s - loss: 319.3316
# Epoch 31/50
#  - 0s - loss: 312.3093
# Epoch 32/50
#  - 0s - loss: 306.0691
# Epoch 33/50
#  - 0s - loss: 299.4896
# Epoch 34/50
#  - 0s - loss: 294.0553
# Epoch 35/50
#  - 0s - loss: 287.9964
# Epoch 36/50
#  - 0s - loss: 282.5888
# Epoch 37/50
#  - 0s - loss: 277.6975
# Epoch 38/50
#  - 0s - loss: 272.1678
# Epoch 39/50
#  - 0s - loss: 268.4941
# Epoch 40/50
#  - 0s - loss: 263.9040
# Epoch 41/50
#  - 0s - loss: 260.1225
# Epoch 42/50
#  - 0s - loss: 255.3599
# Epoch 43/50
#  - 0s - loss: 251.9501
# Epoch 44/50
#  - 0s - loss: 248.2776
# Epoch 45/50
#  - 0s - loss: 245.1738
# Epoch 46/50
#  - 0s - loss: 240.6021
# Epoch 47/50
#  - 0s - loss: 236.6597
# Epoch 48/50
#  - 0s - loss: 235.2437
# Epoch 49/50
#  - 0s - loss: 232.8939
# Epoch 50/50
#  - 0s - loss: 227.1351
# Evaluate on test data
# 309/309 [==============================] - 0s 343us/step
# test loss, test acc: 242.74168845364963
# Test set MSE for 2 cycle:242.74169219262103
# Epoch 1/50
#  - 1s - loss: 17242.2524
# Epoch 2/50
#  - 0s - loss: 4446.4679
# Epoch 3/50
#  - 0s - loss: 2959.3204
# Epoch 4/50
#  - 0s - loss: 2419.6039
# Epoch 5/50
#  - 0s - loss: 2031.0063
# Epoch 6/50
#  - 0s - loss: 1735.3040
# Epoch 7/50
#  - 0s - loss: 1494.7121
# Epoch 8/50
#  - 0s - loss: 1303.9156
# Epoch 9/50
#  - 0s - loss: 1143.3370
# Epoch 10/50
#  - 0s - loss: 985.4823
# Epoch 11/50
#  - 0s - loss: 853.2121
# Epoch 12/50
#  - 0s - loss: 738.9096
# Epoch 13/50
#  - 0s - loss: 645.5199
# Epoch 14/50
#  - 0s - loss: 564.1622
# Epoch 15/50
#  - 0s - loss: 499.7986
# Epoch 16/50
#  - 0s - loss: 444.2634
# Epoch 17/50
#  - 0s - loss: 397.3700
# Epoch 18/50
#  - 0s - loss: 358.7852
# Epoch 19/50
#  - 0s - loss: 326.5511
# Epoch 20/50
#  - 1s - loss: 298.2329
# Epoch 21/50
#  - 0s - loss: 274.2261
# Epoch 22/50
#  - 0s - loss: 254.3701
# Epoch 23/50
#  - 0s - loss: 236.6015
# Epoch 24/50
#  - 0s - loss: 221.2396
# Epoch 25/50
#  - 0s - loss: 208.8004
# Epoch 26/50
#  - 0s - loss: 197.6503
# Epoch 27/50
#  - 0s - loss: 187.6243
# Epoch 28/50
#  - 0s - loss: 179.1519
# Epoch 29/50
#  - 0s - loss: 174.6173
# Epoch 30/50
#  - 0s - loss: 164.2547
# Epoch 31/50
#  - 0s - loss: 159.3843
# Epoch 32/50
#  - 0s - loss: 154.2562
# Epoch 33/50
#  - 0s - loss: 148.1600
# Epoch 34/50
#  - 0s - loss: 145.0998
# Epoch 35/50
#  - 0s - loss: 140.9711
# Epoch 36/50
#  - 0s - loss: 139.7871
# Epoch 37/50
#  - 0s - loss: 134.9035
# Epoch 38/50
#  - 0s - loss: 132.1504
# Epoch 39/50
#  - 0s - loss: 130.1358
# Epoch 40/50
#  - 0s - loss: 127.4940
# Epoch 41/50
#  - 0s - loss: 127.0839
# Epoch 42/50
#  - 0s - loss: 125.0714
# Epoch 43/50
#  - 0s - loss: 123.8607
# Epoch 44/50
#  - 0s - loss: 122.5718
# Epoch 45/50
#  - 0s - loss: 123.2319
# Epoch 46/50
#  - 0s - loss: 121.1342
# Epoch 47/50
#  - 0s - loss: 120.2543
# Epoch 48/50
#  - 0s - loss: 118.9134
# Epoch 49/50
#  - 0s - loss: 118.0515
# Epoch 50/50
#  - 0s - loss: 117.8440
# Evaluate on test data
# 309/309 [==============================] - 0s 514us/step
# test loss, test acc: 124.30189198120512
# Test set MSE for 3 cycle:124.30189288088016
# Epoch 1/50
#  - 1s - loss: 53943.4480
# Epoch 2/50
#  - 0s - loss: 10429.8954
# Epoch 3/50
#  - 0s - loss: 3487.2840
# Epoch 4/50
#  - 0s - loss: 3167.8510
# Epoch 5/50
#  - 0s - loss: 2901.5398
# Epoch 6/50
#  - 0s - loss: 2688.3315
# Epoch 7/50
#  - 0s - loss: 2474.2564
# Epoch 8/50
#  - 0s - loss: 2273.5907
# Epoch 9/50
#  - 0s - loss: 2101.6677
# Epoch 10/50
#  - 0s - loss: 1941.2326
# Epoch 11/50
#  - 0s - loss: 1781.0643
# Epoch 12/50
#  - 0s - loss: 1639.5778
# Epoch 13/50
#  - 0s - loss: 1522.4408
# Epoch 14/50
#  - 0s - loss: 1413.4895
# Epoch 15/50
#  - 0s - loss: 1309.7118
# Epoch 16/50
#  - 0s - loss: 1225.0926
# Epoch 17/50
#  - 0s - loss: 1142.6199
# Epoch 18/50
#  - 0s - loss: 1069.9760
# Epoch 19/50
#  - 0s - loss: 1000.9607
# Epoch 20/50
#  - 0s - loss: 942.3956
# Epoch 21/50
#  - 0s - loss: 886.0291
# Epoch 22/50
#  - 0s - loss: 835.2900
# Epoch 23/50
#  - 0s - loss: 788.8157
# Epoch 24/50
#  - 0s - loss: 747.4446
# Epoch 25/50
#  - 0s - loss: 703.8873
# Epoch 26/50
#  - 0s - loss: 666.9367
# Epoch 27/50
#  - 0s - loss: 631.5953
# Epoch 28/50
#  - 0s - loss: 599.3877
# Epoch 29/50
#  - 0s - loss: 568.6004
# Epoch 30/50
#  - 0s - loss: 540.5585
# Epoch 31/50
#  - 0s - loss: 511.3024
# Epoch 32/50
#  - 0s - loss: 486.1297
# Epoch 33/50
#  - 0s - loss: 461.9462
# Epoch 34/50
#  - 0s - loss: 439.1068
# Epoch 35/50
#  - 0s - loss: 420.1015
# Epoch 36/50
#  - 0s - loss: 399.0793
# Epoch 37/50
#  - 0s - loss: 381.8306
# Epoch 38/50
#  - 0s - loss: 364.2759
# Epoch 39/50
#  - 0s - loss: 348.4327
# Epoch 40/50
#  - 0s - loss: 334.9639
# Epoch 41/50
#  - 0s - loss: 321.3741
# Epoch 42/50
#  - 0s - loss: 305.5679
# Epoch 43/50
#  - 0s - loss: 293.3827
# Epoch 44/50
#  - 0s - loss: 282.0582
# Epoch 45/50
#  - 0s - loss: 272.3890
# Epoch 46/50
#  - 0s - loss: 261.1531
# Epoch 47/50
#  - 0s - loss: 253.9243
# Epoch 48/50
#  - 0s - loss: 243.4953
# Epoch 49/50
#  - 0s - loss: 235.2957
# Epoch 50/50
#  - 0s - loss: 227.8113
# Evaluate on test data
# 309/309 [==============================] - 0s 588us/step
# test loss, test acc: 192.21922470142155
# Test set MSE for 4 cycle:192.21922797333085
# Epoch 1/50
#  - 1s - loss: 2102.7697
# Epoch 2/50
#  - 0s - loss: 1602.8037
# Epoch 3/50
#  - 0s - loss: 1423.6256
# Epoch 4/50
#  - 0s - loss: 1270.8548
# Epoch 5/50
#  - 0s - loss: 1136.9566
# Epoch 6/50
#  - 0s - loss: 1021.4377
# Epoch 7/50
#  - 0s - loss: 915.6832
# Epoch 8/50
#  - 0s - loss: 825.1739
# Epoch 9/50
#  - 0s - loss: 748.8433
# Epoch 10/50
#  - 0s - loss: 672.2636
# Epoch 11/50
#  - 0s - loss: 601.5029
# Epoch 12/50
#  - 0s - loss: 549.6230
# Epoch 13/50
#  - 0s - loss: 486.1548
# Epoch 14/50
#  - 0s - loss: 441.2057
# Epoch 15/50
#  - 0s - loss: 401.3125
# Epoch 16/50
#  - 0s - loss: 361.2452
# Epoch 17/50
#  - 0s - loss: 325.0435
# Epoch 18/50
#  - 0s - loss: 295.3641
# Epoch 19/50
#  - 0s - loss: 268.7705
# Epoch 20/50
#  - 0s - loss: 248.6015
# Epoch 21/50
#  - 0s - loss: 227.1335
# Epoch 22/50
#  - 0s - loss: 207.0875
# Epoch 23/50
#  - 0s - loss: 192.9299
# Epoch 24/50
#  - 0s - loss: 179.3797
# Epoch 25/50
#  - 0s - loss: 166.6114
# Epoch 26/50
#  - 0s - loss: 156.7110
# Epoch 27/50
#  - 0s - loss: 148.5144
# Epoch 28/50
#  - 0s - loss: 141.4064
# Epoch 29/50
#  - 0s - loss: 136.6066
# Epoch 30/50
#  - 0s - loss: 131.3906
# Epoch 31/50
#  - 0s - loss: 127.7312
# Epoch 32/50
#  - 0s - loss: 122.9939
# Epoch 33/50
#  - 0s - loss: 122.4284
# Epoch 34/50
#  - 0s - loss: 119.5268
# Epoch 35/50
#  - 1s - loss: 117.4578
# Epoch 36/50
#  - 0s - loss: 116.4720
# Epoch 37/50
#  - 0s - loss: 115.3543
# Epoch 38/50
#  - 0s - loss: 114.9349
# Epoch 39/50
#  - 0s - loss: 113.2575
# Epoch 40/50
#  - 0s - loss: 112.0648
# Epoch 41/50
#  - 0s - loss: 111.7431
# Epoch 42/50
#  - 0s - loss: 111.1803
# Epoch 43/50
#  - 0s - loss: 110.9223
# Epoch 44/50
#  - 0s - loss: 111.4827
# Epoch 45/50
#  - 0s - loss: 110.8325
# Epoch 46/50
#  - 0s - loss: 112.1120
# Epoch 47/50
#  - 0s - loss: 113.1229
# Epoch 48/50
#  - 0s - loss: 112.6839
# Epoch 49/50
#  - 0s - loss: 111.8686
# Epoch 50/50
#  - 0s - loss: 111.7599
# Evaluate on test data
# 309/309 [==============================] - 0s 705us/step
# test loss, test acc: 110.84736766630006
# Test set MSE for 5 cycle:110.8473695483343
# Epoch 1/50
#  - 1s - loss: 1239364.0906
# Epoch 2/50
#  - 0s - loss: 760926.9304
# Epoch 3/50
#  - 0s - loss: 421343.6618
# Epoch 4/50
#  - 0s - loss: 204166.6381
# Epoch 5/50
#  - 0s - loss: 85057.5424
# Epoch 6/50
#  - 0s - loss: 30839.6235
# Epoch 7/50
#  - 0s - loss: 11450.1697
# Epoch 8/50
#  - 0s - loss: 5836.4690
# Epoch 9/50
#  - 0s - loss: 4607.0033
# Epoch 10/50
#  - 0s - loss: 4389.3481
# Epoch 11/50
#  - 0s - loss: 4280.0543
# Epoch 12/50
#  - 0s - loss: 4192.6109
# Epoch 13/50
#  - 0s - loss: 4108.1247
# Epoch 14/50
#  - 0s - loss: 4021.0274
# Epoch 15/50
#  - 0s - loss: 3935.6858
# Epoch 16/50
#  - 0s - loss: 3847.2809
# Epoch 17/50
#  - 0s - loss: 3762.3073
# Epoch 18/50
#  - 0s - loss: 3675.4880
# Epoch 19/50
#  - 0s - loss: 3589.8923
# Epoch 20/50
#  - 0s - loss: 3505.4954
# Epoch 21/50
#  - 0s - loss: 3420.0768
# Epoch 22/50
#  - 0s - loss: 3339.9723
# Epoch 23/50
#  - 0s - loss: 3256.9147
# Epoch 24/50
#  - 0s - loss: 3172.6597
# Epoch 25/50
#  - 0s - loss: 3093.4111
# Epoch 26/50
#  - 0s - loss: 3016.0218
# Epoch 27/50
#  - 0s - loss: 2937.6014
# Epoch 28/50
#  - 0s - loss: 2861.1960
# Epoch 29/50
#  - 0s - loss: 2786.2836
# Epoch 30/50
#  - 0s - loss: 2717.5332
# Epoch 31/50
#  - 0s - loss: 2639.0398
# Epoch 32/50
#  - 0s - loss: 2574.7243
# Epoch 33/50
#  - 0s - loss: 2498.5033
# Epoch 34/50
#  - 0s - loss: 2431.8841
# Epoch 35/50
#  - 0s - loss: 2366.6621
# Epoch 36/50
#  - 0s - loss: 2306.3191
# Epoch 37/50
#  - 1s - loss: 2238.3543
# Epoch 38/50
#  - 0s - loss: 2173.7408
# Epoch 39/50
#  - 0s - loss: 2113.7799
# Epoch 40/50
#  - 0s - loss: 2051.5863
# Epoch 41/50
#  - 0s - loss: 1997.1556
# Epoch 42/50
#  - 0s - loss: 1942.8620
# Epoch 43/50
#  - 0s - loss: 1881.7703
# Epoch 44/50
#  - 0s - loss: 1825.7353
# Epoch 45/50
#  - 0s - loss: 1771.7836
# Epoch 46/50
#  - 0s - loss: 1725.4059
# Epoch 47/50
#  - 1s - loss: 1674.0820
# Epoch 48/50
#  - 0s - loss: 1628.2075
# Epoch 49/50
#  - 0s - loss: 1571.7770
# Epoch 50/50
#  - 0s - loss: 1521.9841
# Evaluate on test data
# 309/309 [==============================] - 0s 731us/step
# test loss, test acc: 1398.0171329041516
# Test set MSE for 6 cycle:1398.017112585853
# Epoch 1/50
#  - 1s - loss: 1435.0846
# Epoch 2/50
#  - 0s - loss: 827.8093
# Epoch 3/50
#  - 0s - loss: 663.7577
# Epoch 4/50
#  - 0s - loss: 565.4810
# Epoch 5/50
#  - 0s - loss: 471.6242
# Epoch 6/50
#  - 0s - loss: 401.3891
# Epoch 7/50
#  - 0s - loss: 346.5096
# Epoch 8/50
#  - 0s - loss: 301.2524
# Epoch 9/50
#  - 0s - loss: 264.5518
# Epoch 10/50
#  - 0s - loss: 237.9204
# Epoch 11/50
#  - 0s - loss: 220.2731
# Epoch 12/50
#  - 0s - loss: 199.0850
# Epoch 13/50
#  - 0s - loss: 188.1816
# Epoch 14/50
#  - 0s - loss: 175.8448
# Epoch 15/50
#  - 0s - loss: 174.9554
# Epoch 16/50
#  - 0s - loss: 165.8174
# Epoch 17/50
#  - 0s - loss: 156.2442
# Epoch 18/50
#  - 0s - loss: 151.6876
# Epoch 19/50
#  - 0s - loss: 146.2658
# Epoch 20/50
#  - 0s - loss: 149.2872
# Epoch 21/50
#  - 0s - loss: 139.0679
# Epoch 22/50
#  - 0s - loss: 136.5859
# Epoch 23/50
#  - 0s - loss: 132.5148
# Epoch 24/50
#  - 0s - loss: 132.6954
# Epoch 25/50
#  - 0s - loss: 130.9067
# Epoch 26/50
#  - 0s - loss: 132.1931
# Epoch 27/50
#  - 0s - loss: 134.8550
# Epoch 28/50
#  - 0s - loss: 129.3545
# Epoch 29/50
#  - 0s - loss: 124.0469
# Epoch 30/50
#  - 0s - loss: 122.4168
# Epoch 31/50
#  - 0s - loss: 121.7164
# Epoch 32/50
#  - 0s - loss: 122.3270
# Epoch 33/50
#  - 0s - loss: 122.0023
# Epoch 34/50
#  - 0s - loss: 121.8837
# Epoch 35/50
#  - 0s - loss: 120.4081
# Epoch 36/50
#  - 0s - loss: 120.1763
# Epoch 37/50
#  - 0s - loss: 117.9337
# Epoch 38/50
#  - 0s - loss: 117.0862
# Epoch 39/50
#  - 0s - loss: 117.3009
# Epoch 40/50
#  - 0s - loss: 114.7317
# Epoch 41/50
#  - 0s - loss: 117.3411
# Epoch 42/50
#  - 0s - loss: 116.5804
# Epoch 43/50
#  - 0s - loss: 113.9766
# Epoch 44/50
#  - 0s - loss: 119.0152
# Epoch 45/50
#  - 0s - loss: 114.7790
# Epoch 46/50
#  - 0s - loss: 113.0207
# Epoch 47/50
#  - 0s - loss: 115.8103
# Epoch 48/50
#  - 0s - loss: 112.7174
# Epoch 49/50
#  - 1s - loss: 112.8733
# Epoch 50/50
#  - 0s - loss: 116.4487
# Evaluate on test data
# 309/309 [==============================] - 0s 833us/step
# test loss, test acc: 109.81800333658855
# Test set MSE for 7 cycle:109.81800555871241
# Epoch 1/50
#  - 1s - loss: 2545.2239
# Epoch 2/50
#  - 0s - loss: 1996.9938
# Epoch 3/50
#  - 0s - loss: 1500.4197
# Epoch 4/50
#  - 0s - loss: 980.1430
# Epoch 5/50
#  - 0s - loss: 616.6186
# Epoch 6/50
#  - 0s - loss: 462.5641
# Epoch 7/50
#  - 0s - loss: 400.9997
# Epoch 8/50
#  - 0s - loss: 362.1727
# Epoch 9/50
#  - 0s - loss: 340.3745
# Epoch 10/50
#  - 0s - loss: 318.3537
# Epoch 11/50
#  - 0s - loss: 298.8315
# Epoch 12/50
#  - 0s - loss: 284.4435
# Epoch 13/50
#  - 0s - loss: 271.4304
# Epoch 14/50
#  - 0s - loss: 259.6301
# Epoch 15/50
#  - 0s - loss: 246.2927
# Epoch 16/50
#  - 0s - loss: 239.2847
# Epoch 17/50
#  - 0s - loss: 228.7542
# Epoch 18/50
#  - 0s - loss: 219.8100
# Epoch 19/50
#  - 0s - loss: 213.1149
# Epoch 20/50
#  - 0s - loss: 205.6123
# Epoch 21/50
#  - 0s - loss: 197.9360
# Epoch 22/50
#  - 0s - loss: 191.7365
# Epoch 23/50
#  - 0s - loss: 185.6153
# Epoch 24/50
#  - 0s - loss: 180.2421
# Epoch 25/50
#  - 0s - loss: 176.4176
# Epoch 26/50
#  - 0s - loss: 169.8569
# Epoch 27/50
#  - 0s - loss: 165.8598
# Epoch 28/50
#  - 0s - loss: 160.5894
# Epoch 29/50
#  - 0s - loss: 156.6425
# Epoch 30/50
#  - 0s - loss: 152.3352
# Epoch 31/50
#  - 0s - loss: 148.8106
# Epoch 32/50
#  - 0s - loss: 150.1663
# Epoch 33/50
#  - 0s - loss: 142.6783
# Epoch 34/50
#  - 0s - loss: 139.1723
# Epoch 35/50
#  - 0s - loss: 135.4127
# Epoch 36/50
#  - 0s - loss: 136.9828
# Epoch 37/50
#  - 0s - loss: 134.3825
# Epoch 38/50
#  - 0s - loss: 130.7136
# Epoch 39/50
#  - 0s - loss: 126.0290
# Epoch 40/50
#  - 0s - loss: 125.9137
# Epoch 41/50
#  - 0s - loss: 123.0906
# Epoch 42/50
#  - 0s - loss: 122.5265
# Epoch 43/50
#  - 0s - loss: 120.4838
# Epoch 44/50
#  - 0s - loss: 118.9944
# Epoch 45/50
#  - 0s - loss: 118.6860
# Epoch 46/50
#  - 0s - loss: 119.2626
# Epoch 47/50
#  - 0s - loss: 116.4254
# Epoch 48/50
#  - 0s - loss: 116.2442
# Epoch 49/50
#  - 0s - loss: 114.1333
# Epoch 50/50
#  - 0s - loss: 116.4973
# Evaluate on test data
# 309/309 [==============================] - 0s 967us/step
# test loss, test acc: 124.27350036226044
# Test set MSE for 8 cycle:124.27350155222938
# Epoch 1/50
#  - 1s - loss: 5729.8307
# Epoch 2/50
#  - 0s - loss: 1959.0285
# Epoch 3/50
#  - 0s - loss: 1412.3901
# Epoch 4/50
#  - 0s - loss: 1089.6867
# Epoch 5/50
#  - 0s - loss: 856.5160
# Epoch 6/50
#  - 0s - loss: 685.9783
# Epoch 7/50
#  - 0s - loss: 562.4428
# Epoch 8/50
#  - 0s - loss: 478.6757
# Epoch 9/50
#  - 0s - loss: 419.5305
# Epoch 10/50
#  - 0s - loss: 378.8713
# Epoch 11/50
#  - 0s - loss: 349.6763
# Epoch 12/50
#  - 0s - loss: 326.0563
# Epoch 13/50
#  - 0s - loss: 309.6700
# Epoch 14/50
#  - 0s - loss: 301.2049
# Epoch 15/50
#  - 0s - loss: 289.1013
# Epoch 16/50
#  - 0s - loss: 275.0432
# Epoch 17/50
#  - 0s - loss: 269.1537
# Epoch 18/50
#  - 0s - loss: 257.1002
# Epoch 19/50
#  - 0s - loss: 250.2690
# Epoch 20/50
#  - 0s - loss: 243.0355
# Epoch 21/50
#  - 0s - loss: 234.5695
# Epoch 22/50
#  - 0s - loss: 232.0888
# Epoch 23/50
#  - 0s - loss: 226.4144
# Epoch 24/50
#  - 0s - loss: 221.4889
# Epoch 25/50
#  - 0s - loss: 215.8776
# Epoch 26/50
#  - 0s - loss: 211.2098
# Epoch 27/50
#  - 0s - loss: 208.4759
# Epoch 28/50
#  - 0s - loss: 202.8361
# Epoch 29/50
#  - 0s - loss: 198.7066
# Epoch 30/50
#  - 0s - loss: 195.6348
# Epoch 31/50
#  - 0s - loss: 192.3923
# Epoch 32/50
#  - 0s - loss: 189.5104
# Epoch 33/50
#  - 0s - loss: 185.8951
# Epoch 34/50
#  - 0s - loss: 183.1976
# Epoch 35/50
#  - 0s - loss: 181.9492
# Epoch 36/50
#  - 0s - loss: 180.7135
# Epoch 37/50
#  - 0s - loss: 174.8925
# Epoch 38/50
#  - 0s - loss: 171.1684
# Epoch 39/50
#  - 0s - loss: 169.9020
# Epoch 40/50
#  - 0s - loss: 167.1189
# Epoch 41/50
#  - 0s - loss: 163.8547
# Epoch 42/50
#  - 0s - loss: 161.1147
# Epoch 43/50
#  - 0s - loss: 160.9978
# Epoch 44/50
#  - 0s - loss: 158.4126
# Epoch 45/50
#  - 0s - loss: 156.7579
# Epoch 46/50
#  - 0s - loss: 153.5317
# Epoch 47/50
#  - 0s - loss: 151.1060
# Epoch 48/50
#  - 0s - loss: 149.4830
# Epoch 49/50
#  - 0s - loss: 148.0767
# Epoch 50/50
#  - 0s - loss: 146.8877
# Evaluate on test data
# 309/309 [==============================] - 0s 1ms/step
# test loss, test acc: 163.46639130725057
# Test set MSE for 9 cycle:163.46639590837847
# Epoch 1/50
#  - 1s - loss: 3779.4922
# Epoch 2/50
#  - 0s - loss: 3103.5712
# Epoch 3/50
#  - 0s - loss: 2677.5068
# Epoch 4/50
#  - 0s - loss: 2328.8746
# Epoch 5/50
#  - 0s - loss: 2013.1798
# Epoch 6/50
#  - 0s - loss: 1750.5153
# Epoch 7/50
#  - 0s - loss: 1531.3794
# Epoch 8/50
#  - 0s - loss: 1318.2711
# Epoch 9/50
#  - 0s - loss: 1149.6534
# Epoch 10/50
#  - 0s - loss: 1008.9521
# Epoch 11/50
#  - 0s - loss: 879.6574
# Epoch 12/50
#  - 0s - loss: 771.1435
# Epoch 13/50
#  - 0s - loss: 685.0218
# Epoch 14/50
#  - 0s - loss: 604.3083
# Epoch 15/50
#  - 0s - loss: 533.0437
# Epoch 16/50
#  - 0s - loss: 475.9337
# Epoch 17/50
#  - 0s - loss: 424.8149
# Epoch 18/50
#  - 0s - loss: 378.6980
# Epoch 19/50
#  - 0s - loss: 344.7852
# Epoch 20/50
#  - 0s - loss: 307.5745
# Epoch 21/50
#  - 0s - loss: 283.9564
# Epoch 22/50
#  - 0s - loss: 260.1066
# Epoch 23/50
#  - 0s - loss: 235.1446
# Epoch 24/50
#  - 0s - loss: 216.2041
# Epoch 25/50
#  - 0s - loss: 202.7670
# Epoch 26/50
#  - 0s - loss: 191.8728
# Epoch 27/50
#  - 0s - loss: 179.7547
# Epoch 28/50
#  - 0s - loss: 171.1617
# Epoch 29/50
#  - 0s - loss: 164.0772
# Epoch 30/50
#  - 0s - loss: 156.4085
# Epoch 31/50
#  - 0s - loss: 151.1982
# Epoch 32/50
#  - 0s - loss: 146.6216
# Epoch 33/50
#  - 0s - loss: 143.3799
# Epoch 34/50
#  - 0s - loss: 139.7694
# Epoch 35/50
#  - 0s - loss: 137.1312
# Epoch 36/50
#  - 0s - loss: 135.9577
# Epoch 37/50
#  - 0s - loss: 132.9948
# Epoch 38/50
#  - 0s - loss: 130.6857
# Epoch 39/50
#  - 0s - loss: 133.4946
# Epoch 40/50
#  - 0s - loss: 132.2432
# Epoch 41/50
#  - 0s - loss: 128.8117
# Epoch 42/50
#  - 0s - loss: 129.5949
# Epoch 43/50
#  - 0s - loss: 125.9629
# Epoch 44/50
#  - 0s - loss: 127.7218
# Epoch 45/50
#  - 0s - loss: 126.7602
# Epoch 46/50
#  - 0s - loss: 125.3724
# Epoch 47/50
#  - 0s - loss: 123.9082
# Epoch 48/50
#  - 0s - loss: 127.0333
# Epoch 49/50
#  - 0s - loss: 126.4648
# Epoch 50/50
#  - 0s - loss: 124.2576
# Evaluate on test data
# 309/309 [==============================] - 0s 1ms/step
# test loss, test acc: 128.94265811265865
# Test set MSE for 10 cycle:128.94265888453873
# Epoch 1/50
#  - 1s - loss: 2068.5218
# Epoch 2/50
#  - 0s - loss: 383.5910
# Epoch 3/50
#  - 0s - loss: 328.5570
# Epoch 4/50
#  - 0s - loss: 310.1141
# Epoch 5/50
#  - 0s - loss: 295.0524
# Epoch 6/50
#  - 0s - loss: 281.1282
# Epoch 7/50
#  - 0s - loss: 268.9958
# Epoch 8/50
#  - 0s - loss: 254.8178
# Epoch 9/50
#  - 0s - loss: 244.1479
# Epoch 10/50
#  - 1s - loss: 234.0911
# Epoch 11/50
#  - 0s - loss: 225.8203
# Epoch 12/50
#  - 0s - loss: 217.3757
# Epoch 13/50
#  - 0s - loss: 212.4098
# Epoch 14/50
#  - 0s - loss: 204.6552
# Epoch 15/50
#  - 0s - loss: 199.5427
# Epoch 16/50
#  - 0s - loss: 194.5400
# Epoch 17/50
#  - 0s - loss: 191.3799
# Epoch 18/50
#  - 0s - loss: 187.8759
# Epoch 19/50
#  - 0s - loss: 183.5333
# Epoch 20/50
#  - 0s - loss: 183.0269
# Epoch 21/50
#  - 0s - loss: 179.3457
# Epoch 22/50
#  - 0s - loss: 178.9486
# Epoch 23/50
#  - 0s - loss: 174.5202
# Epoch 24/50
#  - 0s - loss: 172.3208
# Epoch 25/50
#  - 0s - loss: 170.1143
# Epoch 26/50
#  - 0s - loss: 168.9126
# Epoch 27/50
#  - 0s - loss: 169.8791
# Epoch 28/50
#  - 0s - loss: 167.4635
# Epoch 29/50
#  - 0s - loss: 164.3253
# Epoch 30/50
#  - 0s - loss: 164.3688
# Epoch 31/50
#  - 0s - loss: 161.2734
# Epoch 32/50
#  - 0s - loss: 160.2636
# Epoch 33/50
#  - 0s - loss: 160.1285
# Epoch 34/50
#  - 0s - loss: 158.0365
# Epoch 35/50
#  - 0s - loss: 157.5300
# Epoch 36/50
#  - 0s - loss: 157.4296
# Epoch 37/50
#  - 0s - loss: 154.2276
# Epoch 38/50
#  - 0s - loss: 156.7698
# Epoch 39/50
#  - 0s - loss: 152.6153
# Epoch 40/50
#  - 0s - loss: 154.2806
# Epoch 41/50
#  - 0s - loss: 152.4265
# Epoch 42/50
#  - 0s - loss: 150.8871
# Epoch 43/50
#  - 0s - loss: 151.7165
# Epoch 44/50
#  - 0s - loss: 148.4993
# Epoch 45/50
#  - 0s - loss: 147.0536
# Epoch 46/50
#  - 0s - loss: 147.7354
# Epoch 47/50
#  - 0s - loss: 145.7082
# Epoch 48/50
#  - 0s - loss: 144.9225
# Epoch 49/50
#  - 0s - loss: 144.2336
# Epoch 50/50
#  - 0s - loss: 142.6325
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 149.91554255315788
# Test set MSE for 11 cycle:149.91554640680943
# Epoch 1/50
#  - 1s - loss: 14760.0184
# Epoch 2/50
#  - 0s - loss: 2864.0523
# Epoch 3/50
#  - 0s - loss: 1457.1432
# Epoch 4/50
#  - 0s - loss: 1350.2298
# Epoch 5/50
#  - 0s - loss: 1246.4907
# Epoch 6/50
#  - 0s - loss: 1162.7199
# Epoch 7/50
#  - 0s - loss: 1087.4577
# Epoch 8/50
#  - 0s - loss: 1016.3865
# Epoch 9/50
#  - 0s - loss: 949.4131
# Epoch 10/50
#  - 0s - loss: 895.2147
# Epoch 11/50
#  - 0s - loss: 836.0398
# Epoch 12/50
#  - 0s - loss: 785.8454
# Epoch 13/50
#  - 0s - loss: 736.6436
# Epoch 14/50
#  - 0s - loss: 696.5289
# Epoch 15/50
#  - 0s - loss: 654.1143
# Epoch 16/50
#  - 0s - loss: 619.0343
# Epoch 17/50
#  - 0s - loss: 585.7305
# Epoch 18/50
#  - 0s - loss: 556.0701
# Epoch 19/50
#  - 0s - loss: 527.5465
# Epoch 20/50
#  - 0s - loss: 501.0706
# Epoch 21/50
#  - 1s - loss: 478.5432
# Epoch 22/50
#  - 0s - loss: 457.3458
# Epoch 23/50
#  - 0s - loss: 435.1806
# Epoch 24/50
#  - 0s - loss: 414.6081
# Epoch 25/50
#  - 0s - loss: 395.1110
# Epoch 26/50
#  - 0s - loss: 378.2735
# Epoch 27/50
#  - 0s - loss: 362.0679
# Epoch 28/50
#  - 0s - loss: 346.8864
# Epoch 29/50
#  - 0s - loss: 332.7753
# Epoch 30/50
#  - 0s - loss: 319.5594
# Epoch 31/50
#  - 0s - loss: 306.7577
# Epoch 32/50
#  - 0s - loss: 296.0318
# Epoch 33/50
#  - 0s - loss: 284.8967
# Epoch 34/50
#  - 0s - loss: 273.3306
# Epoch 35/50
#  - 0s - loss: 263.9424
# Epoch 36/50
#  - 0s - loss: 255.5597
# Epoch 37/50
#  - 0s - loss: 247.9267
# Epoch 38/50
#  - 0s - loss: 241.0947
# Epoch 39/50
#  - 0s - loss: 233.1556
# Epoch 40/50
#  - 0s - loss: 224.0348
# Epoch 41/50
#  - 0s - loss: 217.5866
# Epoch 42/50
#  - 0s - loss: 212.7769
# Epoch 43/50
#  - 0s - loss: 206.8421
# Epoch 44/50
#  - 0s - loss: 201.0010
# Epoch 45/50
#  - 0s - loss: 197.4919
# Epoch 46/50
#  - 0s - loss: 190.5018
# Epoch 47/50
#  - 0s - loss: 185.3992
# Epoch 48/50
#  - 0s - loss: 181.3377
# Epoch 49/50
#  - 0s - loss: 176.7570
# Epoch 50/50
#  - 0s - loss: 173.8584
# Evaluate on test data
# 309/309 [==============================] - 0s 2ms/step
# test loss, test acc: 176.93632294985082
# Test set MSE for 12 cycle:176.9363251046648
# Epoch 1/50
#  - 1s - loss: 288634.3171
# Epoch 2/50
#  - 0s - loss: 189042.3973
# Epoch 3/50
#  - 0s - loss: 110689.7559
# Epoch 4/50
#  - 0s - loss: 45772.2877
# Epoch 5/50
#  - 0s - loss: 11737.0884
# Epoch 6/50
#  - 0s - loss: 3834.0955
# Epoch 7/50
#  - 0s - loss: 3180.3630
# Epoch 8/50
#  - 0s - loss: 2980.5012
# Epoch 9/50
#  - 0s - loss: 2775.6196
# Epoch 10/50
#  - 0s - loss: 2592.8553
# Epoch 11/50
#  - 0s - loss: 2410.4514
# Epoch 12/50
#  - 0s - loss: 2247.0029
# Epoch 13/50
#  - 0s - loss: 2091.2265
# Epoch 14/50
#  - 0s - loss: 1948.6194
# Epoch 15/50
#  - 0s - loss: 1822.7465
# Epoch 16/50
#  - 0s - loss: 1698.7918
# Epoch 17/50
#  - 0s - loss: 1588.9765
# Epoch 18/50
#  - 0s - loss: 1487.8482
# Epoch 19/50
#  - 0s - loss: 1392.5708
# Epoch 20/50
#  - 0s - loss: 1303.7979
# Epoch 21/50
#  - 0s - loss: 1229.0100
# Epoch 22/50
#  - 0s - loss: 1155.5461
# Epoch 23/50
#  - 0s - loss: 1088.9623
# Epoch 24/50
#  - 0s - loss: 1031.1417
# Epoch 25/50
#  - 0s - loss: 975.4561
# Epoch 26/50
#  - 0s - loss: 926.9019
# Epoch 27/50
#  - 0s - loss: 882.3099
# Epoch 28/50
#  - 0s - loss: 840.0324
# Epoch 29/50
#  - 0s - loss: 801.7051
# Epoch 30/50
#  - 0s - loss: 766.1675
# Epoch 31/50
#  - 0s - loss: 734.1927
# Epoch 32/50
#  - 0s - loss: 703.8572
# Epoch 33/50
#  - 0s - loss: 676.0654
# Epoch 34/50
#  - 0s - loss: 650.2346
# Epoch 35/50
#  - 0s - loss: 626.2178
# Epoch 36/50
#  - 0s - loss: 604.2579
# Epoch 37/50
#  - 0s - loss: 584.2382
# Epoch 38/50
#  - 0s - loss: 562.7660
# Epoch 39/50
#  - 0s - loss: 543.2381
# Epoch 40/50
#  - 0s - loss: 525.8134
# Epoch 41/50
#  - 0s - loss: 510.2645
# Epoch 42/50
#  - 0s - loss: 492.7890
# Epoch 43/50
#  - 0s - loss: 477.1906
# Epoch 44/50
#  - 0s - loss: 462.3628
# Epoch 45/50
#  - 0s - loss: 448.1601
# Epoch 46/50
#  - 0s - loss: 434.9530
# Epoch 47/50
#  - 0s - loss: 421.5069
# Epoch 48/50
#  - 0s - loss: 409.1939
# Epoch 49/50
#  - 0s - loss: 396.7083
# Epoch 50/50
#  - 0s - loss: 385.8311
# Evaluate on test data
# 309/309 [==============================] - 0s 1ms/step
# test loss, test acc: 375.4148117608623
# Test set MSE for 13 cycle:375.41481752877985
# Epoch 1/50
#  - 2s - loss: 314668.8881
# Epoch 2/50
#  - 0s - loss: 166902.6086
# Epoch 3/50
#  - 0s - loss: 75984.1015
# Epoch 4/50
#  - 0s - loss: 29451.3233
# Epoch 5/50
#  - 0s - loss: 10629.2257
# Epoch 6/50
#  - 0s - loss: 4703.5631
# Epoch 7/50
#  - 0s - loss: 3376.0905
# Epoch 8/50
#  - 0s - loss: 3094.4629
# Epoch 9/50
#  - 0s - loss: 2953.0220
# Epoch 10/50
#  - 0s - loss: 2838.2807
# Epoch 11/50
#  - 0s - loss: 2715.4450
# Epoch 12/50
#  - 0s - loss: 2600.1839
# Epoch 13/50
#  - 0s - loss: 2479.7191
# Epoch 14/50
#  - 0s - loss: 2367.6868
# Epoch 15/50
#  - 0s - loss: 2255.5501
# Epoch 16/50
#  - 0s - loss: 2146.2512
# Epoch 17/50
#  - 0s - loss: 2040.4267
# Epoch 18/50
#  - 0s - loss: 1936.6139
# Epoch 19/50
#  - 0s - loss: 1836.3573
# Epoch 20/50
#  - 0s - loss: 1741.8665
# Epoch 21/50
#  - 0s - loss: 1651.0087
# Epoch 22/50
#  - 0s - loss: 1561.5770
# Epoch 23/50
#  - 0s - loss: 1476.2944
# Epoch 24/50
#  - 0s - loss: 1401.7571
# Epoch 25/50
#  - 0s - loss: 1322.3190
# Epoch 26/50
#  - 0s - loss: 1252.2745
# Epoch 27/50
#  - 0s - loss: 1177.9568
# Epoch 28/50
#  - 0s - loss: 1113.9324
# Epoch 29/50
#  - 0s - loss: 1052.7313
# Epoch 30/50
#  - 0s - loss: 994.8420
# Epoch 31/50
#  - 0s - loss: 941.2038
# Epoch 32/50
#  - 0s - loss: 891.1945
# Epoch 33/50
#  - 0s - loss: 839.3681
# Epoch 34/50
#  - 0s - loss: 794.2087
# Epoch 35/50
#  - 0s - loss: 751.9908
# Epoch 36/50
#  - 0s - loss: 711.9905
# Epoch 37/50
#  - 0s - loss: 675.9944
# Epoch 38/50
#  - 0s - loss: 640.7371
# Epoch 39/50
#  - 0s - loss: 610.3971
# Epoch 40/50
#  - 0s - loss: 580.6744
# Epoch 41/50
#  - 0s - loss: 553.2746
# Epoch 42/50
#  - 0s - loss: 526.6153
# Epoch 43/50
#  - 0s - loss: 503.4845
# Epoch 44/50
#  - 0s - loss: 480.6647
# Epoch 45/50
#  - 0s - loss: 461.8002
# Epoch 46/50
#  - 0s - loss: 440.8115
# Epoch 47/50
#  - 0s - loss: 422.4095
# Epoch 48/50
#  - 0s - loss: 406.9579
# Epoch 49/50
#  - 0s - loss: 391.4994
# Epoch 50/50
#  - 0s - loss: 376.5439
# Evaluate on test data
# 309/309 [==============================] - 0s 2ms/step
# test loss, test acc: 375.57245139705327
# Test set MSE for 14 cycle:375.5724632581423
# Epoch 1/50
#  - 1s - loss: 415080.4104
# Epoch 2/50
#  - 0s - loss: 134156.0358
# Epoch 3/50
#  - 0s - loss: 28655.5607
# Epoch 4/50
#  - 0s - loss: 7140.3331
# Epoch 5/50
#  - 0s - loss: 5163.8370
# Epoch 6/50
#  - 0s - loss: 4963.2414
# Epoch 7/50
#  - 0s - loss: 4720.7102
# Epoch 8/50
#  - 0s - loss: 4487.7660
# Epoch 9/50
#  - 0s - loss: 4259.6979
# Epoch 10/50
#  - 0s - loss: 4029.5698
# Epoch 11/50
#  - 0s - loss: 3800.5968
# Epoch 12/50
#  - 0s - loss: 3579.2792
# Epoch 13/50
#  - 0s - loss: 3378.0817
# Epoch 14/50
#  - 0s - loss: 3167.6764
# Epoch 15/50
#  - 0s - loss: 2965.7070
# Epoch 16/50
#  - 0s - loss: 2789.1578
# Epoch 17/50
#  - 0s - loss: 2597.0825
# Epoch 18/50
#  - 0s - loss: 2426.7597
# Epoch 19/50
#  - 0s - loss: 2265.6330
# Epoch 20/50
#  - 0s - loss: 2118.7689
# Epoch 21/50
#  - 0s - loss: 1971.6418
# Epoch 22/50
#  - 0s - loss: 1837.0244
# Epoch 23/50
#  - 0s - loss: 1707.1575
# Epoch 24/50
#  - 0s - loss: 1590.1428
# Epoch 25/50
#  - 0s - loss: 1486.1562
# Epoch 26/50
#  - 1s - loss: 1374.2872
# Epoch 27/50
#  - 0s - loss: 1287.5364
# Epoch 28/50
#  - 0s - loss: 1187.2365
# Epoch 29/50
#  - 0s - loss: 1110.1281
# Epoch 30/50
#  - 0s - loss: 1026.4058
# Epoch 31/50
#  - 0s - loss: 958.0605
# Epoch 32/50
#  - 0s - loss: 890.3245
# Epoch 33/50
#  - 0s - loss: 832.2316
# Epoch 34/50
#  - 0s - loss: 772.1406
# Epoch 35/50
#  - 0s - loss: 720.4736
# Epoch 36/50
#  - 0s - loss: 671.6441
# Epoch 37/50
#  - 0s - loss: 627.1566
# Epoch 38/50
#  - 0s - loss: 592.1541
# Epoch 39/50
#  - 0s - loss: 548.0344
# Epoch 40/50
#  - 0s - loss: 512.3428
# Epoch 41/50
#  - 1s - loss: 480.6231
# Epoch 42/50
#  - 0s - loss: 451.8470
# Epoch 43/50
#  - 0s - loss: 424.5276
# Epoch 44/50
#  - 0s - loss: 397.7034
# Epoch 45/50
#  - 0s - loss: 377.1781
# Epoch 46/50
#  - 0s - loss: 356.7343
# Epoch 47/50
#  - 0s - loss: 336.1230
# Epoch 48/50
#  - 0s - loss: 320.0852
# Epoch 49/50
#  - 0s - loss: 300.6726
# Epoch 50/50
#  - 0s - loss: 284.8844
# Evaluate on test data
# 309/309 [==============================] - 0s 1ms/step
# test loss, test acc: 272.85788911986117
# Test set MSE for 15 cycle:272.8578935325515
# Epoch 1/50
#  - 1s - loss: 43227.3510
# Epoch 2/50
#  - 0s - loss: 18012.2360
# Epoch 3/50
#  - 0s - loss: 7535.8255
# Epoch 4/50
#  - 0s - loss: 3576.0259
# Epoch 5/50
#  - 0s - loss: 2006.0093
# Epoch 6/50
#  - 0s - loss: 1338.5271
# Epoch 7/50
#  - 0s - loss: 1022.9537
# Epoch 8/50
#  - 0s - loss: 861.8086
# Epoch 9/50
#  - 0s - loss: 767.8646
# Epoch 10/50
#  - 0s - loss: 704.7327
# Epoch 11/50
#  - 0s - loss: 657.8174
# Epoch 12/50
#  - 0s - loss: 622.5123
# Epoch 13/50
#  - 0s - loss: 589.8567
# Epoch 14/50
#  - 0s - loss: 563.4727
# Epoch 15/50
#  - 0s - loss: 539.4052
# Epoch 16/50
#  - 0s - loss: 515.8200
# Epoch 17/50
#  - 0s - loss: 494.2709
# Epoch 18/50
#  - 0s - loss: 475.2477
# Epoch 19/50
#  - 0s - loss: 457.1093
# Epoch 20/50
#  - 0s - loss: 441.0695
# Epoch 21/50
#  - 0s - loss: 426.8852
# Epoch 22/50
#  - 0s - loss: 412.7016
# Epoch 23/50
#  - 0s - loss: 400.6479
# Epoch 24/50
#  - 0s - loss: 389.8784
# Epoch 25/50
#  - 0s - loss: 379.3132
# Epoch 26/50
#  - 0s - loss: 369.7107
# Epoch 27/50
#  - 0s - loss: 361.0737
# Epoch 28/50
#  - 0s - loss: 352.7674
# Epoch 29/50
#  - 0s - loss: 345.2994
# Epoch 30/50
#  - 0s - loss: 338.1219
# Epoch 31/50
#  - 0s - loss: 331.5679
# Epoch 32/50
#  - 0s - loss: 325.2207
# Epoch 33/50
#  - 0s - loss: 319.6252
# Epoch 34/50
#  - 0s - loss: 314.2710
# Epoch 35/50
#  - 0s - loss: 309.0949
# Epoch 36/50
#  - 0s - loss: 304.6673
# Epoch 37/50
#  - 0s - loss: 300.4819
# Epoch 38/50
#  - 0s - loss: 296.4757
# Epoch 39/50
#  - 0s - loss: 292.8065
# Epoch 40/50
#  - 0s - loss: 289.2224
# Epoch 41/50
#  - 0s - loss: 286.3245
# Epoch 42/50
#  - 0s - loss: 283.0804
# Epoch 43/50
#  - 0s - loss: 280.0259
# Epoch 44/50
#  - 0s - loss: 277.3263
# Epoch 45/50
#  - 0s - loss: 274.6927
# Epoch 46/50
#  - 0s - loss: 272.1966
# Epoch 47/50
#  - 0s - loss: 269.9334
# Epoch 48/50
#  - 0s - loss: 267.6908
# Epoch 49/50
#  - 0s - loss: 265.3219
# Epoch 50/50
#  - 0s - loss: 263.1400
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 266.3470977486916
# Test set MSE for 16 cycle:266.34709822798146
# Epoch 1/50
#  - 2s - loss: 6950.9300
# Epoch 2/50
#  - 0s - loss: 2473.1556
# Epoch 3/50
#  - 0s - loss: 1169.6984
# Epoch 4/50
#  - 0s - loss: 703.9168
# Epoch 5/50
#  - 0s - loss: 515.7387
# Epoch 6/50
#  - 0s - loss: 431.0720
# Epoch 7/50
#  - 0s - loss: 389.0173
# Epoch 8/50
#  - 0s - loss: 368.9061
# Epoch 9/50
#  - 0s - loss: 357.9945
# Epoch 10/50
#  - 0s - loss: 352.2395
# Epoch 11/50
#  - 0s - loss: 347.0975
# Epoch 12/50
#  - 0s - loss: 342.9321
# Epoch 13/50
#  - 0s - loss: 338.7743
# Epoch 14/50
#  - 0s - loss: 335.4559
# Epoch 15/50
#  - 0s - loss: 331.6596
# Epoch 16/50
#  - 0s - loss: 328.1904
# Epoch 17/50
#  - 0s - loss: 323.2642
# Epoch 18/50
#  - 0s - loss: 319.4393
# Epoch 19/50
#  - 0s - loss: 316.1134
# Epoch 20/50
#  - 0s - loss: 311.6978
# Epoch 21/50
#  - 0s - loss: 307.9906
# Epoch 22/50
#  - 0s - loss: 304.4220
# Epoch 23/50
#  - 0s - loss: 300.7620
# Epoch 24/50
#  - 0s - loss: 295.9015
# Epoch 25/50
#  - 0s - loss: 291.5956
# Epoch 26/50
#  - 0s - loss: 286.3944
# Epoch 27/50
#  - 0s - loss: 281.9699
# Epoch 28/50
#  - 0s - loss: 277.8989
# Epoch 29/50
#  - 0s - loss: 273.7939
# Epoch 30/50
#  - 0s - loss: 269.9225
# Epoch 31/50
#  - 0s - loss: 266.4774
# Epoch 32/50
#  - 0s - loss: 262.5062
# Epoch 33/50
#  - 0s - loss: 259.0880
# Epoch 34/50
#  - 0s - loss: 256.7711
# Epoch 35/50
#  - 0s - loss: 252.4300
# Epoch 36/50
#  - 0s - loss: 248.7366
# Epoch 37/50
#  - 0s - loss: 245.6354
# Epoch 38/50
#  - 0s - loss: 242.9956
# Epoch 39/50
#  - 0s - loss: 239.8539
# Epoch 40/50
#  - 0s - loss: 237.3463
# Epoch 41/50
#  - 0s - loss: 235.4499
# Epoch 42/50
#  - 0s - loss: 232.6276
# Epoch 43/50
#  - 0s - loss: 230.0820
# Epoch 44/50
#  - 0s - loss: 228.0406
# Epoch 45/50
#  - 0s - loss: 225.8773
# Epoch 46/50
#  - 0s - loss: 224.3471
# Epoch 47/50
#  - 0s - loss: 221.8936
# Epoch 48/50
#  - 0s - loss: 219.9474
# Epoch 49/50
#  - 0s - loss: 218.2549
# Epoch 50/50
#  - 0s - loss: 216.3472
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 252.0356726785308
# Test set MSE for 17 cycle:252.0356818739717
# Epoch 1/50
#  - 2s - loss: 21916.9139
# Epoch 2/50
#  - 0s - loss: 5461.3268
# Epoch 3/50
#  - 0s - loss: 1505.2352
# Epoch 4/50
#  - 0s - loss: 859.5340
# Epoch 5/50
#  - 0s - loss: 784.0862
# Epoch 6/50
#  - 0s - loss: 754.9605
# Epoch 7/50
#  - 0s - loss: 727.2178
# Epoch 8/50
#  - 0s - loss: 699.3550
# Epoch 9/50
#  - 0s - loss: 673.7101
# Epoch 10/50
#  - 0s - loss: 649.1894
# Epoch 11/50
#  - 0s - loss: 625.9547
# Epoch 12/50
#  - 0s - loss: 604.9510
# Epoch 13/50
#  - 5s - loss: 585.2652
# Epoch 14/50
#  - 0s - loss: 568.1819
# Epoch 15/50
#  - 0s - loss: 552.4570
# Epoch 16/50
#  - 0s - loss: 538.6162
# Epoch 17/50
#  - 0s - loss: 524.1386
# Epoch 18/50
#  - 0s - loss: 510.3788
# Epoch 19/50
#  - 0s - loss: 497.5476
# Epoch 20/50
#  - 0s - loss: 485.2315
# Epoch 21/50
#  - 0s - loss: 474.4137
# Epoch 22/50
#  - 0s - loss: 463.7238
# Epoch 23/50
#  - 0s - loss: 453.7467
# Epoch 24/50
#  - 0s - loss: 444.5494
# Epoch 25/50
#  - 0s - loss: 435.2921
# Epoch 26/50
#  - 0s - loss: 425.7743
# Epoch 27/50
#  - 0s - loss: 418.1766
# Epoch 28/50
#  - 0s - loss: 409.4147
# Epoch 29/50
#  - 0s - loss: 401.2323
# Epoch 30/50
#  - 0s - loss: 392.9621
# Epoch 31/50
#  - 0s - loss: 384.7971
# Epoch 32/50
#  - 0s - loss: 377.2208
# Epoch 33/50
#  - 0s - loss: 369.9143
# Epoch 34/50
#  - 0s - loss: 362.6992
# Epoch 35/50
#  - 0s - loss: 358.0989
# Epoch 36/50
#  - 0s - loss: 351.8791
# Epoch 37/50
#  - 0s - loss: 341.9677
# Epoch 38/50
#  - 0s - loss: 334.7171
# Epoch 39/50
#  - 0s - loss: 329.4978
# Epoch 40/50
#  - 0s - loss: 323.5655
# Epoch 41/50
#  - 0s - loss: 317.5571
# Epoch 42/50
#  - 0s - loss: 312.0929
# Epoch 43/50
#  - 0s - loss: 306.4277
# Epoch 44/50
#  - 0s - loss: 301.2398
# Epoch 45/50
#  - 0s - loss: 295.8779
# Epoch 46/50
#  - 0s - loss: 290.2518
# Epoch 47/50
#  - 0s - loss: 285.2237
# Epoch 48/50
#  - 0s - loss: 280.5672
# Epoch 49/50
#  - 0s - loss: 275.5259
# Epoch 50/50
#  - 0s - loss: 270.9391
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 262.8899671931097
# Test set MSE for 18 cycle:262.88996917761125
# Epoch 1/50
#  - 2s - loss: 56215.1008
# Epoch 2/50
#  - 0s - loss: 32234.2417
# Epoch 3/50
#  - 0s - loss: 20832.0854
# Epoch 4/50
#  - 0s - loss: 14703.4587
# Epoch 5/50
#  - 0s - loss: 10930.8359
# Epoch 6/50
#  - 0s - loss: 8448.6088
# Epoch 7/50
#  - 0s - loss: 6707.1012
# Epoch 8/50
#  - 0s - loss: 5467.1538
# Epoch 9/50
#  - 0s - loss: 4547.5544
# Epoch 10/50
#  - 0s - loss: 3824.1949
# Epoch 11/50
#  - 0s - loss: 3258.6906
# Epoch 12/50
#  - 0s - loss: 2799.2189
# Epoch 13/50
#  - 0s - loss: 2414.4049
# Epoch 14/50
#  - 0s - loss: 2092.4653
# Epoch 15/50
#  - 0s - loss: 1813.2972
# Epoch 16/50
#  - 0s - loss: 1570.8311
# Epoch 17/50
#  - 0s - loss: 1356.6165
# Epoch 18/50
#  - 0s - loss: 1167.5400
# Epoch 19/50
#  - 0s - loss: 998.9468
# Epoch 20/50
#  - 0s - loss: 851.9239
# Epoch 21/50
#  - 0s - loss: 723.8411
# Epoch 22/50
#  - 0s - loss: 613.0660
# Epoch 23/50
#  - 0s - loss: 522.2121
# Epoch 24/50
#  - 0s - loss: 448.7421
# Epoch 25/50
#  - 0s - loss: 389.7467
# Epoch 26/50
#  - 0s - loss: 345.1079
# Epoch 27/50
#  - 0s - loss: 311.7750
# Epoch 28/50
#  - 0s - loss: 287.9507
# Epoch 29/50
#  - 0s - loss: 270.8423
# Epoch 30/50
#  - 0s - loss: 259.5184
# Epoch 31/50
#  - 0s - loss: 251.5666
# Epoch 32/50
#  - 0s - loss: 246.5091
# Epoch 33/50
#  - 0s - loss: 243.0111
# Epoch 34/50
#  - 0s - loss: 240.6622
# Epoch 35/50
#  - 0s - loss: 239.1157
# Epoch 36/50
#  - 0s - loss: 237.9585
# Epoch 37/50
#  - 0s - loss: 237.0416
# Epoch 38/50
#  - 0s - loss: 236.2988
# Epoch 39/50
#  - 0s - loss: 235.5035
# Epoch 40/50
#  - 0s - loss: 234.8039
# Epoch 41/50
#  - 0s - loss: 234.1607
# Epoch 42/50
#  - 0s - loss: 233.5615
# Epoch 43/50
#  - 0s - loss: 232.7981
# Epoch 44/50
#  - 0s - loss: 232.1458
# Epoch 45/50
#  - 0s - loss: 231.4274
# Epoch 46/50
#  - 0s - loss: 230.8416
# Epoch 47/50
#  - 0s - loss: 230.1443
# Epoch 48/50
#  - 0s - loss: 229.4075
# Epoch 49/50
#  - 0s - loss: 228.7801
# Epoch 50/50
#  - 0s - loss: 228.0798
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 235.99288333040997
# Test set MSE for 19 cycle:235.99288586023133
# Epoch 1/50
#  - 2s - loss: 86960.8141
# Epoch 2/50
#  - 0s - loss: 35288.0088
# Epoch 3/50
#  - 0s - loss: 13607.7457
# Epoch 4/50
#  - 0s - loss: 4875.6357
# Epoch 5/50
#  - 0s - loss: 1749.7946
# Epoch 6/50
#  - 0s - loss: 1121.7222
# Epoch 7/50
#  - 0s - loss: 1013.5779
# Epoch 8/50
#  - 0s - loss: 931.0395
# Epoch 9/50
#  - 0s - loss: 860.4999
# Epoch 10/50
#  - 0s - loss: 796.0213
# Epoch 11/50
#  - 0s - loss: 739.9153
# Epoch 12/50
#  - 0s - loss: 691.0504
# Epoch 13/50
#  - 0s - loss: 648.6531
# Epoch 14/50
#  - 0s - loss: 610.6716
# Epoch 15/50
#  - 0s - loss: 578.2199
# Epoch 16/50
#  - 0s - loss: 550.2252
# Epoch 17/50
#  - 0s - loss: 525.7395
# Epoch 18/50
#  - 0s - loss: 503.4025
# Epoch 19/50
#  - 0s - loss: 483.1550
# Epoch 20/50
#  - 0s - loss: 466.9039
# Epoch 21/50
#  - 0s - loss: 451.0151
# Epoch 22/50
#  - 0s - loss: 436.9802
# Epoch 23/50
#  - 0s - loss: 424.2283
# Epoch 24/50
#  - 0s - loss: 412.1924
# Epoch 25/50
#  - 0s - loss: 401.4318
# Epoch 26/50
#  - 0s - loss: 390.4766
# Epoch 27/50
#  - 0s - loss: 380.0029
# Epoch 28/50
#  - 0s - loss: 369.4616
# Epoch 29/50
#  - 0s - loss: 361.1696
# Epoch 30/50
#  - 0s - loss: 352.0499
# Epoch 31/50
#  - 0s - loss: 342.8654
# Epoch 32/50
#  - 0s - loss: 333.6088
# Epoch 33/50
#  - 0s - loss: 326.4122
# Epoch 34/50
#  - 0s - loss: 316.5970
# Epoch 35/50
#  - 0s - loss: 307.5292
# Epoch 36/50
#  - 0s - loss: 300.0716
# Epoch 37/50
#  - 0s - loss: 292.7804
# Epoch 38/50
#  - 0s - loss: 286.6961
# Epoch 39/50
#  - 0s - loss: 279.5081
# Epoch 40/50
#  - 0s - loss: 272.3875
# Epoch 41/50
#  - 0s - loss: 266.1030
# Epoch 42/50
#  - 0s - loss: 259.8249
# Epoch 43/50
#  - 0s - loss: 253.9355
# Epoch 44/50
#  - 0s - loss: 248.4282
# Epoch 45/50
#  - 0s - loss: 242.5938
# Epoch 46/50
#  - 0s - loss: 238.3505
# Epoch 47/50
#  - 0s - loss: 233.3235
# Epoch 48/50
#  - 0s - loss: 227.1961
# Epoch 49/50
#  - 0s - loss: 223.3556
# Epoch 50/50
#  - 0s - loss: 217.1288
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 198.5194951523469
# Test set MSE for 20 cycle:198.51949150868606
# Epoch 1/50
#  - 2s - loss: 258383.6543
# Epoch 2/50
#  - 0s - loss: 119331.1930
# Epoch 3/50
#  - 0s - loss: 33540.3702
# Epoch 4/50
#  - 0s - loss: 7127.0212
# Epoch 5/50
#  - 0s - loss: 5840.2710
# Epoch 6/50
#  - 0s - loss: 5173.0779
# Epoch 7/50
#  - 0s - loss: 4664.9257
# Epoch 8/50
#  - 0s - loss: 4210.5185
# Epoch 9/50
#  - 0s - loss: 3817.5141
# Epoch 10/50
#  - 0s - loss: 3451.9332
# Epoch 11/50
#  - 0s - loss: 3144.3776
# Epoch 12/50
#  - 0s - loss: 2862.7824
# Epoch 13/50
#  - 0s - loss: 2608.0529
# Epoch 14/50
#  - 0s - loss: 2385.0145
# Epoch 15/50
#  - 0s - loss: 2191.2895
# Epoch 16/50
#  - 0s - loss: 2015.7513
# Epoch 17/50
#  - 0s - loss: 1862.6919
# Epoch 18/50
#  - 0s - loss: 1723.5565
# Epoch 19/50
#  - 0s - loss: 1590.9784
# Epoch 20/50
#  - 0s - loss: 1479.5131
# Epoch 21/50
#  - 0s - loss: 1385.7339
# Epoch 22/50
#  - 0s - loss: 1294.1702
# Epoch 23/50
#  - 0s - loss: 1212.8584
# Epoch 24/50
#  - 0s - loss: 1144.4483
# Epoch 25/50
#  - 0s - loss: 1075.1421
# Epoch 26/50
#  - 0s - loss: 1018.9293
# Epoch 27/50
#  - 0s - loss: 965.3151
# Epoch 28/50
#  - 0s - loss: 911.3481
# Epoch 29/50
#  - 0s - loss: 865.0779
# Epoch 30/50
#  - 0s - loss: 824.6024
# Epoch 31/50
#  - 0s - loss: 787.8599
# Epoch 32/50
#  - 0s - loss: 752.7368
# Epoch 33/50
#  - 0s - loss: 722.3103
# Epoch 34/50
#  - 0s - loss: 689.6623
# Epoch 35/50
#  - 0s - loss: 658.1147
# Epoch 36/50
#  - 0s - loss: 630.7818
# Epoch 37/50
#  - 0s - loss: 604.9286
# Epoch 38/50
#  - 0s - loss: 580.2102
# Epoch 39/50
#  - 0s - loss: 556.8937
# Epoch 40/50
#  - 0s - loss: 537.1772
# Epoch 41/50
#  - 0s - loss: 516.7796
# Epoch 42/50
#  - 0s - loss: 497.3963
# Epoch 43/50
#  - 0s - loss: 480.5652
# Epoch 44/50
#  - 0s - loss: 463.4145
# Epoch 45/50
#  - 0s - loss: 449.0799
# Epoch 46/50
#  - 0s - loss: 434.7468
# Epoch 47/50
#  - 0s - loss: 421.4704
# Epoch 48/50
#  - 0s - loss: 408.5819
# Epoch 49/50
#  - 0s - loss: 397.5273
# Epoch 50/50
#  - 0s - loss: 386.5519
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 395.85118977074484
# Test set MSE for 21 cycle:395.851189918046
# Epoch 1/50
#  - 2s - loss: 11304.4705
# Epoch 2/50
#  - 0s - loss: 5960.9239
# Epoch 3/50
#  - 0s - loss: 5021.0804
# Epoch 4/50
#  - 0s - loss: 4362.7235
# Epoch 5/50
#  - 0s - loss: 3788.4348
# Epoch 6/50
#  - 0s - loss: 3287.2261
# Epoch 7/50
#  - 0s - loss: 2856.3132
# Epoch 8/50
#  - 0s - loss: 2479.8459
# Epoch 9/50
#  - 0s - loss: 2124.7049
# Epoch 10/50
#  - 0s - loss: 1836.1020
# Epoch 11/50
#  - 0s - loss: 1567.5476
# Epoch 12/50
#  - 0s - loss: 1334.2537
# Epoch 13/50
#  - 0s - loss: 1142.0802
# Epoch 14/50
#  - 0s - loss: 961.9752
# Epoch 15/50
#  - 0s - loss: 825.0539
# Epoch 16/50
#  - 0s - loss: 677.5339
# Epoch 17/50
#  - 0s - loss: 582.6418
# Epoch 18/50
#  - 0s - loss: 492.1714
# Epoch 19/50
#  - 0s - loss: 414.9481
# Epoch 20/50
#  - 0s - loss: 355.1746
# Epoch 21/50
#  - 0s - loss: 313.2409
# Epoch 22/50
#  - 0s - loss: 272.9391
# Epoch 23/50
#  - 0s - loss: 245.3889
# Epoch 24/50
#  - 0s - loss: 221.3661
# Epoch 25/50
#  - 0s - loss: 200.2489
# Epoch 26/50
#  - 0s - loss: 184.6448
# Epoch 27/50
#  - 0s - loss: 175.1180
# Epoch 28/50
#  - 0s - loss: 165.9922
# Epoch 29/50
#  - 0s - loss: 160.0612
# Epoch 30/50
#  - 0s - loss: 148.3694
# Epoch 31/50
#  - 0s - loss: 148.8498
# Epoch 32/50
#  - 0s - loss: 142.1459
# Epoch 33/50
#  - 0s - loss: 139.6986
# Epoch 34/50
#  - 0s - loss: 137.8415
# Epoch 35/50
#  - 0s - loss: 135.0436
# Epoch 36/50
#  - 0s - loss: 132.6908
# Epoch 37/50
#  - 0s - loss: 131.9605
# Epoch 38/50
#  - 0s - loss: 131.3450
# Epoch 39/50
#  - 0s - loss: 130.2306
# Epoch 40/50
#  - 0s - loss: 131.5439
# Epoch 41/50
#  - 0s - loss: 127.4826
# Epoch 42/50
#  - 0s - loss: 130.0791
# Epoch 43/50
#  - 0s - loss: 127.8077
# Epoch 44/50
#  - 0s - loss: 127.7798
# Epoch 45/50
#  - 0s - loss: 129.8960
# Epoch 46/50
#  - 0s - loss: 126.7664
# Epoch 47/50
#  - 0s - loss: 126.3428
# Epoch 48/50
#  - 0s - loss: 123.8771
# Epoch 49/50
#  - 0s - loss: 124.0904
# Epoch 50/50
#  - 0s - loss: 125.5691
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 125.29584629095874
# Test set MSE for 22 cycle:125.29584768514462
# Epoch 1/50
#  - 2s - loss: 20689.7907
# Epoch 2/50
#  - 0s - loss: 9782.8559
# Epoch 3/50
#  - 0s - loss: 8451.9183
# Epoch 4/50
#  - 0s - loss: 7464.8252
# Epoch 5/50
#  - 0s - loss: 6446.3216
# Epoch 6/50
#  - 0s - loss: 5286.1390
# Epoch 7/50
#  - 0s - loss: 4129.2022
# Epoch 8/50
#  - 0s - loss: 3136.1856
# Epoch 9/50
#  - 0s - loss: 2427.6266
# Epoch 10/50
#  - 0s - loss: 1923.4165
# Epoch 11/50
#  - 0s - loss: 1565.1396
# Epoch 12/50
#  - 0s - loss: 1280.7207
# Epoch 13/50
#  - 0s - loss: 1074.3298
# Epoch 14/50
#  - 0s - loss: 899.3757
# Epoch 15/50
#  - 0s - loss: 760.4284
# Epoch 16/50
#  - 0s - loss: 648.6318
# Epoch 17/50
#  - 0s - loss: 554.0421
# Epoch 18/50
#  - 0s - loss: 478.7720
# Epoch 19/50
#  - 0s - loss: 417.1473
# Epoch 20/50
#  - 0s - loss: 379.8546
# Epoch 21/50
#  - 0s - loss: 333.9442
# Epoch 22/50
#  - 0s - loss: 292.5975
# Epoch 23/50
#  - 0s - loss: 265.2329
# Epoch 24/50
#  - 0s - loss: 244.3568
# Epoch 25/50
#  - 0s - loss: 224.3199
# Epoch 26/50
#  - 0s - loss: 209.3601
# Epoch 27/50
#  - 0s - loss: 197.0746
# Epoch 28/50
#  - 0s - loss: 186.2845
# Epoch 29/50
#  - 0s - loss: 180.1815
# Epoch 30/50
#  - 0s - loss: 171.2022
# Epoch 31/50
#  - 0s - loss: 164.8870
# Epoch 32/50
#  - 0s - loss: 158.9808
# Epoch 33/50
#  - 0s - loss: 158.1741
# Epoch 34/50
#  - 0s - loss: 153.3198
# Epoch 35/50
#  - 0s - loss: 150.9800
# Epoch 36/50
#  - 0s - loss: 146.5526
# Epoch 37/50
#  - 0s - loss: 144.3032
# Epoch 38/50
#  - 0s - loss: 140.9342
# Epoch 39/50
#  - 0s - loss: 141.1944
# Epoch 40/50
#  - 0s - loss: 138.1449
# Epoch 41/50
#  - 0s - loss: 135.9436
# Epoch 42/50
#  - 0s - loss: 135.5753
# Epoch 43/50
#  - 0s - loss: 136.1665
# Epoch 44/50
#  - 0s - loss: 133.5884
# Epoch 45/50
#  - 1s - loss: 134.1638
# Epoch 46/50
#  - 0s - loss: 128.9625
# Epoch 47/50
#  - 0s - loss: 129.4842
# Epoch 48/50
#  - 0s - loss: 127.8324
# Epoch 49/50
#  - 0s - loss: 127.1033
# Epoch 50/50
#  - 0s - loss: 126.6465
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 121.52857921810212
# Test set MSE for 23 cycle:121.52858334612088
# Epoch 1/50
#  - 2s - loss: 9524.0368
# Epoch 2/50
#  - 0s - loss: 2935.4381
# Epoch 3/50
#  - 0s - loss: 2684.4209
# Epoch 4/50
#  - 0s - loss: 2435.9507
# Epoch 5/50
#  - 0s - loss: 2268.5521
# Epoch 6/50
#  - 0s - loss: 2104.3158
# Epoch 7/50
#  - 0s - loss: 1953.9991
# Epoch 8/50
#  - 0s - loss: 1815.6440
# Epoch 9/50
#  - 0s - loss: 1675.3878
# Epoch 10/50
#  - 0s - loss: 1564.0225
# Epoch 11/50
#  - 0s - loss: 1438.5809
# Epoch 12/50
#  - 0s - loss: 1330.6319
# Epoch 13/50
#  - 0s - loss: 1240.5133
# Epoch 14/50
#  - 0s - loss: 1153.4794
# Epoch 15/50
#  - 0s - loss: 1066.3015
# Epoch 16/50
#  - 0s - loss: 999.7694
# Epoch 17/50
#  - 0s - loss: 928.6919
# Epoch 18/50
#  - 0s - loss: 855.3623
# Epoch 19/50
#  - 0s - loss: 795.6466
# Epoch 20/50
#  - 0s - loss: 733.3512
# Epoch 21/50
#  - 3s - loss: 680.5732
# Epoch 22/50
#  - 0s - loss: 615.0056
# Epoch 23/50
#  - 0s - loss: 565.3029
# Epoch 24/50
#  - 0s - loss: 516.8609
# Epoch 25/50
#  - 0s - loss: 472.0693
# Epoch 26/50
#  - 0s - loss: 433.6995
# Epoch 27/50
#  - 0s - loss: 394.2841
# Epoch 28/50
#  - 0s - loss: 362.7937
# Epoch 29/50
#  - 0s - loss: 332.2487
# Epoch 30/50
#  - 0s - loss: 305.9946
# Epoch 31/50
#  - 0s - loss: 284.0845
# Epoch 32/50
#  - 0s - loss: 260.8029
# Epoch 33/50
#  - 0s - loss: 242.6971
# Epoch 34/50
#  - 0s - loss: 226.1478
# Epoch 35/50
#  - 0s - loss: 213.9274
# Epoch 36/50
#  - 0s - loss: 199.4779
# Epoch 37/50
#  - 0s - loss: 187.2621
# Epoch 38/50
#  - 0s - loss: 177.8176
# Epoch 39/50
#  - 0s - loss: 168.9102
# Epoch 40/50
#  - 0s - loss: 160.9116
# Epoch 41/50
#  - 0s - loss: 153.9790
# Epoch 42/50
#  - 0s - loss: 150.6291
# Epoch 43/50
#  - 0s - loss: 145.6894
# Epoch 44/50
#  - 0s - loss: 140.7683
# Epoch 45/50
#  - 0s - loss: 137.6760
# Epoch 46/50
#  - 0s - loss: 134.0621
# Epoch 47/50
#  - 0s - loss: 129.4972
# Epoch 48/50
#  - 0s - loss: 131.3218
# Epoch 49/50
#  - 0s - loss: 125.9497
# Epoch 50/50
#  - 0s - loss: 125.5469
# Evaluate on test data
# 309/309 [==============================] - 1s 2ms/step
# test loss, test acc: 131.52379455072594
# Test set MSE for 24 cycle:131.523795271224
# Epoch 1/50
#  - 2s - loss: 346065.5512
# Epoch 2/50
#  - 0s - loss: 164206.2406
# Epoch 3/50
#  - 0s - loss: 70227.2245
# Epoch 4/50
#  - 0s - loss: 28131.2494
# Epoch 5/50
#  - 0s - loss: 11235.7069
# Epoch 6/50
#  - 0s - loss: 5294.5458
# Epoch 7/50
#  - 0s - loss: 3520.1579
# Epoch 8/50
#  - 0s - loss: 3054.5199
# Epoch 9/50
#  - 0s - loss: 2874.1777
# Epoch 10/50
#  - 0s - loss: 2781.0486
# Epoch 11/50
#  - 0s - loss: 2684.2046
# Epoch 12/50
#  - 0s - loss: 2600.2781
# Epoch 13/50
#  - 0s - loss: 2513.7108
# Epoch 14/50
#  - 0s - loss: 2433.8421
# Epoch 15/50
#  - 0s - loss: 2361.1804
# Epoch 16/50
#  - 0s - loss: 2286.7025
# Epoch 17/50
#  - 0s - loss: 2218.6743
# Epoch 18/50
#  - 0s - loss: 2151.0168
# Epoch 19/50
#  - 0s - loss: 2087.5277
# Epoch 20/50
#  - 0s - loss: 2023.9290
# Epoch 21/50
#  - 0s - loss: 1961.7881
# Epoch 22/50
#  - 0s - loss: 1905.2188
# Epoch 23/50
#  - 0s - loss: 1842.8254
# Epoch 24/50
#  - 0s - loss: 1787.4641
# Epoch 25/50
#  - 0s - loss: 1731.5972
# Epoch 26/50
#  - 0s - loss: 1679.3843
# Epoch 27/50
#  - 0s - loss: 1625.6802
# Epoch 28/50
#  - 0s - loss: 1573.7289
# Epoch 29/50
#  - 0s - loss: 1525.2998
# Epoch 30/50
#  - 0s - loss: 1478.9175
# Epoch 31/50
#  - 0s - loss: 1426.0819
# Epoch 32/50
#  - 0s - loss: 1363.1902
# Epoch 33/50
#  - 0s - loss: 1266.7138
# Epoch 34/50
#  - 0s - loss: 1100.0750
# Epoch 35/50
#  - 0s - loss: 943.8354
# Epoch 36/50
#  - 0s - loss: 794.2919
# Epoch 37/50
#  - 0s - loss: 652.1328
# Epoch 38/50
#  - 0s - loss: 533.6295
# Epoch 39/50
#  - 0s - loss: 442.2754
# Epoch 40/50
#  - 0s - loss: 366.9344
# Epoch 41/50
#  - 0s - loss: 317.3755
# Epoch 42/50
#  - 0s - loss: 270.6860
# Epoch 43/50
#  - 0s - loss: 252.8953
# Epoch 44/50
#  - 0s - loss: 223.6555
# Epoch 45/50
#  - 0s - loss: 205.2811
# Epoch 46/50
#  - 0s - loss: 193.9536
# Epoch 47/50
#  - 0s - loss: 183.5346
# Epoch 48/50
#  - 0s - loss: 176.7893
# Epoch 49/50
#  - 0s - loss: 170.9788
# Epoch 50/50
#  - 0s - loss: 168.5324
# Evaluate on test data
# 309/309 [==============================] - 1s 3ms/step
# test loss, test acc: 169.21088085977004
# ...
# Epoch 36/50
#  - 0s - loss: 139.9793
# Epoch 37/50
#  - 0s - loss: 141.4542
# Epoch 38/50
#  - 0s - loss: 133.1620
# Epoch 39/50
#  - 0s - loss: 128.7422
# Epoch 40/50
#  - 0s - loss: 125.8342
# Epoch 41/50
#  - 0s - loss: 125.8859
# Epoch 42/50
#  - 0s - loss: 122.7952
# Epoch 43/50
#  - 0s - loss: 121.2382
# Epoch 44/50
#  - 0s - loss: 118.6227
# Epoch 45/50
#  - 0s - loss: 116.7914
# Epoch 46/50
#  - 0s - loss: 117.2361
# Epoch 47/50
#  - 0s - loss: 116.1784
# Epoch 48/50
#  - 0s - loss: 113.7515
# Epoch 49/50
#  - 0s - loss: 114.1349
# Epoch 50/50
#  - 0s - loss: 111.8951
# Evaluate on test data
# 309/309 [==============================] - 1s 4ms/step
# test loss, test acc: 113.78346289477302
# Test set MSE for 42 cycle:113.78346610932526
# Epoch 1/50
#  - 4s - loss: 75091.2765
# Epoch 2/50
#  - 0s - loss: 26745.2768
# Epoch 3/50
#  - 0s - loss: 8050.9733
# Epoch 4/50
#  - 0s - loss: 4113.8600
# Epoch 5/50
#  - 0s - loss: 3566.0960
# Epoch 6/50
#  - 0s - loss: 3269.7040
# Epoch 7/50
#  - 0s - loss: 3022.4920
# Epoch 8/50
#  - 0s - loss: 2797.2259
# Epoch 9/50
#  - 0s - loss: 2586.6576
# Epoch 10/50
#  - 0s - loss: 2386.0335
# Epoch 11/50
#  - 0s - loss: 2201.4458
# Epoch 12/50
#  - 0s - loss: 2030.1459
# Epoch 13/50
#  - 0s - loss: 1868.5044
# Epoch 14/50
#  - 0s - loss: 1725.1599
# Epoch 15/50
#  - 0s - loss: 1588.7200
# Epoch 16/50
#  - 0s - loss: 1469.4105
# Epoch 17/50
#  - 0s - loss: 1355.4484
# Epoch 18/50
#  - 0s - loss: 1256.1405
# Epoch 19/50
#  - 0s - loss: 1162.1315
# Epoch 20/50
#  - 0s - loss: 1071.9432
# Epoch 21/50
#  - 0s - loss: 997.0744
# Epoch 22/50
#  - 0s - loss: 923.1400
# Epoch 23/50
#  - 0s - loss: 857.4373
# Epoch 24/50
#  - 0s - loss: 799.8904
# Epoch 25/50
#  - 0s - loss: 747.2640
# Epoch 26/50
#  - 0s - loss: 699.7766
# Epoch 27/50
#  - 0s - loss: 655.7382
# Epoch 28/50
#  - 0s - loss: 615.1845
# Epoch 29/50
#  - 0s - loss: 580.8755
# Epoch 30/50
#  - 0s - loss: 548.5683
# Epoch 31/50
#  - 0s - loss: 519.3598
# Epoch 32/50
#  - 0s - loss: 493.2268
# Epoch 33/50
#  - 0s - loss: 469.5820
# Epoch 34/50
#  - 0s - loss: 448.3688
# Epoch 35/50
#  - 0s - loss: 426.4666
# Epoch 36/50
#  - 0s - loss: 405.1386
# Epoch 37/50
#  - 0s - loss: 382.9882
# Epoch 38/50
#  - 0s - loss: 363.3484
# Epoch 39/50
#  - 0s - loss: 344.5533
# Epoch 40/50
#  - 0s - loss: 326.9561
# Epoch 41/50
#  - 0s - loss: 308.9002
# Epoch 42/50
#  - 0s - loss: 289.9359
# Epoch 43/50
#  - 0s - loss: 274.8949
# Epoch 44/50
#  - 0s - loss: 261.8575
# Epoch 45/50
#  - 0s - loss: 248.2658
# Epoch 46/50
#  - 0s - loss: 235.4874
# Epoch 47/50
#  - 0s - loss: 223.5371
# Epoch 48/50
#  - 0s - loss: 213.1743
# Epoch 49/50
#  - 0s - loss: 204.2173
# Epoch 50/50
#  - 0s - loss: 195.4850
# Evaluate on test data
# 309/309 [==============================] - 1s 4ms/step
# test loss, test acc: 170.79000163155467
# Test set MSE for 43 cycle:170.79000556684397
# Epoch 1/50
#  - 3s - loss: 65277.6338
# Epoch 2/50
#  - 0s - loss: 24161.5375
# Epoch 3/50
#  - 0s - loss: 8444.2213
# Epoch 4/50
#  - 0s - loss: 5333.2084
# Epoch 5/50
#  - 0s - loss: 4794.4757
# Epoch 6/50
#  - 0s - loss: 4141.9837
# Epoch 7/50
#  - 0s - loss: 3319.4674
# Epoch 8/50
#  - 0s - loss: 2787.8721
# Epoch 9/50
#  - 0s - loss: 2400.4070
# Epoch 10/50
#  - 0s - loss: 2113.6406
# Epoch 11/50
#  - 0s - loss: 1863.1020
# Epoch 12/50
#  - 0s - loss: 1663.8131
# Epoch 13/50
#  - 0s - loss: 1487.2864
# Epoch 14/50
#  - 0s - loss: 1337.2590
# Epoch 15/50
#  - 0s - loss: 1203.4134
# Epoch 16/50
#  - 0s - loss: 1089.0727
# Epoch 17/50
#  - 0s - loss: 989.8546
# Epoch 18/50
#  - 0s - loss: 898.5272
# Epoch 19/50
#  - 0s - loss: 821.6385
# Epoch 20/50
#  - 0s - loss: 757.7426
# Epoch 21/50
#  - 0s - loss: 695.4602
# Epoch 22/50
#  - 0s - loss: 641.2092
# Epoch 23/50
#  - 0s - loss: 593.7489
# Epoch 24/50
#  - 0s - loss: 549.2574
# Epoch 25/50
#  - 0s - loss: 512.0823
# Epoch 26/50
#  - 0s - loss: 476.0463
# Epoch 27/50
#  - 0s - loss: 445.7461
# Epoch 28/50
#  - 0s - loss: 421.4871
# Epoch 29/50
#  - 0s - loss: 394.4669
# Epoch 30/50
#  - 0s - loss: 374.2987
# Epoch 31/50
#  - 0s - loss: 354.8163
# Epoch 32/50
#  - 0s - loss: 335.7050
# Epoch 33/50
#  - 0s - loss: 322.1442
# Epoch 34/50
#  - 0s - loss: 308.0312
# Epoch 35/50
#  - 0s - loss: 296.8376
# Epoch 36/50
#  - 0s - loss: 287.2041
# Epoch 37/50
#  - 0s - loss: 278.7269
# Epoch 38/50
#  - 0s - loss: 270.3374
# Epoch 39/50
#  - 0s - loss: 264.4862
# Epoch 40/50
#  - 0s - loss: 257.5075
# Epoch 41/50
#  - 0s - loss: 252.6825
# Epoch 42/50
#  - 0s - loss: 245.2564
# Epoch 43/50
#  - 0s - loss: 240.8047
# Epoch 44/50
#  - 0s - loss: 236.4138
# Epoch 45/50
#  - 0s - loss: 231.2238
# Epoch 46/50
#  - 0s - loss: 229.5432
# Epoch 47/50
#  - 0s - loss: 223.1086
# Epoch 48/50
#  - 0s - loss: 220.7642
# Epoch 49/50
#  - 0s - loss: 217.4485
# Epoch 50/50
#  - 0s - loss: 212.2485
# Evaluate on test data
# 309/309 [==============================] - 1s 4ms/step
# test loss, test acc: 228.92194393614736
# Test set MSE for 44 cycle:228.921944900435
# Epoch 1/50
#  - 4s - loss: 140294.2138
# Epoch 2/50
#  - 0s - loss: 71036.8839
# Epoch 3/50
#  - 0s - loss: 20128.8141
# Epoch 4/50
#  - 0s - loss: 3455.1353
# Epoch 5/50
#  - 0s - loss: 2687.9267
# Epoch 6/50
#  - 0s - loss: 2301.8951
# Epoch 7/50
#  - 0s - loss: 2051.0738
# Epoch 8/50
#  - 0s - loss: 1806.5883
# Epoch 9/50
#  - 0s - loss: 1579.6378
# Epoch 10/50
#  - 0s - loss: 1380.5282
# Epoch 11/50
#  - 0s - loss: 1206.9889
# Epoch 12/50
#  - 0s - loss: 1057.7122
# Epoch 13/50
#  - 0s - loss: 933.2926
# Epoch 14/50
#  - 0s - loss: 836.1176
# Epoch 15/50
#  - 0s - loss: 755.2880
# Epoch 16/50
#  - 0s - loss: 686.4618
# Epoch 17/50
#  - 0s - loss: 630.5689
# Epoch 18/50
#  - 0s - loss: 581.2086
# Epoch 19/50
#  - 0s - loss: 534.7510
# Epoch 20/50
#  - 0s - loss: 495.6753
# Epoch 21/50
#  - 0s - loss: 460.2606
# Epoch 22/50
#  - 0s - loss: 430.6633
# Epoch 23/50
#  - 0s - loss: 402.5769
# Epoch 24/50
#  - 0s - loss: 375.9794
# Epoch 25/50
#  - 0s - loss: 351.2605
# Epoch 26/50
#  - 0s - loss: 334.5752
# Epoch 27/50
#  - 0s - loss: 310.1493
# Epoch 28/50
#  - 0s - loss: 291.9854
# Epoch 29/50
#  - 0s - loss: 275.0337
# Epoch 30/50
#  - 0s - loss: 259.8459
# Epoch 31/50
#  - 0s - loss: 243.8601
# Epoch 32/50
#  - 0s - loss: 228.0834
# Epoch 33/50
#  - 0s - loss: 214.7904
# Epoch 34/50
#  - 0s - loss: 201.6336
# Epoch 35/50
#  - 0s - loss: 190.2698
# Epoch 36/50
#  - 0s - loss: 180.4601
# Epoch 37/50
#  - 0s - loss: 171.4196
# Epoch 38/50
#  - 0s - loss: 165.4248
# Epoch 39/50
#  - 0s - loss: 160.4323
# Epoch 40/50
#  - 0s - loss: 152.8659
# Epoch 41/50
#  - 0s - loss: 147.7357
# Epoch 42/50
#  - 0s - loss: 144.8827
# Epoch 43/50
#  - 0s - loss: 140.0649
# Epoch 44/50
#  - 0s - loss: 138.6013
# Epoch 45/50
#  - 0s - loss: 134.9574
# Epoch 46/50
#  - 0s - loss: 132.5270
# Epoch 47/50
#  - 0s - loss: 131.2787
# Epoch 48/50
#  - 0s - loss: 128.8857
# Epoch 49/50
#  - 0s - loss: 128.0019
# Epoch 50/50
#  - 0s - loss: 126.6542
# Evaluate on test data
# 309/309 [==============================] - 1s 5ms/step
# test loss, test acc: 126.48950555795219
# Test set MSE for 45 cycle:126.48951061900856
# Epoch 1/50
#  - 4s - loss: 809.4465
# Epoch 2/50
#  - 0s - loss: 630.1155
# Epoch 3/50
#  - 0s - loss: 539.3669
# Epoch 4/50
#  - 0s - loss: 475.9506
# Epoch 5/50
#  - 0s - loss: 422.2920
# Epoch 6/50
#  - 0s - loss: 374.5892
# Epoch 7/50
#  - 0s - loss: 340.2227
# Epoch 8/50
#  - 0s - loss: 316.8309
# Epoch 9/50
#  - 0s - loss: 287.8476
# Epoch 10/50
#  - 0s - loss: 265.0150
# Epoch 11/50
#  - 0s - loss: 249.5110
# Epoch 12/50
#  - 0s - loss: 232.6686
# Epoch 13/50
#  - 0s - loss: 218.9863
# Epoch 14/50
#  - 0s - loss: 211.2976
# Epoch 15/50
#  - 0s - loss: 199.3407
# Epoch 16/50
#  - 0s - loss: 189.5884
# Epoch 17/50
#  - 0s - loss: 180.8795
# Epoch 18/50
#  - 0s - loss: 172.0419
# Epoch 19/50
#  - 0s - loss: 165.5713
# Epoch 20/50
#  - 0s - loss: 161.9867
# Epoch 21/50
#  - 0s - loss: 153.1035
# Epoch 22/50
#  - 0s - loss: 147.8574
# Epoch 23/50
#  - 0s - loss: 142.8197
# Epoch 24/50
#  - 0s - loss: 142.4375
# Epoch 25/50
#  - 0s - loss: 136.1084
# Epoch 26/50
#  - 0s - loss: 131.6481
# Epoch 27/50
#  - 0s - loss: 129.7271
# Epoch 28/50
#  - 0s - loss: 128.5104
# Epoch 29/50
#  - 0s - loss: 124.2007
# Epoch 30/50
#  - 0s - loss: 121.4486
# Epoch 31/50
#  - 0s - loss: 119.0416
# Epoch 32/50
#  - 0s - loss: 118.4481
# Epoch 33/50
#  - 0s - loss: 121.4967
# Epoch 34/50
#  - 0s - loss: 115.2329
# Epoch 35/50
#  - 0s - loss: 115.1114
# Epoch 36/50
#  - 0s - loss: 114.3628
# Epoch 37/50
#  - 0s - loss: 114.2394
# Epoch 38/50
#  - 0s - loss: 113.5603
# Epoch 39/50
#  - 0s - loss: 111.7154
# Epoch 40/50
#  - 0s - loss: 113.5155
# Epoch 41/50
#  - 0s - loss: 111.1053
# Epoch 42/50
#  - 0s - loss: 111.0991
# Epoch 43/50
#  - 0s - loss: 111.5258
# Epoch 44/50
#  - 0s - loss: 111.8779
# Epoch 45/50
#  - 0s - loss: 112.8702
# Epoch 46/50
#  - 0s - loss: 112.1067
# Epoch 47/50
#  - 0s - loss: 109.8254
# Epoch 48/50
#  - 0s - loss: 112.1680
# Epoch 49/50
#  - 0s - loss: 109.8904
# Epoch 50/50
#  - 0s - loss: 109.8383
# Evaluate on test data
# 309/309 [==============================] - 1s 5ms/step
# test loss, test acc: 113.4026739867374
# Test set MSE for 46 cycle:113.40267487161313
# Epoch 1/50
#  - 4s - loss: 23273.5953
# Epoch 2/50
#  - 0s - loss: 7405.7902
# Epoch 3/50
#  - 0s - loss: 4529.4110
# Epoch 4/50
#  - 0s - loss: 4087.9261
# Epoch 5/50
#  - 0s - loss: 3645.0410
# Epoch 6/50
#  - 0s - loss: 3286.7830
# Epoch 7/50
#  - 0s - loss: 2943.8309
# Epoch 8/50
#  - 0s - loss: 2677.0454
# Epoch 9/50
#  - 0s - loss: 2435.3997
# Epoch 10/50
#  - 0s - loss: 2230.9018
# Epoch 11/50
#  - 0s - loss: 2037.2961
# Epoch 12/50
#  - 0s - loss: 1870.1115
# Epoch 13/50
#  - 0s - loss: 1716.7797
# Epoch 14/50
#  - 0s - loss: 1578.7401
# Epoch 15/50
#  - 0s - loss: 1454.7270
# Epoch 16/50
#  - 0s - loss: 1337.9832
# Epoch 17/50
#  - 0s - loss: 1236.0377
# Epoch 18/50
#  - 0s - loss: 1133.2651
# Epoch 19/50
#  - 0s - loss: 1046.5249
# Epoch 20/50
#  - 0s - loss: 964.3283
# Epoch 21/50
#  - 0s - loss: 891.2718
# Epoch 22/50
#  - 0s - loss: 822.2517
# Epoch 23/50
#  - 0s - loss: 761.4096
# Epoch 24/50
#  - 0s - loss: 705.0990
# Epoch 25/50
#  - 0s - loss: 652.2922
# Epoch 26/50
#  - 0s - loss: 605.9370
# Epoch 27/50
#  - 0s - loss: 563.8847
# Epoch 28/50
#  - 0s - loss: 524.3445
# Epoch 29/50
#  - 0s - loss: 490.3818
# Epoch 30/50
#  - 0s - loss: 458.2457
# Epoch 31/50
#  - 0s - loss: 433.1584
# Epoch 32/50
#  - 0s - loss: 407.3074
# Epoch 33/50
#  - 0s - loss: 384.6493
# Epoch 34/50
#  - 0s - loss: 365.7174
# Epoch 35/50
#  - 0s - loss: 348.9153
# Epoch 36/50
#  - 0s - loss: 332.5389
# Epoch 37/50
#  - 0s - loss: 319.6021
# Epoch 38/50
#  - 0s - loss: 306.5153
# Epoch 39/50
#  - 0s - loss: 294.9404
# Epoch 40/50
#  - 0s - loss: 284.3847
# Epoch 41/50
#  - 0s - loss: 276.9393
# Epoch 42/50
#  - 0s - loss: 267.9256
# Epoch 43/50
#  - 0s - loss: 258.6963
# Epoch 44/50
#  - 0s - loss: 251.6770
# Epoch 45/50
#  - 0s - loss: 245.1273
# Epoch 46/50
#  - 0s - loss: 239.4977
# Epoch 47/50
#  - 0s - loss: 234.2394
# Epoch 48/50
#  - 0s - loss: 229.7871
# Epoch 49/50
#  - 0s - loss: 226.0298
# Epoch 50/50
#  - 0s - loss: 220.0045
# Evaluate on test data
# 309/309 [==============================] - 2s 5ms/step
# test loss, test acc: 238.8108026202057
# Test set MSE for 47 cycle:238.81080125641185
# Epoch 1/50
#  - 4s - loss: 5610.9702
# Epoch 2/50
#  - 0s - loss: 1920.5678
# Epoch 3/50
#  - 0s - loss: 1205.4552
# Epoch 4/50
#  - 0s - loss: 939.0746
# Epoch 5/50
#  - 0s - loss: 746.1911
# Epoch 6/50
#  - 0s - loss: 606.2898
# Epoch 7/50
#  - 0s - loss: 519.6920
# Epoch 8/50
#  - 0s - loss: 460.5892
# Epoch 9/50
#  - 0s - loss: 413.9065
# Epoch 10/50
#  - 0s - loss: 378.1919
# Epoch 11/50
#  - 0s - loss: 352.1714
# Epoch 12/50
#  - 0s - loss: 321.2096
# Epoch 13/50
#  - 0s - loss: 299.5179
# Epoch 14/50
#  - 1s - loss: 277.9915
# Epoch 15/50
#  - 0s - loss: 260.0219
# Epoch 16/50
#  - 0s - loss: 241.2895
# Epoch 17/50
#  - 0s - loss: 226.9104
# Epoch 18/50
#  - 0s - loss: 213.9393
# Epoch 19/50
#  - 0s - loss: 199.1452
# Epoch 20/50
#  - 0s - loss: 187.6893
# Epoch 21/50
#  - 0s - loss: 176.3380
# Epoch 22/50
#  - 0s - loss: 168.3051
# Epoch 23/50
#  - 0s - loss: 159.1955
# Epoch 24/50
#  - 0s - loss: 151.9008
# Epoch 25/50
#  - 0s - loss: 148.1043
# Epoch 26/50
#  - 0s - loss: 141.3287
# Epoch 27/50
#  - 0s - loss: 138.7641
# Epoch 28/50
#  - 0s - loss: 132.2407
# Epoch 29/50
#  - 0s - loss: 130.4256
# Epoch 30/50
#  - 0s - loss: 126.7755
# Epoch 31/50
#  - 0s - loss: 124.1962
# Epoch 32/50
#  - 0s - loss: 121.7771
# Epoch 33/50
#  - 0s - loss: 118.8826
# Epoch 34/50
#  - 0s - loss: 116.1366
# Epoch 35/50
#  - 0s - loss: 113.8694
# Epoch 36/50
#  - 0s - loss: 111.0560
# Epoch 37/50
#  - 0s - loss: 108.6624
# Epoch 38/50
#  - 0s - loss: 106.9068
# Epoch 39/50
#  - 0s - loss: 105.6177
# Epoch 40/50
#  - 0s - loss: 106.6315
# Epoch 41/50
#  - 0s - loss: 102.9047
# Epoch 42/50
#  - 0s - loss: 101.8975
# Epoch 43/50
#  - 0s - loss: 101.3674
# Epoch 44/50
#  - 0s - loss: 99.6771
# Epoch 45/50
#  - 0s - loss: 100.2107
# Epoch 46/50
#  - 0s - loss: 97.7777
# Epoch 47/50
#  - 0s - loss: 95.9940
# Epoch 48/50
#  - 0s - loss: 95.5931
# Epoch 49/50
#  - 0s - loss: 95.0789
# Epoch 50/50
#  - 0s - loss: 93.0173
# Evaluate on test data
# 309/309 [==============================] - 2s 5ms/step
# test loss, test acc: 109.36034731571728
# Test set MSE for 48 cycle:109.36035193808974
# Epoch 1/50
#  - 4s - loss: 37674.1277
# Epoch 2/50
#  - 0s - loss: 13707.4659
# Epoch 3/50
#  - 0s - loss: 4340.6242
# Epoch 4/50
#  - 0s - loss: 1447.9519
# Epoch 5/50
#  - 0s - loss: 729.2462
# Epoch 6/50
#  - 0s - loss: 585.3489
# Epoch 7/50
#  - 0s - loss: 549.0389
# Epoch 8/50
#  - 0s - loss: 528.5089
# Epoch 9/50
#  - 0s - loss: 506.9167
# Epoch 10/50
#  - 0s - loss: 488.2818
# Epoch 11/50
#  - 0s - loss: 469.8810
# Epoch 12/50
#  - 0s - loss: 453.1828
# Epoch 13/50
#  - 0s - loss: 437.2404
# Epoch 14/50
#  - 0s - loss: 423.0043
# Epoch 15/50
#  - 0s - loss: 408.0199
# Epoch 16/50
#  - 0s - loss: 394.2504
# Epoch 17/50
#  - 0s - loss: 381.4044
# Epoch 18/50
#  - 0s - loss: 369.1201
# Epoch 19/50
#  - 0s - loss: 358.0139
# Epoch 20/50
#  - 0s - loss: 346.3525
# Epoch 21/50
#  - 0s - loss: 336.1545
# Epoch 22/50
#  - 0s - loss: 326.4419
# Epoch 23/50
#  - 0s - loss: 316.9573
# Epoch 24/50
#  - 0s - loss: 308.1818
# Epoch 25/50
#  - 0s - loss: 300.0053
# Epoch 26/50
#  - 0s - loss: 292.6450
# Epoch 27/50
#  - 0s - loss: 285.7837
# Epoch 28/50
#  - 0s - loss: 278.3811
# Epoch 29/50
#  - 0s - loss: 272.7991
# Epoch 30/50
#  - 0s - loss: 265.9474
# Epoch 31/50
#  - 0s - loss: 261.1579
# Epoch 32/50
#  - 0s - loss: 255.0523
# Epoch 33/50
#  - 0s - loss: 250.0945
# Epoch 34/50
#  - 0s - loss: 245.2922
# Epoch 35/50
#  - 0s - loss: 240.5121
# Epoch 36/50
#  - 0s - loss: 236.0242
# Epoch 37/50
#  - 0s - loss: 231.7777
# Epoch 38/50
#  - 0s - loss: 227.6594
# Epoch 39/50
#  - 0s - loss: 223.8058
# Epoch 40/50
#  - 0s - loss: 219.7967
# Epoch 41/50
#  - 0s - loss: 215.9305
# Epoch 42/50
#  - 0s - loss: 212.3418
# Epoch 43/50
#  - 0s - loss: 208.8617
# Epoch 44/50
#  - 0s - loss: 205.6722
# Epoch 45/50
#  - 0s - loss: 202.4983
# Epoch 46/50
#  - 0s - loss: 199.1836
# Epoch 47/50
#  - 0s - loss: 196.1022
# Epoch 48/50
#  - 0s - loss: 193.5148
# Epoch 49/50
#  - 0s - loss: 190.3826
# Epoch 50/50
#  - 0s - loss: 188.3403
# Evaluate on test data
# 309/309 [==============================] - 2s 5ms/step
# test loss, test acc: 181.50724313482883
# Test set MSE for 49 cycle:181.50724876360212
# Epoch 1/50
#  - 4s - loss: 8162.0896
# Epoch 2/50
#  - 0s - loss: 973.0038
# Epoch 3/50
#  - 0s - loss: 714.5726
# Epoch 4/50
#  - 0s - loss: 572.4621
# Epoch 5/50
#  - 0s - loss: 507.4821
# Epoch 6/50
#  - 0s - loss: 475.4591
# Epoch 7/50
#  - 0s - loss: 456.1458
# Epoch 8/50
#  - 0s - loss: 436.2076
# Epoch 9/50
#  - 0s - loss: 415.6088
# Epoch 10/50
#  - 0s - loss: 397.5481
# Epoch 11/50
#  - 0s - loss: 377.0697
# Epoch 12/50
#  - 0s - loss: 362.6036
# Epoch 13/50
#  - 0s - loss: 344.2085
# Epoch 14/50
#  - 0s - loss: 328.1276
# Epoch 15/50
#  - 0s - loss: 311.6982
# Epoch 16/50
#  - 0s - loss: 293.1757
# Epoch 17/50
#  - 0s - loss: 276.9154
# Epoch 18/50
#  - 0s - loss: 262.9969
# Epoch 19/50
#  - 0s - loss: 252.9280
# Epoch 20/50
#  - 0s - loss: 240.0362
# Epoch 21/50
#  - 0s - loss: 228.4991
# Epoch 22/50
#  - 0s - loss: 220.3442
# Epoch 23/50
#  - 0s - loss: 210.2559
# Epoch 24/50
#  - 0s - loss: 203.0476
# Epoch 25/50
#  - 0s - loss: 193.4725
# Epoch 26/50
#  - 0s - loss: 186.2127
# Epoch 27/50
#  - 0s - loss: 179.4037
# Epoch 28/50
#  - 0s - loss: 171.0739
# Epoch 29/50
#  - 0s - loss: 166.0671
# Epoch 30/50
#  - 0s - loss: 158.8546
# Epoch 31/50
#  - 0s - loss: 152.6823
# Epoch 32/50
#  - 0s - loss: 147.4565
# Epoch 33/50
#  - 0s - loss: 142.9209
# Epoch 34/50
#  - 0s - loss: 137.3804
# Epoch 35/50
#  - 0s - loss: 133.9065
# Epoch 36/50
#  - 0s - loss: 130.5876
# Epoch 37/50
#  - 0s - loss: 127.9240
# Epoch 38/50
#  - 0s - loss: 124.6300
# Epoch 39/50
#  - 0s - loss: 124.0852
# Epoch 40/50
#  - 0s - loss: 121.4655
# Epoch 41/50
#  - 0s - loss: 119.9948
# Epoch 42/50
#  - 0s - loss: 117.2094
# Epoch 43/50
#  - 0s - loss: 116.5542
# Epoch 44/50
#  - 0s - loss: 112.4306
# Epoch 45/50
#  - 0s - loss: 111.9985
# Epoch 46/50
#  - 0s - loss: 110.1903
# Epoch 47/50
#  - 0s - loss: 109.8289
# Epoch 48/50
#  - 0s - loss: 108.3047
# Epoch 49/50
#  - 0s - loss: 107.2465
# Epoch 50/50
#  - 0s - loss: 104.8975
# Evaluate on test data
# 309/309 [==============================] - 2s 5ms/step
# test loss, test acc: 96.43928500672375
# Test set MSE for 50 cycle:96.43928508104044

# %% [markdown]
# **Let's get the mean and the standard deviation of the mean sqaured errors from previous cycle**

# %%
mean_MSE = MSE[i].mean() #creating a variable reporting the mean value for the mean squared errors
std_MSE = MSE[i].std() #creating a variable reporting the standard value for the mean squared errors

# %%
print("The mean of the mean squared errors is {}, and the standard deviation for the mean squared value is {}".format(mean_MSE, std_MSE))
# Out:
# The mean of the mean squared errors is 96.43928508104044, and the standard deviation for the mean squared value is 0.0
