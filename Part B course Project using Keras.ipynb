# %% [markdown]
# <h1>Part B<h1>

# %% [markdown]
# Creating the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error as the loss function.
#
# A. Build a baseline model (5 marks)
#
# Using the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Using the adam optimizer and the mean squared error as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_splithelper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.

# %% [markdown]
# <h1>Normalized version of the data <h1>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing Concrete data for evaluation

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')#importing the data using pandas
concrete_data.head() #Checking the first five items from the dataset
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# The data must be splited between the independent variable and dependent variable, that will be *(cement, blast furnance, fly slag,
# water, superplasticizer, coarse aggregate, fine aggregate, and age)* and the dependent variable that will be *(Strenght)*

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# **Let's normalize the data of the predictors which is by subtracting the mean from the individual predictors and dividing by the standard deviation.**

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# We have to get the number of columns of the **predictors** variable that was **normalized** as the number of inputs to the deep learning model

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# **Then we have to import keras library and as per video lesson, the model have two classes.**

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense

# %%
# define classification model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# <h3> Now we have to randomly split a data into training data and 30% of the data randomly chosen as test data using
#     Scikit-learn.<h3> <h3> Therefore we have to import sklearn library to select train_test_split  <h3>
#     <h2> Evaluating the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. Using the mean_squared_error function from Scikit-learn <h3>

# %% [markdown]
# **First let's import the mean_sqaure_error function from the scikit_learn library, Evaluating the model on the test data using "evaluate"**

# %%
from sklearn.model_selection import train_test_split #importing the sklearn library for train_test_split
from sklearn.metrics import mean_squared_error#importing the mean_sqaure_error function from the sklearn library

# %%
MSE=np.zeros(50)
for i in range(50):
    X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size=0.3, random_state=42) #test size is set to 30%
    model=regression_model() #Call the function to create a model
    model.fit(X_train, y_train, epochs=50, verbose=2) #we then need to fit the x-train data along with y_train data and  fit it on a model
    print("Evaluate on test data")
    results=model.evaluate(X_test, y_test)
    print("test loss, test acc:", results) 
    target_predicted= model.predict(X_test)
    MSE[i]=mean_squared_error(y_test, target_predicted)
    print("Test set MSE for {} cycle:{}".format(i+1,MSE[i]))
# Out:
# Epoch 1/50
#  - 4s - loss: 1571.8768
# Epoch 2/50
#  - 0s - loss: 1556.4683
# Epoch 3/50
#  - 0s - loss: 1540.9802
# Epoch 4/50
#  - 0s - loss: 1525.0321
# Epoch 5/50
#  - 0s - loss: 1508.5537
# Epoch 6/50
#  - 0s - loss: 1490.9438
# Epoch 7/50
#  - 0s - loss: 1472.4403
# Epoch 8/50
#  - 0s - loss: 1452.9286
# Epoch 9/50
#  - 0s - loss: 1432.5274
# Epoch 10/50
#  - 0s - loss: 1410.9453
# Epoch 11/50
#  - 0s - loss: 1388.0862
# Epoch 12/50
#  - 0s - loss: 1364.2157
# Epoch 13/50
#  - 0s - loss: 1339.0086
# Epoch 14/50
#  - 0s - loss: 1311.9340
# Epoch 15/50
#  - 0s - loss: 1284.0311
# Epoch 16/50
#  - 0s - loss: 1254.5759
# Epoch 17/50
#  - 0s - loss: 1224.5828
# Epoch 18/50
#  - 0s - loss: 1192.3318
# Epoch 19/50
#  - 0s - loss: 1160.2885
# Epoch 20/50
#  - 0s - loss: 1126.5064
# Epoch 21/50
#  - 0s - loss: 1092.8239
# Epoch 22/50
#  - 0s - loss: 1058.0226
# Epoch 23/50
#  - 0s - loss: 1022.6842
# Epoch 24/50
#  - 0s - loss: 987.1246
# Epoch 25/50
#  - 0s - loss: 951.6738
# Epoch 26/50
#  - 0s - loss: 916.3862
# Epoch 27/50
#  - 0s - loss: 881.0615
# Epoch 28/50
#  - 0s - loss: 847.0015
# Epoch 29/50
#  - 0s - loss: 812.1876
# Epoch 30/50
#  - 0s - loss: 778.7411
# Epoch 31/50
#  - 0s - loss: 745.7991
# Epoch 32/50
#  - 0s - loss: 713.7755
# Epoch 33/50
#  - 0s - loss: 682.6784
# Epoch 34/50
#  - 0s - loss: 652.2469
# Epoch 35/50
#  - 0s - loss: 623.1357
# Epoch 36/50
#  - 0s - loss: 595.1777
# Epoch 37/50
#  - 0s - loss: 568.1349
# Epoch 38/50
#  - 0s - loss: 542.8766
# Epoch 39/50
#  - 0s - loss: 518.3139
# Epoch 40/50
#  - 0s - loss: 494.8706
# Epoch 41/50
#  - 0s - loss: 473.2558
# Epoch 42/50
#  - 0s - loss: 452.1116
# Epoch 43/50
#  - 0s - loss: 432.4599
# Epoch 44/50
#  - 0s - loss: 414.3892
# Epoch 45/50
#  - 0s - loss: 397.2631
# Epoch 46/50
#  - 0s - loss: 381.0775
# Epoch 47/50
#  - 0s - loss: 366.2842
# Epoch 48/50
#  - 0s - loss: 352.3353
# Epoch 49/50
#  - 0s - loss: 339.3366
# Epoch 50/50
#  - 0s - loss: 327.2905
# Evaluate on test data
# 309/309 [==============================] - 2s 5ms/step
# test loss, test acc: 319.34545908313737
# Test set MSE for 1 cycle:319.34546738365276
# Epoch 1/50
#  - 4s - loss: 1609.5926
# Epoch 2/50
#  - 0s - loss: 1589.0059
# Epoch 3/50
#  - 0s - loss: 1568.9318
# Epoch 4/50
#  - 0s - loss: 1549.4240
# Epoch 5/50
#  - 0s - loss: 1529.6698
# Epoch 6/50
#  - 0s - loss: 1510.2225
# Epoch 7/50
#  - 0s - loss: 1490.1617
# Epoch 8/50
#  - 0s - loss: 1469.9373
# Epoch 9/50
#  - 0s - loss: 1449.2312
# Epoch 10/50
#  - 0s - loss: 1428.2455
# Epoch 11/50
#  - 0s - loss: 1406.6021
# Epoch 12/50
#  - 0s - loss: 1384.7722
# Epoch 13/50
#  - 0s - loss: 1361.7328
# Epoch 14/50
#  - 0s - loss: 1338.7173
# Epoch 15/50
#  - 0s - loss: 1315.0400
# Epoch 16/50
#  - 0s - loss: 1290.6245
# Epoch 17/50
#  - 0s - loss: 1265.6869
# Epoch 18/50
#  - 0s - loss: 1240.4943
# Epoch 19/50
#  - 0s - loss: 1214.6618
# Epoch 20/50
#  - 0s - loss: 1188.6649
# Epoch 21/50
#  - 0s - loss: 1161.6695
# Epoch 22/50
#  - 0s - loss: 1134.9408
# Epoch 23/50
#  - 0s - loss: 1107.7667
# Epoch 24/50
#  - 0s - loss: 1079.6974
# Epoch 25/50
#  - 0s - loss: 1051.9346
# Epoch 26/50
#  - 0s - loss: 1024.1253
# Epoch 27/50
#  - 0s - loss: 995.9623
# Epoch 28/50
#  - 0s - loss: 967.8260
# Epoch 29/50
#  - 0s - loss: 939.8347
# Epoch 30/50
#  - 0s - loss: 912.0297
# Epoch 31/50
#  - 0s - loss: 884.2497
# Epoch 32/50
#  - 0s - loss: 856.7340
# Epoch 33/50
#  - 0s - loss: 829.2243
# Epoch 34/50
#  - 0s - loss: 802.4394
# Epoch 35/50
#  - 0s - loss: 775.4913
# Epoch 36/50
#  - 0s - loss: 749.5854
# Epoch 37/50
#  - 0s - loss: 723.8046
# Epoch 38/50
#  - 0s - loss: 698.6202
# Epoch 39/50
#  - 0s - loss: 674.1068
# Epoch 40/50
#  - 0s - loss: 650.2382
# Epoch 41/50
#  - 0s - loss: 626.8938
# Epoch 42/50
#  - 0s - loss: 604.4849
# Epoch 43/50
#  - 0s - loss: 582.6501
# Epoch 44/50
#  - 0s - loss: 561.6204
# Epoch 45/50
#  - 0s - loss: 541.3094
# Epoch 46/50
#  - 0s - loss: 521.6788
# Epoch 47/50
#  - 0s - loss: 503.0298
# Epoch 48/50
#  - 0s - loss: 485.0618
# Epoch 49/50
#  - 0s - loss: 467.8066
# Epoch 50/50
#  - 0s - loss: 451.5607
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 435.82923706449736
# Test set MSE for 2 cycle:435.8292286345591
# Epoch 1/50
#  - 4s - loss: 1669.6088
# Epoch 2/50
#  - 0s - loss: 1652.1215
# Epoch 3/50
#  - 0s - loss: 1635.5726
# Epoch 4/50
#  - 0s - loss: 1619.8232
# Epoch 5/50
#  - 0s - loss: 1604.1448
# Epoch 6/50
#  - 0s - loss: 1588.7698
# Epoch 7/50
#  - 0s - loss: 1572.9091
# Epoch 8/50
#  - 0s - loss: 1556.8643
# Epoch 9/50
#  - 0s - loss: 1540.0795
# Epoch 10/50
#  - 0s - loss: 1522.9473
# Epoch 11/50
#  - 0s - loss: 1505.1324
# Epoch 12/50
#  - 0s - loss: 1486.5891
# Epoch 13/50
#  - 0s - loss: 1467.4374
# Epoch 14/50
#  - 0s - loss: 1447.8903
# Epoch 15/50
#  - 0s - loss: 1427.6216
# Epoch 16/50
#  - 0s - loss: 1406.0514
# Epoch 17/50
#  - 0s - loss: 1384.3486
# Epoch 18/50
#  - 0s - loss: 1361.3337
# Epoch 19/50
#  - 0s - loss: 1337.7982
# Epoch 20/50
#  - 0s - loss: 1313.8022
# Epoch 21/50
#  - 0s - loss: 1288.9001
# Epoch 22/50
#  - 0s - loss: 1263.3421
# Epoch 23/50
#  - 0s - loss: 1237.5904
# Epoch 24/50
#  - 0s - loss: 1210.9436
# Epoch 25/50
#  - 0s - loss: 1184.2493
# Epoch 26/50
#  - 0s - loss: 1156.0900
# Epoch 27/50
#  - 0s - loss: 1128.4561
# Epoch 28/50
#  - 0s - loss: 1099.8565
# Epoch 29/50
#  - 0s - loss: 1071.1302
# Epoch 30/50
#  - 0s - loss: 1042.4463
# Epoch 31/50
#  - 0s - loss: 1012.8800
# Epoch 32/50
#  - 0s - loss: 983.0327
# Epoch 33/50
#  - 0s - loss: 953.0942
# Epoch 34/50
#  - 0s - loss: 922.7184
# Epoch 35/50
#  - 0s - loss: 891.9655
# Epoch 36/50
#  - 0s - loss: 861.3554
# Epoch 37/50
#  - 0s - loss: 830.4369
# Epoch 38/50
#  - 0s - loss: 799.2845
# Epoch 39/50
#  - 0s - loss: 768.6667
# Epoch 40/50
#  - 0s - loss: 737.9169
# Epoch 41/50
#  - 0s - loss: 707.2754
# Epoch 42/50
#  - 0s - loss: 677.4554
# Epoch 43/50
#  - 0s - loss: 648.3877
# Epoch 44/50
#  - 0s - loss: 619.7092
# Epoch 45/50
#  - 0s - loss: 591.7720
# Epoch 46/50
#  - 0s - loss: 565.1362
# Epoch 47/50
#  - 0s - loss: 538.9127
# Epoch 48/50
#  - 0s - loss: 514.1752
# Epoch 49/50
#  - 0s - loss: 490.2282
# Epoch 50/50
#  - 0s - loss: 467.5480
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 441.0036470974919
# Test set MSE for 3 cycle:441.0036440191504
# Epoch 1/50
#  - 4s - loss: 1556.6828
# Epoch 2/50
#  - 0s - loss: 1542.3373
# Epoch 3/50
#  - 0s - loss: 1526.8907
# Epoch 4/50
#  - 0s - loss: 1510.5475
# Epoch 5/50
#  - 0s - loss: 1492.7359
# Epoch 6/50
#  - 0s - loss: 1473.4038
# Epoch 7/50
#  - 0s - loss: 1452.2253
# Epoch 8/50
#  - 0s - loss: 1429.4327
# Epoch 9/50
#  - 0s - loss: 1404.4131
# Epoch 10/50
#  - 0s - loss: 1377.8003
# Epoch 11/50
#  - 0s - loss: 1349.2538
# Epoch 12/50
#  - 1s - loss: 1319.1607
# Epoch 13/50
#  - 0s - loss: 1287.7731
# Epoch 14/50
#  - 0s - loss: 1254.2657
# Epoch 15/50
#  - 0s - loss: 1220.0585
# Epoch 16/50
#  - 0s - loss: 1184.4720
# Epoch 17/50
#  - 0s - loss: 1148.1182
# Epoch 18/50
#  - 0s - loss: 1110.8316
# Epoch 19/50
#  - 0s - loss: 1072.9325
# Epoch 20/50
#  - 0s - loss: 1034.1205
# Epoch 21/50
#  - 0s - loss: 995.6676
# Epoch 22/50
#  - 0s - loss: 956.9294
# Epoch 23/50
#  - 0s - loss: 918.3490
# Epoch 24/50
#  - 0s - loss: 879.9486
# Epoch 25/50
#  - 0s - loss: 842.5224
# Epoch 26/50
#  - 0s - loss: 805.8828
# Epoch 27/50
#  - 0s - loss: 769.6095
# Epoch 28/50
#  - 0s - loss: 734.3167
# Epoch 29/50
#  - 0s - loss: 700.7617
# Epoch 30/50
#  - 0s - loss: 667.4508
# Epoch 31/50
#  - 0s - loss: 635.6294
# Epoch 32/50
#  - 0s - loss: 605.7530
# Epoch 33/50
#  - 0s - loss: 577.0241
# Epoch 34/50
#  - 0s - loss: 549.7290
# Epoch 35/50
#  - 0s - loss: 523.4995
# Epoch 36/50
#  - 0s - loss: 499.2681
# Epoch 37/50
#  - 0s - loss: 475.5969
# Epoch 38/50
#  - 0s - loss: 453.6717
# Epoch 39/50
#  - 0s - loss: 433.1533
# Epoch 40/50
#  - 0s - loss: 413.9569
# Epoch 41/50
#  - 0s - loss: 395.9081
# Epoch 42/50
#  - 0s - loss: 379.1150
# Epoch 43/50
#  - 0s - loss: 363.3576
# Epoch 44/50
#  - 0s - loss: 348.9860
# Epoch 45/50
#  - 0s - loss: 335.2998
# Epoch 46/50
#  - 0s - loss: 322.9583
# Epoch 47/50
#  - 0s - loss: 311.2191
# Epoch 48/50
#  - 0s - loss: 300.5749
# Epoch 49/50
#  - 0s - loss: 290.4013
# Epoch 50/50
#  - 0s - loss: 281.1531
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 276.72978753642354
# Test set MSE for 4 cycle:276.7297861654738
# Epoch 1/50
#  - 4s - loss: 1557.1906
# Epoch 2/50
#  - 1s - loss: 1544.7835
# Epoch 3/50
#  - 0s - loss: 1531.5764
# Epoch 4/50
#  - 0s - loss: 1517.3407
# Epoch 5/50
#  - 0s - loss: 1501.7775
# Epoch 6/50
#  - 0s - loss: 1484.9119
# Epoch 7/50
#  - 0s - loss: 1466.8548
# Epoch 8/50
#  - 0s - loss: 1447.1866
# Epoch 9/50
#  - 0s - loss: 1425.7811
# Epoch 10/50
#  - 0s - loss: 1402.9607
# Epoch 11/50
#  - 0s - loss: 1378.4312
# Epoch 12/50
#  - 0s - loss: 1351.9439
# Epoch 13/50
#  - 0s - loss: 1324.0220
# Epoch 14/50
#  - 0s - loss: 1294.1505
# Epoch 15/50
#  - 0s - loss: 1262.8343
# Epoch 16/50
#  - 0s - loss: 1229.7533
# Epoch 17/50
#  - 0s - loss: 1194.9718
# Epoch 18/50
#  - 0s - loss: 1159.3260
# Epoch 19/50
#  - 0s - loss: 1121.7229
# Epoch 20/50
#  - 0s - loss: 1083.4937
# Epoch 21/50
#  - 0s - loss: 1043.9503
# Epoch 22/50
#  - 0s - loss: 1004.3811
# Epoch 23/50
#  - 0s - loss: 963.9445
# Epoch 24/50
#  - 0s - loss: 922.8756
# Epoch 25/50
#  - 0s - loss: 882.7709
# Epoch 26/50
#  - 0s - loss: 842.6474
# Epoch 27/50
#  - 0s - loss: 802.9492
# Epoch 28/50
#  - 0s - loss: 764.4640
# Epoch 29/50
#  - 0s - loss: 726.3377
# Epoch 30/50
#  - 0s - loss: 689.5104
# Epoch 31/50
#  - 0s - loss: 653.5932
# Epoch 32/50
#  - 0s - loss: 619.7641
# Epoch 33/50
#  - 0s - loss: 587.5766
# Epoch 34/50
#  - 0s - loss: 555.9467
# Epoch 35/50
#  - 0s - loss: 526.9631
# Epoch 36/50
#  - 0s - loss: 499.5076
# Epoch 37/50
#  - 0s - loss: 474.0686
# Epoch 38/50
#  - 0s - loss: 449.6469
# Epoch 39/50
#  - 0s - loss: 427.4912
# Epoch 40/50
#  - 0s - loss: 406.5509
# Epoch 41/50
#  - 0s - loss: 387.4769
# Epoch 42/50
#  - 0s - loss: 369.8001
# Epoch 43/50
#  - 0s - loss: 353.4621
# Epoch 44/50
#  - 0s - loss: 338.5675
# Epoch 45/50
#  - 0s - loss: 325.0923
# Epoch 46/50
#  - 0s - loss: 312.6578
# Epoch 47/50
#  - 0s - loss: 301.5023
# Epoch 48/50
#  - 0s - loss: 291.2681
# Epoch 49/50
#  - 0s - loss: 281.8934
# Epoch 50/50
#  - 0s - loss: 273.6954
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 266.7350628306565
# Test set MSE for 5 cycle:266.73505971641777
# Epoch 1/50
#  - 6s - loss: 1546.2332
# Epoch 2/50
#  - 0s - loss: 1528.1811
# Epoch 3/50
#  - 0s - loss: 1509.3904
# Epoch 4/50
#  - 0s - loss: 1489.8251
# Epoch 5/50
#  - 0s - loss: 1468.6598
# Epoch 6/50
#  - 0s - loss: 1446.5684
# Epoch 7/50
#  - 0s - loss: 1423.4274
# Epoch 8/50
#  - 0s - loss: 1398.6625
# Epoch 9/50
#  - 0s - loss: 1372.3648
# Epoch 10/50
#  - 0s - loss: 1345.2435
# Epoch 11/50
#  - 0s - loss: 1316.5688
# Epoch 12/50
#  - 0s - loss: 1287.0797
# Epoch 13/50
#  - 0s - loss: 1256.0657
# Epoch 14/50
#  - 0s - loss: 1224.4175
# Epoch 15/50
#  - 0s - loss: 1192.2870
# Epoch 16/50
#  - 0s - loss: 1159.2749
# Epoch 17/50
#  - 0s - loss: 1125.6417
# Epoch 18/50
#  - 0s - loss: 1091.4476
# Epoch 19/50
#  - 0s - loss: 1057.1608
# Epoch 20/50
#  - 0s - loss: 1022.4291
# Epoch 21/50
#  - 0s - loss: 987.3768
# Epoch 22/50
#  - 0s - loss: 952.7399
# Epoch 23/50
#  - 0s - loss: 918.4378
# Epoch 24/50
#  - 0s - loss: 883.5706
# Epoch 25/50
#  - 0s - loss: 849.8032
# Epoch 26/50
#  - 0s - loss: 816.4976
# Epoch 27/50
#  - 0s - loss: 783.5160
# Epoch 28/50
#  - 0s - loss: 752.4304
# Epoch 29/50
#  - 0s - loss: 720.6710
# Epoch 30/50
#  - 0s - loss: 690.4317
# Epoch 31/50
#  - 0s - loss: 661.3608
# Epoch 32/50
#  - 0s - loss: 632.9534
# Epoch 33/50
#  - 0s - loss: 605.6817
# Epoch 34/50
#  - 0s - loss: 579.6150
# Epoch 35/50
#  - 0s - loss: 554.7693
# Epoch 36/50
#  - 0s - loss: 530.8273
# Epoch 37/50
#  - 0s - loss: 508.2928
# Epoch 38/50
#  - 0s - loss: 486.2903
# Epoch 39/50
#  - 0s - loss: 465.9362
# Epoch 40/50
#  - 0s - loss: 445.5261
# Epoch 41/50
#  - 0s - loss: 427.2253
# Epoch 42/50
#  - 0s - loss: 409.3350
# Epoch 43/50
#  - 0s - loss: 393.0647
# Epoch 44/50
#  - 0s - loss: 377.3656
# Epoch 45/50
#  - 0s - loss: 362.7251
# Epoch 46/50
#  - 0s - loss: 349.0274
# Epoch 47/50
#  - 0s - loss: 336.1839
# Epoch 48/50
#  - 0s - loss: 324.2287
# Epoch 49/50
#  - 0s - loss: 312.8163
# Epoch 50/50
#  - 0s - loss: 302.1735
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 274.3511330811337
# Test set MSE for 6 cycle:274.35113204068875
# Epoch 1/50
#  - 4s - loss: 1647.1254
# Epoch 2/50
#  - 0s - loss: 1632.4565
# Epoch 3/50
#  - 0s - loss: 1618.5038
# Epoch 4/50
#  - 0s - loss: 1605.2615
# Epoch 5/50
#  - 0s - loss: 1592.4058
# Epoch 6/50
#  - 0s - loss: 1579.8229
# Epoch 7/50
#  - 0s - loss: 1567.2296
# Epoch 8/50
#  - 0s - loss: 1554.7073
# Epoch 9/50
#  - 0s - loss: 1542.1078
# Epoch 10/50
#  - 0s - loss: 1529.2591
# Epoch 11/50
#  - 0s - loss: 1516.1217
# Epoch 12/50
#  - 0s - loss: 1502.6207
# Epoch 13/50
#  - 0s - loss: 1488.7612
# Epoch 14/50
#  - 0s - loss: 1474.4104
# Epoch 15/50
#  - 0s - loss: 1459.3247
# Epoch 16/50
#  - 0s - loss: 1443.7229
# Epoch 17/50
#  - 0s - loss: 1427.3352
# Epoch 18/50
#  - 0s - loss: 1410.0503
# Epoch 19/50
#  - 0s - loss: 1391.8142
# Epoch 20/50
#  - 0s - loss: 1372.5230
# Epoch 21/50
#  - 0s - loss: 1352.0516
# Epoch 22/50
#  - 0s - loss: 1330.6032
# Epoch 23/50
#  - 0s - loss: 1308.0887
# Epoch 24/50
#  - 0s - loss: 1284.6595
# Epoch 25/50
#  - 0s - loss: 1260.5111
# Epoch 26/50
#  - 0s - loss: 1235.6238
# Epoch 27/50
#  - 0s - loss: 1209.5992
# Epoch 28/50
#  - 0s - loss: 1182.9512
# Epoch 29/50
#  - 0s - loss: 1155.9092
# Epoch 30/50
#  - 0s - loss: 1127.9048
# Epoch 31/50
#  - 0s - loss: 1099.6194
# Epoch 32/50
#  - 0s - loss: 1070.8104
# Epoch 33/50
#  - 0s - loss: 1041.5309
# Epoch 34/50
#  - 0s - loss: 1011.4502
# Epoch 35/50
#  - 0s - loss: 981.5310
# Epoch 36/50
#  - 0s - loss: 951.1089
# Epoch 37/50
#  - 0s - loss: 920.8193
# Epoch 38/50
#  - 0s - loss: 890.6465
# Epoch 39/50
#  - 0s - loss: 860.0613
# Epoch 40/50
#  - 0s - loss: 830.2395
# Epoch 41/50
#  - 0s - loss: 800.3105
# Epoch 42/50
#  - 0s - loss: 771.0714
# Epoch 43/50
#  - 0s - loss: 742.0146
# Epoch 44/50
#  - 0s - loss: 713.8568
# Epoch 45/50
#  - 0s - loss: 685.6194
# Epoch 46/50
#  - 0s - loss: 658.3742
# Epoch 47/50
#  - 0s - loss: 631.2619
# Epoch 48/50
#  - 0s - loss: 605.4235
# Epoch 49/50
#  - 0s - loss: 580.1071
# Epoch 50/50
#  - 0s - loss: 555.8824
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 497.36511981062904
# Test set MSE for 7 cycle:497.36512186832357
# Epoch 1/50
#  - 5s - loss: 1574.1972
# Epoch 2/50
#  - 0s - loss: 1556.7721
# Epoch 3/50
#  - 0s - loss: 1539.8850
# Epoch 4/50
#  - 0s - loss: 1523.1067
# Epoch 5/50
#  - 0s - loss: 1506.4982
# Epoch 6/50
#  - 0s - loss: 1489.9630
# Epoch 7/50
#  - 0s - loss: 1473.1180
# Epoch 8/50
#  - 0s - loss: 1456.4018
# Epoch 9/50
#  - 0s - loss: 1438.9325
# Epoch 10/50
#  - 0s - loss: 1420.8961
# Epoch 11/50
#  - 0s - loss: 1402.3056
# Epoch 12/50
#  - 0s - loss: 1382.8849
# Epoch 13/50
#  - 0s - loss: 1362.5075
# Epoch 14/50
#  - 0s - loss: 1341.0861
# Epoch 15/50
#  - 0s - loss: 1318.4885
# Epoch 16/50
#  - 0s - loss: 1294.6153
# Epoch 17/50
#  - 0s - loss: 1269.8994
# Epoch 18/50
#  - 0s - loss: 1243.7615
# Epoch 19/50
#  - 0s - loss: 1216.4506
# Epoch 20/50
#  - 0s - loss: 1188.2200
# Epoch 21/50
#  - 0s - loss: 1158.9910
# Epoch 22/50
#  - 0s - loss: 1128.5085
# Epoch 23/50
#  - 0s - loss: 1097.1020
# Epoch 24/50
#  - 0s - loss: 1064.5719
# Epoch 25/50
#  - 0s - loss: 1031.1671
# Epoch 26/50
#  - 0s - loss: 997.3937
# Epoch 27/50
#  - 0s - loss: 962.8197
# Epoch 28/50
#  - 0s - loss: 928.2650
# Epoch 29/50
#  - 0s - loss: 892.5332
# Epoch 30/50
#  - 0s - loss: 857.7234
# Epoch 31/50
#  - 0s - loss: 822.7210
# Epoch 32/50
#  - 0s - loss: 788.7339
# Epoch 33/50
#  - 0s - loss: 754.8283
# Epoch 34/50
#  - 0s - loss: 721.8832
# Epoch 35/50
#  - 0s - loss: 689.8448
# Epoch 36/50
#  - 0s - loss: 658.7399
# Epoch 37/50
#  - 0s - loss: 629.0440
# Epoch 38/50
#  - 0s - loss: 599.8422
# Epoch 39/50
#  - 0s - loss: 572.6671
# Epoch 40/50
#  - 0s - loss: 546.5870
# Epoch 41/50
#  - 0s - loss: 521.4000
# Epoch 42/50
#  - 0s - loss: 497.9482
# Epoch 43/50
#  - 0s - loss: 475.7946
# Epoch 44/50
#  - 0s - loss: 454.6623
# Epoch 45/50
#  - 0s - loss: 435.3242
# Epoch 46/50
#  - 0s - loss: 416.8358
# Epoch 47/50
#  - 0s - loss: 399.7589
# Epoch 48/50
#  - 0s - loss: 384.0580
# Epoch 49/50
#  - 0s - loss: 369.5154
# Epoch 50/50
#  - 0s - loss: 355.8898
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 336.92631910996914
# Test set MSE for 8 cycle:336.9263207083958
# Epoch 1/50
#  - 6s - loss: 1542.2694
# Epoch 2/50
#  - 0s - loss: 1527.5330
# Epoch 3/50
#  - 1s - loss: 1512.0441
# Epoch 4/50
#  - 0s - loss: 1495.8970
# Epoch 5/50
#  - 0s - loss: 1478.5546
# Epoch 6/50
#  - 0s - loss: 1460.4296
# Epoch 7/50
#  - 0s - loss: 1440.9337
# Epoch 8/50
#  - 0s - loss: 1420.2751
# Epoch 9/50
#  - 0s - loss: 1398.3439
# Epoch 10/50
#  - 0s - loss: 1374.7879
# Epoch 11/50
#  - 0s - loss: 1350.2271
# Epoch 12/50
#  - 0s - loss: 1324.0120
# Epoch 13/50
#  - 0s - loss: 1296.0371
# Epoch 14/50
#  - 0s - loss: 1266.8322
# Epoch 15/50
#  - 0s - loss: 1235.9289
# Epoch 16/50
#  - 0s - loss: 1203.4597
# Epoch 17/50
#  - 0s - loss: 1169.6814
# Epoch 18/50
#  - 0s - loss: 1134.4501
# Epoch 19/50
#  - 0s - loss: 1098.2906
# Epoch 20/50
#  - 0s - loss: 1060.9757
# Epoch 21/50
#  - 0s - loss: 1022.3750
# Epoch 22/50
#  - 0s - loss: 984.0230
# Epoch 23/50
#  - 0s - loss: 944.4951
# Epoch 24/50
#  - 0s - loss: 905.1367
# Epoch 25/50
#  - 0s - loss: 865.4863
# Epoch 26/50
#  - 0s - loss: 826.4279
# Epoch 27/50
#  - 0s - loss: 788.4202
# Epoch 28/50
#  - 0s - loss: 750.1737
# Epoch 29/50
#  - 0s - loss: 714.0627
# Epoch 30/50
#  - 0s - loss: 678.0155
# Epoch 31/50
#  - 0s - loss: 644.0867
# Epoch 32/50
#  - 0s - loss: 611.5707
# Epoch 33/50
#  - 0s - loss: 579.8674
# Epoch 34/50
#  - 0s - loss: 550.1033
# Epoch 35/50
#  - 0s - loss: 522.4472
# Epoch 36/50
#  - 0s - loss: 495.8159
# Epoch 37/50
#  - 0s - loss: 471.0564
# Epoch 38/50
#  - 0s - loss: 448.4939
# Epoch 39/50
#  - 0s - loss: 427.0496
# Epoch 40/50
#  - 0s - loss: 407.4523
# Epoch 41/50
#  - 0s - loss: 389.5587
# Epoch 42/50
#  - 0s - loss: 373.2912
# Epoch 43/50
#  - 0s - loss: 357.8638
# Epoch 44/50
#  - 0s - loss: 343.9398
# Epoch 45/50
#  - 0s - loss: 331.3957
# Epoch 46/50
#  - 0s - loss: 319.6955
# Epoch 47/50
#  - 0s - loss: 309.2967
# Epoch 48/50
#  - 0s - loss: 299.5838
# Epoch 49/50
#  - 0s - loss: 290.7765
# Epoch 50/50
#  - 0s - loss: 282.6347
# Evaluate on test data
# 309/309 [==============================] - 2s 6ms/step
# test loss, test acc: 246.50247760266546
# Test set MSE for 9 cycle:246.50247996365124
# Epoch 1/50
#  - 5s - loss: 1580.1108
# Epoch 2/50
#  - 0s - loss: 1561.4650
# Epoch 3/50
#  - 0s - loss: 1542.9064
# Epoch 4/50
#  - 0s - loss: 1523.5955
# Epoch 5/50
#  - 0s - loss: 1503.8553
# Epoch 6/50
#  - 0s - loss: 1483.4050
# Epoch 7/50
#  - 0s - loss: 1462.1979
# Epoch 8/50
#  - 0s - loss: 1439.7633
# Epoch 9/50
#  - 0s - loss: 1416.6343
# Epoch 10/50
#  - 0s - loss: 1392.5890
# Epoch 11/50
#  - 0s - loss: 1367.3489
# Epoch 12/50
#  - 0s - loss: 1340.6018
# Epoch 13/50
#  - 0s - loss: 1313.2842
# Epoch 14/50
#  - 0s - loss: 1284.3645
# Epoch 15/50
#  - 0s - loss: 1254.0015
# Epoch 16/50
#  - 0s - loss: 1222.7047
# Epoch 17/50
#  - 0s - loss: 1189.9944
# Epoch 18/50
#  - 0s - loss: 1156.6964
# Epoch 19/50
#  - 0s - loss: 1122.4464
# Epoch 20/50
#  - 0s - loss: 1088.1819
# Epoch 21/50
#  - 0s - loss: 1053.1785
# Epoch 22/50
#  - 0s - loss: 1017.5431
# Epoch 23/50
#  - 0s - loss: 982.7665
# Epoch 24/50
#  - 0s - loss: 946.8924
# Epoch 25/50
#  - 0s - loss: 912.5522
# Epoch 26/50
#  - 0s - loss: 877.6385
# Epoch 27/50
#  - 0s - loss: 843.0269
# Epoch 28/50
#  - 0s - loss: 809.5453
# Epoch 29/50
#  - 0s - loss: 775.9714
# Epoch 30/50
#  - 0s - loss: 743.6592
# Epoch 31/50
#  - 0s - loss: 711.5033
# Epoch 32/50
#  - 0s - loss: 680.2960
# Epoch 33/50
#  - 0s - loss: 650.4683
# Epoch 34/50
#  - 0s - loss: 621.0556
# Epoch 35/50
#  - 0s - loss: 593.6945
# Epoch 36/50
#  - 0s - loss: 566.8385
# Epoch 37/50
#  - 0s - loss: 541.5071
# Epoch 38/50
#  - 0s - loss: 517.0783
# Epoch 39/50
#  - 0s - loss: 494.2857
# Epoch 40/50
#  - 0s - loss: 472.1822
# Epoch 41/50
#  - 0s - loss: 451.3447
# Epoch 42/50
#  - 0s - loss: 431.8087
# Epoch 43/50
#  - 0s - loss: 413.5612
# Epoch 44/50
#  - 0s - loss: 396.1394
# Epoch 45/50
#  - 0s - loss: 380.0561
# Epoch 46/50
#  - 0s - loss: 365.0004
# Epoch 47/50
#  - 0s - loss: 351.1569
# Epoch 48/50
#  - 0s - loss: 337.6276
# Epoch 49/50
#  - 0s - loss: 325.6589
# Epoch 50/50
#  - 0s - loss: 314.3901
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 294.93950517277887
# Test set MSE for 10 cycle:294.93950238915187
# Epoch 1/50
#  - 5s - loss: 1605.0868
# Epoch 2/50
#  - 0s - loss: 1589.6136
# Epoch 3/50
#  - 0s - loss: 1574.7137
# Epoch 4/50
#  - 0s - loss: 1560.3826
# Epoch 5/50
#  - 0s - loss: 1545.9981
# Epoch 6/50
#  - 0s - loss: 1531.3541
# Epoch 7/50
#  - 0s - loss: 1515.9375
# Epoch 8/50
#  - 0s - loss: 1499.5677
# Epoch 9/50
#  - 0s - loss: 1482.2830
# Epoch 10/50
#  - 0s - loss: 1463.8083
# Epoch 11/50
#  - 0s - loss: 1444.2900
# Epoch 12/50
#  - 0s - loss: 1423.4623
# Epoch 13/50
#  - 0s - loss: 1401.5400
# Epoch 14/50
#  - 0s - loss: 1378.2258
# Epoch 15/50
#  - 0s - loss: 1353.5106
# Epoch 16/50
#  - 0s - loss: 1327.1274
# Epoch 17/50
#  - 0s - loss: 1299.8995
# Epoch 18/50
#  - 0s - loss: 1270.7768
# Epoch 19/50
#  - 0s - loss: 1240.0309
# Epoch 20/50
#  - 0s - loss: 1207.9300
# Epoch 21/50
#  - 0s - loss: 1174.3923
# Epoch 22/50
#  - 0s - loss: 1139.6868
# Epoch 23/50
#  - 0s - loss: 1103.5170
# Epoch 24/50
#  - 0s - loss: 1067.2488
# Epoch 25/50
#  - 0s - loss: 1029.4460
# Epoch 26/50
#  - 0s - loss: 991.6180
# Epoch 27/50
#  - 0s - loss: 953.3750
# Epoch 28/50
#  - 0s - loss: 914.9092
# Epoch 29/50
#  - 0s - loss: 876.2526
# Epoch 30/50
#  - 0s - loss: 838.3398
# Epoch 31/50
#  - 0s - loss: 800.7205
# Epoch 32/50
#  - 0s - loss: 763.1039
# Epoch 33/50
#  - 0s - loss: 727.0263
# Epoch 34/50
#  - 0s - loss: 691.3807
# Epoch 35/50
#  - 0s - loss: 657.2850
# Epoch 36/50
#  - 1s - loss: 624.1150
# Epoch 37/50
#  - 0s - loss: 592.1775
# Epoch 38/50
#  - 0s - loss: 561.8743
# Epoch 39/50
#  - 0s - loss: 533.2343
# Epoch 40/50
#  - 0s - loss: 506.0023
# Epoch 41/50
#  - 0s - loss: 480.6232
# Epoch 42/50
#  - 0s - loss: 457.0356
# Epoch 43/50
#  - 0s - loss: 434.4619
# Epoch 44/50
#  - 0s - loss: 413.7101
# Epoch 45/50
#  - 0s - loss: 394.2618
# Epoch 46/50
#  - 0s - loss: 376.1869
# Epoch 47/50
#  - 0s - loss: 360.0170
# Epoch 48/50
#  - 0s - loss: 344.7870
# Epoch 49/50
#  - 0s - loss: 330.6613
# Epoch 50/50
#  - 0s - loss: 318.2784
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 296.0680869883318
# Test set MSE for 11 cycle:296.0680855916929
# Epoch 1/50
#  - 5s - loss: 1545.3374
# Epoch 2/50
#  - 0s - loss: 1525.3910
# Epoch 3/50
#  - 0s - loss: 1505.3092
# Epoch 4/50
#  - 0s - loss: 1484.3282
# Epoch 5/50
#  - 0s - loss: 1462.7676
# Epoch 6/50
#  - 0s - loss: 1440.3660
# Epoch 7/50
#  - 0s - loss: 1416.7744
# Epoch 8/50
#  - 0s - loss: 1392.4796
# Epoch 9/50
#  - 0s - loss: 1367.0179
# Epoch 10/50
#  - 0s - loss: 1340.2658
# Epoch 11/50
#  - 0s - loss: 1312.5506
# Epoch 12/50
#  - 0s - loss: 1283.7585
# Epoch 13/50
#  - 0s - loss: 1254.1410
# Epoch 14/50
#  - 0s - loss: 1223.3305
# Epoch 15/50
#  - 0s - loss: 1192.1537
# Epoch 16/50
#  - 0s - loss: 1159.7208
# Epoch 17/50
#  - 0s - loss: 1126.9840
# Epoch 18/50
#  - 0s - loss: 1094.0621
# Epoch 19/50
#  - 0s - loss: 1060.2432
# Epoch 20/50
#  - 0s - loss: 1026.6145
# Epoch 21/50
#  - 0s - loss: 992.6779
# Epoch 22/50
#  - 0s - loss: 958.4015
# Epoch 23/50
#  - 0s - loss: 924.6124
# Epoch 24/50
#  - 0s - loss: 890.6667
# Epoch 25/50
#  - 0s - loss: 858.2444
# Epoch 26/50
#  - 0s - loss: 825.6773
# Epoch 27/50
#  - 0s - loss: 793.1601
# Epoch 28/50
#  - 0s - loss: 762.4889
# Epoch 29/50
#  - 0s - loss: 731.9508
# Epoch 30/50
#  - 4s - loss: 702.3697
# Epoch 31/50
#  - 0s - loss: 673.9490
# Epoch 32/50
#  - 0s - loss: 646.5350
# Epoch 33/50
#  - 0s - loss: 619.9050
# Epoch 34/50
#  - 0s - loss: 594.3311
# Epoch 35/50
#  - 0s - loss: 570.1223
# Epoch 36/50
#  - 0s - loss: 547.0911
# Epoch 37/50
#  - 0s - loss: 524.7006
# Epoch 38/50
#  - 0s - loss: 503.8377
# Epoch 39/50
#  - 0s - loss: 483.8412
# Epoch 40/50
#  - 0s - loss: 464.5579
# Epoch 41/50
#  - 0s - loss: 446.6234
# Epoch 42/50
#  - 0s - loss: 429.6848
# Epoch 43/50
#  - 0s - loss: 413.7170
# Epoch 44/50
#  - 0s - loss: 398.5193
# Epoch 45/50
#  - 0s - loss: 384.8043
# Epoch 46/50
#  - 0s - loss: 371.2971
# Epoch 47/50
#  - 0s - loss: 358.8272
# Epoch 48/50
#  - 0s - loss: 347.1930
# Epoch 49/50
#  - 0s - loss: 336.0079
# Epoch 50/50
#  - 0s - loss: 325.8978
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 323.2323361492466
# Test set MSE for 12 cycle:323.2323437841039
# Epoch 1/50
#  - 5s - loss: 1533.7515
# Epoch 2/50
#  - 0s - loss: 1515.7504
# Epoch 3/50
#  - 0s - loss: 1497.7640
# Epoch 4/50
#  - 0s - loss: 1479.1491
# Epoch 5/50
#  - 0s - loss: 1459.9108
# Epoch 6/50
#  - 0s - loss: 1440.1212
# Epoch 7/50
#  - 0s - loss: 1419.3130
# Epoch 8/50
#  - 0s - loss: 1397.5063
# Epoch 9/50
#  - 0s - loss: 1374.3210
# Epoch 10/50
#  - 0s - loss: 1350.0994
# Epoch 11/50
#  - 0s - loss: 1324.8471
# Epoch 12/50
#  - 0s - loss: 1297.8285
# Epoch 13/50
#  - 0s - loss: 1269.8184
# Epoch 14/50
#  - 0s - loss: 1240.5520
# Epoch 15/50
#  - 0s - loss: 1210.0957
# Epoch 16/50
#  - 0s - loss: 1178.7403
# Epoch 17/50
#  - 0s - loss: 1145.8823
# Epoch 18/50
#  - 0s - loss: 1112.3129
# Epoch 19/50
#  - 0s - loss: 1077.3075
# Epoch 20/50
#  - 0s - loss: 1041.6178
# Epoch 21/50
#  - 0s - loss: 1005.1441
# Epoch 22/50
#  - 0s - loss: 968.4918
# Epoch 23/50
#  - 0s - loss: 930.9582
# Epoch 24/50
#  - 0s - loss: 894.0551
# Epoch 25/50
#  - 0s - loss: 856.4345
# Epoch 26/50
#  - 0s - loss: 819.5052
# Epoch 27/50
#  - 0s - loss: 782.0276
# Epoch 28/50
#  - 0s - loss: 746.1993
# Epoch 29/50
#  - 0s - loss: 710.4720
# Epoch 30/50
#  - 0s - loss: 675.5581
# Epoch 31/50
#  - 0s - loss: 641.8480
# Epoch 32/50
#  - 0s - loss: 608.9087
# Epoch 33/50
#  - 0s - loss: 577.3692
# Epoch 34/50
#  - 0s - loss: 547.0903
# Epoch 35/50
#  - 0s - loss: 518.0149
# Epoch 36/50
#  - 0s - loss: 490.7106
# Epoch 37/50
#  - 0s - loss: 464.8940
# Epoch 38/50
#  - 0s - loss: 440.3189
# Epoch 39/50
#  - 0s - loss: 417.8879
# Epoch 40/50
#  - 0s - loss: 396.3932
# Epoch 41/50
#  - 0s - loss: 376.7485
# Epoch 42/50
#  - 0s - loss: 358.5005
# Epoch 43/50
#  - 0s - loss: 341.6273
# Epoch 44/50
#  - 0s - loss: 326.4235
# Epoch 45/50
#  - 0s - loss: 312.0782
# Epoch 46/50
#  - 0s - loss: 299.1274
# Epoch 47/50
#  - 0s - loss: 287.3343
# Epoch 48/50
#  - 0s - loss: 276.7306
# Epoch 49/50
#  - 0s - loss: 267.1231
# Epoch 50/50
#  - 0s - loss: 258.3874
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 241.05924785330072
# Test set MSE for 13 cycle:241.05925482873926
# Epoch 1/50
#  - 6s - loss: 1591.9072
# Epoch 2/50
#  - 0s - loss: 1578.2570
# Epoch 3/50
#  - 0s - loss: 1564.4768
# Epoch 4/50
#  - 0s - loss: 1550.4307
# Epoch 5/50
#  - 0s - loss: 1535.7424
# Epoch 6/50
#  - 0s - loss: 1519.8679
# Epoch 7/50
#  - 0s - loss: 1503.1993
# Epoch 8/50
#  - 0s - loss: 1484.7470
# Epoch 9/50
#  - 0s - loss: 1464.7791
# Epoch 10/50
#  - 0s - loss: 1443.4724
# Epoch 11/50
#  - 0s - loss: 1420.1405
# Epoch 12/50
#  - 0s - loss: 1395.5714
# Epoch 13/50
#  - 0s - loss: 1369.1773
# Epoch 14/50
#  - 0s - loss: 1340.8037
# Epoch 15/50
#  - 0s - loss: 1311.2981
# Epoch 16/50
#  - 0s - loss: 1280.2513
# Epoch 17/50
#  - 0s - loss: 1247.9512
# Epoch 18/50
#  - 0s - loss: 1214.1679
# Epoch 19/50
#  - 0s - loss: 1180.2840
# Epoch 20/50
#  - 0s - loss: 1144.4545
# Epoch 21/50
#  - 0s - loss: 1108.3818
# Epoch 22/50
#  - 0s - loss: 1071.7129
# Epoch 23/50
#  - 0s - loss: 1034.7455
# Epoch 24/50
#  - 0s - loss: 997.8053
# Epoch 25/50
#  - 0s - loss: 961.3093
# Epoch 26/50
#  - 0s - loss: 923.6549
# Epoch 27/50
#  - 0s - loss: 887.7441
# Epoch 28/50
#  - 0s - loss: 851.7968
# Epoch 29/50
#  - 0s - loss: 816.4599
# Epoch 30/50
#  - 0s - loss: 782.3768
# Epoch 31/50
#  - 0s - loss: 748.5030
# Epoch 32/50
#  - 0s - loss: 715.7636
# Epoch 33/50
#  - 0s - loss: 684.2258
# Epoch 34/50
#  - 0s - loss: 653.1690
# Epoch 35/50
#  - 0s - loss: 623.8873
# Epoch 36/50
#  - 0s - loss: 595.2348
# Epoch 37/50
#  - 0s - loss: 568.3129
# Epoch 38/50
#  - 0s - loss: 542.2097
# Epoch 39/50
#  - 0s - loss: 517.1764
# Epoch 40/50
#  - 0s - loss: 493.9775
# Epoch 41/50
#  - 0s - loss: 472.0246
# Epoch 42/50
#  - 0s - loss: 451.2987
# Epoch 43/50
#  - 0s - loss: 431.9734
# Epoch 44/50
#  - 0s - loss: 414.2533
# Epoch 45/50
#  - 0s - loss: 397.3450
# Epoch 46/50
#  - 0s - loss: 382.2164
# Epoch 47/50
#  - 0s - loss: 368.0157
# Epoch 48/50
#  - 0s - loss: 354.9397
# Epoch 49/50
#  - 0s - loss: 343.0965
# Epoch 50/50
#  - 0s - loss: 331.6298
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 330.9573598324674
# Test set MSE for 14 cycle:330.9573589192004
# Epoch 1/50
#  - 5s - loss: 1616.7285
# Epoch 2/50
#  - 0s - loss: 1600.3691
# Epoch 3/50
#  - 1s - loss: 1584.2745
# Epoch 4/50
#  - 0s - loss: 1568.1578
# Epoch 5/50
#  - 0s - loss: 1551.8621
# Epoch 6/50
#  - 0s - loss: 1535.3922
# Epoch 7/50
#  - 0s - loss: 1518.5825
# Epoch 8/50
#  - 0s - loss: 1501.1029
# Epoch 9/50
#  - 0s - loss: 1482.9807
# Epoch 10/50
#  - 0s - loss: 1463.8100
# Epoch 11/50
#  - 0s - loss: 1443.8722
# Epoch 12/50
#  - 0s - loss: 1422.7840
# Epoch 13/50
#  - 0s - loss: 1400.4817
# Epoch 14/50
#  - 0s - loss: 1376.9748
# Epoch 15/50
#  - 0s - loss: 1352.2955
# Epoch 16/50
#  - 0s - loss: 1326.6690
# Epoch 17/50
#  - 0s - loss: 1299.4730
# Epoch 18/50
#  - 0s - loss: 1271.8451
# Epoch 19/50
#  - 0s - loss: 1243.2492
# Epoch 20/50
#  - 0s - loss: 1213.6623
# Epoch 21/50
#  - 0s - loss: 1183.2324
# Epoch 22/50
#  - 0s - loss: 1152.1761
# Epoch 23/50
#  - 0s - loss: 1120.6264
# Epoch 24/50
#  - 0s - loss: 1088.8002
# Epoch 25/50
#  - 0s - loss: 1056.6404
# Epoch 26/50
#  - 0s - loss: 1024.4537
# Epoch 27/50
#  - 0s - loss: 992.1310
# Epoch 28/50
#  - 0s - loss: 960.0206
# Epoch 29/50
#  - 0s - loss: 927.9154
# Epoch 30/50
#  - 0s - loss: 896.0809
# Epoch 31/50
#  - 0s - loss: 864.4730
# Epoch 32/50
#  - 0s - loss: 832.7980
# Epoch 33/50
#  - 0s - loss: 801.6485
# Epoch 34/50
#  - 0s - loss: 770.6766
# Epoch 35/50
#  - 0s - loss: 740.0604
# Epoch 36/50
#  - 0s - loss: 710.4997
# Epoch 37/50
#  - 0s - loss: 681.2200
# Epoch 38/50
#  - 0s - loss: 651.9271
# Epoch 39/50
#  - 0s - loss: 624.0922
# Epoch 40/50
#  - 0s - loss: 596.7043
# Epoch 41/50
#  - 0s - loss: 570.2021
# Epoch 42/50
#  - 0s - loss: 544.5766
# Epoch 43/50
#  - 0s - loss: 519.9424
# Epoch 44/50
#  - 0s - loss: 495.8271
# Epoch 45/50
#  - 0s - loss: 473.4740
# Epoch 46/50
#  - 0s - loss: 451.5353
# Epoch 47/50
#  - 0s - loss: 431.0827
# Epoch 48/50
#  - 0s - loss: 411.5198
# Epoch 49/50
#  - 0s - loss: 393.8038
# Epoch 50/50
#  - 0s - loss: 376.1869
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 321.194141079307
# Test set MSE for 15 cycle:321.1941451758052
# Epoch 1/50
#  - 5s - loss: 1508.7823
# Epoch 2/50
#  - 0s - loss: 1490.5347
# Epoch 3/50
#  - 0s - loss: 1470.6946
# Epoch 4/50
#  - 0s - loss: 1449.6212
# Epoch 5/50
#  - 0s - loss: 1426.8038
# Epoch 6/50
#  - 0s - loss: 1402.3704
# Epoch 7/50
#  - 0s - loss: 1376.1292
# Epoch 8/50
#  - 0s - loss: 1348.1468
# Epoch 9/50
#  - 0s - loss: 1319.1620
# Epoch 10/50
#  - 0s - loss: 1287.9757
# Epoch 11/50
#  - 0s - loss: 1256.0673
# Epoch 12/50
#  - 0s - loss: 1222.4838
# Epoch 13/50
#  - 0s - loss: 1188.3851
# Epoch 14/50
#  - 0s - loss: 1152.5537
# Epoch 15/50
#  - 1s - loss: 1116.6822
# Epoch 16/50
#  - 0s - loss: 1079.8095
# Epoch 17/50
#  - 0s - loss: 1042.5088
# Epoch 18/50
#  - 0s - loss: 1004.0741
# Epoch 19/50
#  - 0s - loss: 965.8666
# Epoch 20/50
#  - 0s - loss: 927.7540
# Epoch 21/50
#  - 0s - loss: 889.3846
# Epoch 22/50
#  - 0s - loss: 851.6592
# Epoch 23/50
#  - 0s - loss: 814.7203
# Epoch 24/50
#  - 0s - loss: 776.8959
# Epoch 25/50
#  - 0s - loss: 740.8442
# Epoch 26/50
#  - 0s - loss: 705.3478
# Epoch 27/50
#  - 0s - loss: 670.2684
# Epoch 28/50
#  - 1s - loss: 636.6252
# Epoch 29/50
#  - 1s - loss: 603.6135
# Epoch 30/50
#  - 0s - loss: 572.5196
# Epoch 31/50
#  - 0s - loss: 542.1051
# Epoch 32/50
#  - 0s - loss: 512.9664
# Epoch 33/50
#  - 0s - loss: 486.0456
# Epoch 34/50
#  - 0s - loss: 459.8973
# Epoch 35/50
#  - 0s - loss: 435.0896
# Epoch 36/50
#  - 0s - loss: 412.2456
# Epoch 37/50
#  - 0s - loss: 390.6389
# Epoch 38/50
#  - 0s - loss: 370.6667
# Epoch 39/50
#  - 0s - loss: 352.4309
# Epoch 40/50
#  - 0s - loss: 334.8168
# Epoch 41/50
#  - 0s - loss: 319.1050
# Epoch 42/50
#  - 0s - loss: 304.8466
# Epoch 43/50
#  - 0s - loss: 291.3438
# Epoch 44/50
#  - 0s - loss: 279.4421
# Epoch 45/50
#  - 0s - loss: 268.3877
# Epoch 46/50
#  - 0s - loss: 258.5242
# Epoch 47/50
#  - 0s - loss: 249.6304
# Epoch 48/50
#  - 0s - loss: 241.5977
# Epoch 49/50
#  - 0s - loss: 234.2611
# Epoch 50/50
#  - 0s - loss: 227.8353
# Evaluate on test data
# 309/309 [==============================] - 2s 7ms/step
# test loss, test acc: 232.87884437536346
# Test set MSE for 16 cycle:232.87884316517415
# Epoch 1/50
#  - 5s - loss: 1593.9779
# Epoch 2/50
#  - 0s - loss: 1578.9493
# Epoch 3/50
#  - 0s - loss: 1564.7405
# Epoch 4/50
#  - 0s - loss: 1550.7986
# Epoch 5/50
#  - 0s - loss: 1537.0357
# Epoch 6/50
#  - 0s - loss: 1523.1516
# Epoch 7/50
#  - 0s - loss: 1508.7385
# Epoch 8/50
#  - 0s - loss: 1494.1929
# Epoch 9/50
#  - 0s - loss: 1478.5654
# Epoch 10/50
#  - 0s - loss: 1462.4943
# Epoch 11/50
#  - 0s - loss: 1445.3042
# Epoch 12/50
#  - 0s - loss: 1426.9952
# Epoch 13/50
#  - 0s - loss: 1407.6237
# Epoch 14/50
#  - 0s - loss: 1386.6238
# Epoch 15/50
#  - 0s - loss: 1364.2430
# Epoch 16/50
#  - 0s - loss: 1340.0116
# Epoch 17/50
#  - 0s - loss: 1314.4238
# Epoch 18/50
#  - 0s - loss: 1287.0117
# Epoch 19/50
#  - 0s - loss: 1257.8162
# Epoch 20/50
#  - 0s - loss: 1227.2219
# Epoch 21/50
#  - 0s - loss: 1195.1312
# Epoch 22/50
#  - 0s - loss: 1162.0192
# Epoch 23/50
#  - 0s - loss: 1127.8958
# Epoch 24/50
#  - 0s - loss: 1092.9692
# Epoch 25/50
#  - 0s - loss: 1057.3580
# Epoch 26/50
#  - 0s - loss: 1021.3357
# Epoch 27/50
#  - 0s - loss: 984.2377
# Epoch 28/50
#  - 0s - loss: 947.6686
# Epoch 29/50
#  - 0s - loss: 910.5498
# Epoch 30/50
#  - 1s - loss: 873.7335
# Epoch 31/50
#  - 0s - loss: 836.3877
# Epoch 32/50
#  - 0s - loss: 800.4412
# Epoch 33/50
#  - 0s - loss: 763.9761
# Epoch 34/50
#  - 0s - loss: 728.3248
# Epoch 35/50
#  - 0s - loss: 694.0877
# Epoch 36/50
#  - 0s - loss: 659.3533
# Epoch 37/50
#  - 0s - loss: 626.1988
# Epoch 38/50
#  - 0s - loss: 594.1415
# Epoch 39/50
#  - 0s - loss: 562.9953
# Epoch 40/50
#  - 0s - loss: 533.2456
# Epoch 41/50
#  - 0s - loss: 504.4643
# Epoch 42/50
#  - 0s - loss: 477.4232
# Epoch 43/50
#  - 0s - loss: 451.3555
# Epoch 44/50
#  - 0s - loss: 427.3208
# Epoch 45/50
#  - 0s - loss: 404.1344
# Epoch 46/50
#  - 0s - loss: 382.7484
# Epoch 47/50
#  - 0s - loss: 362.6042
# Epoch 48/50
#  - 0s - loss: 343.9889
# Epoch 49/50
#  - 0s - loss: 326.5787
# Epoch 50/50
#  - 0s - loss: 310.5429
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 310.4910052154442
# Test set MSE for 17 cycle:310.49100518361377
# Epoch 1/50
#  - 6s - loss: 1608.6126
# Epoch 2/50
#  - 0s - loss: 1596.8835
# Epoch 3/50
#  - 0s - loss: 1585.1769
# Epoch 4/50
#  - 0s - loss: 1573.3603
# Epoch 5/50
#  - 0s - loss: 1561.0834
# Epoch 6/50
#  - 0s - loss: 1548.2116
# Epoch 7/50
#  - 0s - loss: 1534.7502
# Epoch 8/50
#  - 0s - loss: 1520.2263
# Epoch 9/50
#  - 0s - loss: 1505.1576
# Epoch 10/50
#  - 0s - loss: 1488.8324
# Epoch 11/50
#  - 0s - loss: 1471.4397
# Epoch 12/50
#  - 0s - loss: 1452.9968
# Epoch 13/50
#  - 0s - loss: 1433.3648
# Epoch 14/50
#  - 0s - loss: 1412.4762
# Epoch 15/50
#  - 0s - loss: 1389.9079
# Epoch 16/50
#  - 0s - loss: 1366.3497
# Epoch 17/50
#  - 0s - loss: 1341.2742
# Epoch 18/50
#  - 0s - loss: 1314.8710
# Epoch 19/50
#  - 0s - loss: 1287.4794
# Epoch 20/50
#  - 0s - loss: 1258.4873
# Epoch 21/50
#  - 0s - loss: 1228.5866
# Epoch 22/50
#  - 0s - loss: 1198.2670
# Epoch 23/50
#  - 0s - loss: 1166.6769
# Epoch 24/50
#  - 0s - loss: 1134.5991
# Epoch 25/50
#  - 0s - loss: 1102.1107
# Epoch 26/50
#  - 0s - loss: 1069.2303
# Epoch 27/50
#  - 0s - loss: 1035.6697
# Epoch 28/50
#  - 0s - loss: 1002.8360
# Epoch 29/50
#  - 0s - loss: 969.4179
# Epoch 30/50
#  - 0s - loss: 936.5343
# Epoch 31/50
#  - 0s - loss: 903.6947
# Epoch 32/50
#  - 0s - loss: 871.2610
# Epoch 33/50
#  - 0s - loss: 839.2975
# Epoch 34/50
#  - 0s - loss: 807.4568
# Epoch 35/50
#  - 0s - loss: 776.5005
# Epoch 36/50
#  - 0s - loss: 745.8198
# Epoch 37/50
#  - 0s - loss: 716.6196
# Epoch 38/50
#  - 0s - loss: 687.3300
# Epoch 39/50
#  - 0s - loss: 659.3566
# Epoch 40/50
#  - 0s - loss: 632.3946
# Epoch 41/50
#  - 0s - loss: 605.5650
# Epoch 42/50
#  - 0s - loss: 580.0430
# Epoch 43/50
#  - 0s - loss: 554.8501
# Epoch 44/50
#  - 0s - loss: 530.7496
# Epoch 45/50
#  - 0s - loss: 507.4805
# Epoch 46/50
#  - 0s - loss: 485.0867
# Epoch 47/50
#  - 0s - loss: 463.4802
# Epoch 48/50
#  - 0s - loss: 442.2368
# Epoch 49/50
#  - 0s - loss: 422.3113
# Epoch 50/50
#  - 0s - loss: 403.4965
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 374.2106661009557
# Test set MSE for 18 cycle:374.2106640641724
# Epoch 1/50
#  - 6s - loss: 1587.0748
# Epoch 2/50
#  - 0s - loss: 1572.9655
# Epoch 3/50
#  - 0s - loss: 1558.7371
# Epoch 4/50
#  - 0s - loss: 1544.0643
# Epoch 5/50
#  - 0s - loss: 1528.8574
# Epoch 6/50
#  - 0s - loss: 1512.6878
# Epoch 7/50
#  - 0s - loss: 1495.8136
# Epoch 8/50
#  - 0s - loss: 1477.6462
# Epoch 9/50
#  - 0s - loss: 1458.8389
# Epoch 10/50
#  - 0s - loss: 1438.3723
# Epoch 11/50
#  - 0s - loss: 1416.5528
# Epoch 12/50
#  - 0s - loss: 1393.5924
# Epoch 13/50
#  - 0s - loss: 1368.4050
# Epoch 14/50
#  - 0s - loss: 1341.5996
# Epoch 15/50
#  - 0s - loss: 1314.0508
# Epoch 16/50
#  - 0s - loss: 1284.3908
# Epoch 17/50
#  - 0s - loss: 1253.3761
# Epoch 18/50
#  - 0s - loss: 1221.4766
# Epoch 19/50
#  - 0s - loss: 1188.2396
# Epoch 20/50
#  - 0s - loss: 1154.9103
# Epoch 21/50
#  - 0s - loss: 1120.4272
# Epoch 22/50
#  - 0s - loss: 1085.1993
# Epoch 23/50
#  - 0s - loss: 1049.9967
# Epoch 24/50
#  - 0s - loss: 1014.2526
# Epoch 25/50
#  - 0s - loss: 979.2886
# Epoch 26/50
#  - 0s - loss: 943.2587
# Epoch 27/50
#  - 0s - loss: 908.0958
# Epoch 28/50
#  - 0s - loss: 873.6325
# Epoch 29/50
#  - 0s - loss: 839.0924
# Epoch 30/50
#  - 0s - loss: 804.9145
# Epoch 31/50
#  - 0s - loss: 771.8213
# Epoch 32/50
#  - 0s - loss: 739.7831
# Epoch 33/50
#  - 0s - loss: 708.3246
# Epoch 34/50
#  - 0s - loss: 678.1174
# Epoch 35/50
#  - 0s - loss: 648.8730
# Epoch 36/50
#  - 0s - loss: 620.7171
# Epoch 37/50
#  - 0s - loss: 594.0750
# Epoch 38/50
#  - 0s - loss: 567.6178
# Epoch 39/50
#  - 0s - loss: 543.1730
# Epoch 40/50
#  - 0s - loss: 519.7512
# Epoch 41/50
#  - 0s - loss: 497.0546
# Epoch 42/50
#  - 0s - loss: 475.3533
# Epoch 43/50
#  - 0s - loss: 455.3327
# Epoch 44/50
#  - 0s - loss: 435.9252
# Epoch 45/50
#  - 0s - loss: 417.7692
# Epoch 46/50
#  - 0s - loss: 400.7403
# Epoch 47/50
#  - 0s - loss: 384.8132
# Epoch 48/50
#  - 0s - loss: 369.4754
# Epoch 49/50
#  - 0s - loss: 355.6262
# Epoch 50/50
#  - 0s - loss: 342.4068
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 307.5529925398842
# Test set MSE for 19 cycle:307.5529990900633
# Epoch 1/50
#  - 6s - loss: 1518.2409
# Epoch 2/50
#  - 0s - loss: 1500.5477
# Epoch 3/50
#  - 0s - loss: 1482.7839
# Epoch 4/50
#  - 0s - loss: 1464.7862
# Epoch 5/50
#  - 0s - loss: 1446.1415
# Epoch 6/50
#  - 0s - loss: 1427.3553
# Epoch 7/50
#  - 0s - loss: 1407.8246
# Epoch 8/50
#  - 0s - loss: 1387.9867
# Epoch 9/50
#  - 0s - loss: 1367.3771
# Epoch 10/50
#  - 0s - loss: 1345.9681
# Epoch 11/50
#  - 0s - loss: 1324.4773
# Epoch 12/50
#  - 0s - loss: 1301.5571
# Epoch 13/50
#  - 0s - loss: 1278.5778
# Epoch 14/50
#  - 0s - loss: 1254.6869
# Epoch 15/50
#  - 0s - loss: 1230.2563
# Epoch 16/50
#  - 0s - loss: 1205.4468
# Epoch 17/50
#  - 0s - loss: 1179.7116
# Epoch 18/50
#  - 0s - loss: 1153.7464
# Epoch 19/50
#  - 0s - loss: 1127.2240
# Epoch 20/50
#  - 0s - loss: 1100.1407
# Epoch 21/50
#  - 0s - loss: 1071.9147
# Epoch 22/50
#  - 0s - loss: 1043.1468
# Epoch 23/50
#  - 0s - loss: 1013.5729
# Epoch 24/50
#  - 0s - loss: 983.0496
# Epoch 25/50
#  - 0s - loss: 951.6213
# Epoch 26/50
#  - 0s - loss: 919.8171
# Epoch 27/50
#  - 0s - loss: 886.8963
# Epoch 28/50
#  - 0s - loss: 854.6985
# Epoch 29/50
#  - 0s - loss: 821.1935
# Epoch 30/50
#  - 0s - loss: 787.5513
# Epoch 31/50
#  - 0s - loss: 753.1489
# Epoch 32/50
#  - 0s - loss: 718.5235
# Epoch 33/50
#  - 0s - loss: 682.7010
# Epoch 34/50
#  - 0s - loss: 647.2248
# Epoch 35/50
#  - 0s - loss: 611.9899
# Epoch 36/50
#  - 0s - loss: 576.8582
# Epoch 37/50
#  - 0s - loss: 542.7199
# Epoch 38/50
#  - 0s - loss: 509.6877
# Epoch 39/50
#  - 0s - loss: 478.5450
# Epoch 40/50
#  - 0s - loss: 449.0753
# Epoch 41/50
#  - 0s - loss: 421.7288
# Epoch 42/50
#  - 0s - loss: 395.3209
# Epoch 43/50
#  - 0s - loss: 371.5614
# Epoch 44/50
#  - 0s - loss: 349.4973
# Epoch 45/50
#  - 0s - loss: 329.5428
# Epoch 46/50
#  - 0s - loss: 311.1519
# Epoch 47/50
#  - 0s - loss: 294.8559
# Epoch 48/50
#  - 1s - loss: 280.2997
# Epoch 49/50
#  - 0s - loss: 267.2199
# Epoch 50/50
#  - 0s - loss: 255.9150
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 253.6762739755575
# Test set MSE for 20 cycle:253.6762807645679
# Epoch 1/50
#  - 6s - loss: 1573.5870
# Epoch 2/50
#  - 0s - loss: 1557.9308
# Epoch 3/50
#  - 0s - loss: 1541.9114
# Epoch 4/50
#  - 0s - loss: 1525.3440
# Epoch 5/50
#  - 0s - loss: 1508.3954
# Epoch 6/50
#  - 0s - loss: 1490.7122
# Epoch 7/50
#  - 0s - loss: 1472.2300
# Epoch 8/50
#  - 0s - loss: 1453.1953
# Epoch 9/50
#  - 0s - loss: 1432.9007
# Epoch 10/50
#  - 0s - loss: 1412.0529
# Epoch 11/50
#  - 0s - loss: 1390.2158
# Epoch 12/50
#  - 0s - loss: 1367.4155
# Epoch 13/50
#  - 0s - loss: 1344.0028
# Epoch 14/50
#  - 0s - loss: 1319.3687
# Epoch 15/50
#  - 0s - loss: 1294.2249
# Epoch 16/50
#  - 0s - loss: 1267.9791
# Epoch 17/50
#  - 0s - loss: 1240.8803
# Epoch 18/50
#  - 0s - loss: 1213.1863
# Epoch 19/50
#  - 0s - loss: 1184.6136
# Epoch 20/50
#  - 0s - loss: 1155.5894
# Epoch 21/50
#  - 0s - loss: 1125.6790
# Epoch 22/50
#  - 1s - loss: 1095.4566
# Epoch 23/50
#  - 1s - loss: 1064.7468
# Epoch 24/50
#  - 1s - loss: 1033.8145
# Epoch 25/50
#  - 0s - loss: 1002.7317
# Epoch 26/50
#  - 1s - loss: 971.6242
# Epoch 27/50
#  - 0s - loss: 939.9844
# Epoch 28/50
#  - 0s - loss: 909.2233
# Epoch 29/50
#  - 0s - loss: 878.4485
# Epoch 30/50
#  - 0s - loss: 847.3079
# Epoch 31/50
#  - 0s - loss: 817.2248
# Epoch 32/50
#  - 0s - loss: 787.1828
# Epoch 33/50
#  - 0s - loss: 757.6401
# Epoch 34/50
#  - 0s - loss: 729.0103
# Epoch 35/50
#  - 0s - loss: 700.3677
# Epoch 36/50
#  - 0s - loss: 673.0858
# Epoch 37/50
#  - 0s - loss: 646.1227
# Epoch 38/50
#  - 0s - loss: 620.0389
# Epoch 39/50
#  - 0s - loss: 594.4383
# Epoch 40/50
#  - 0s - loss: 570.4710
# Epoch 41/50
#  - 0s - loss: 546.5478
# Epoch 42/50
#  - 0s - loss: 523.7870
# Epoch 43/50
#  - 0s - loss: 502.0020
# Epoch 44/50
#  - 0s - loss: 481.3253
# Epoch 45/50
#  - 0s - loss: 461.3871
# Epoch 46/50
#  - 0s - loss: 442.5599
# Epoch 47/50
#  - 0s - loss: 424.8371
# Epoch 48/50
#  - 0s - loss: 407.9239
# Epoch 49/50
#  - 0s - loss: 391.7199
# Epoch 50/50
#  - 0s - loss: 376.3682
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 337.7645916491265
# Test set MSE for 21 cycle:337.76461125776603
# Epoch 1/50
#  - 6s - loss: 1554.1132
# Epoch 2/50
#  - 0s - loss: 1540.8210
# Epoch 3/50
#  - 0s - loss: 1527.4156
# Epoch 4/50
#  - 0s - loss: 1513.4036
# Epoch 5/50
#  - 0s - loss: 1498.7669
# Epoch 6/50
#  - 0s - loss: 1483.2106
# Epoch 7/50
#  - 0s - loss: 1466.8452
# Epoch 8/50
#  - 0s - loss: 1449.4477
# Epoch 9/50
#  - 0s - loss: 1430.6143
# Epoch 10/50
#  - 0s - loss: 1410.6585
# Epoch 11/50
#  - 0s - loss: 1389.0929
# Epoch 12/50
#  - 0s - loss: 1365.9496
# Epoch 13/50
#  - 0s - loss: 1340.9092
# Epoch 14/50
#  - 0s - loss: 1313.9715
# Epoch 15/50
#  - 0s - loss: 1284.7809
# Epoch 16/50
#  - 0s - loss: 1253.7412
# Epoch 17/50
#  - 0s - loss: 1220.8245
# Epoch 18/50
#  - 0s - loss: 1185.3915
# Epoch 19/50
#  - 0s - loss: 1148.0386
# Epoch 20/50
#  - 0s - loss: 1109.6963
# Epoch 21/50
#  - 0s - loss: 1069.4172
# Epoch 22/50
#  - 0s - loss: 1028.5148
# Epoch 23/50
#  - 0s - loss: 987.3172
# Epoch 24/50
#  - 0s - loss: 944.5057
# Epoch 25/50
#  - 0s - loss: 902.4821
# Epoch 26/50
#  - 0s - loss: 860.9530
# Epoch 27/50
#  - 0s - loss: 818.9069
# Epoch 28/50
#  - 0s - loss: 778.4130
# Epoch 29/50
#  - 0s - loss: 738.3559
# Epoch 30/50
#  - 0s - loss: 699.8940
# Epoch 31/50
#  - 0s - loss: 662.8754
# Epoch 32/50
#  - 0s - loss: 627.0115
# Epoch 33/50
#  - 0s - loss: 593.2047
# Epoch 34/50
#  - 0s - loss: 561.2627
# Epoch 35/50
#  - 0s - loss: 530.5997
# Epoch 36/50
#  - 0s - loss: 502.0645
# Epoch 37/50
#  - 0s - loss: 475.8715
# Epoch 38/50
#  - 0s - loss: 451.1079
# Epoch 39/50
#  - 0s - loss: 428.1283
# Epoch 40/50
#  - 0s - loss: 407.2876
# Epoch 41/50
#  - 0s - loss: 388.0046
# Epoch 42/50
#  - 0s - loss: 370.4926
# Epoch 43/50
#  - 0s - loss: 354.4190
# Epoch 44/50
#  - 0s - loss: 339.7125
# Epoch 45/50
#  - 0s - loss: 326.8206
# Epoch 46/50
#  - 0s - loss: 314.7779
# Epoch 47/50
#  - 0s - loss: 304.0375
# Epoch 48/50
#  - 0s - loss: 294.2068
# Epoch 49/50
#  - 0s - loss: 285.3749
# Epoch 50/50
#  - 0s - loss: 277.1832
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 263.69736251090336
# Test set MSE for 22 cycle:263.69736582911867
# Epoch 1/50
#  - 6s - loss: 1598.4016
# Epoch 2/50
#  - 0s - loss: 1581.8506
# Epoch 3/50
#  - 0s - loss: 1565.6557
# Epoch 4/50
#  - 0s - loss: 1549.3059
# Epoch 5/50
#  - 0s - loss: 1532.7633
# Epoch 6/50
#  - 0s - loss: 1515.7937
# Epoch 7/50
#  - 0s - loss: 1498.2928
# Epoch 8/50
#  - 0s - loss: 1480.2844
# Epoch 9/50
#  - 0s - loss: 1461.4344
# Epoch 10/50
#  - 0s - loss: 1441.8418
# Epoch 11/50
#  - 0s - loss: 1421.4398
# Epoch 12/50
#  - 0s - loss: 1400.2240
# Epoch 13/50
#  - 0s - loss: 1377.9260
# Epoch 14/50
#  - 0s - loss: 1355.0482
# Epoch 15/50
#  - 0s - loss: 1331.5477
# Epoch 16/50
#  - 0s - loss: 1307.1048
# Epoch 17/50
#  - 0s - loss: 1282.0388
# Epoch 18/50
#  - 0s - loss: 1256.2278
# Epoch 19/50
#  - 0s - loss: 1230.1660
# Epoch 20/50
#  - 0s - loss: 1202.9954
# Epoch 21/50
#  - 0s - loss: 1175.5256
# Epoch 22/50
#  - 0s - loss: 1147.9383
# Epoch 23/50
#  - 0s - loss: 1119.2677
# Epoch 24/50
#  - 0s - loss: 1090.6423
# Epoch 25/50
#  - 0s - loss: 1061.4659
# Epoch 26/50
#  - 0s - loss: 1031.8773
# Epoch 27/50
#  - 0s - loss: 1002.1879
# Epoch 28/50
#  - 0s - loss: 971.5514
# Epoch 29/50
#  - 0s - loss: 941.2139
# Epoch 30/50
#  - 0s - loss: 909.9665
# Epoch 31/50
#  - 0s - loss: 879.0554
# Epoch 32/50
#  - 0s - loss: 847.3498
# Epoch 33/50
#  - 0s - loss: 816.2657
# Epoch 34/50
#  - 0s - loss: 785.2071
# Epoch 35/50
#  - 0s - loss: 753.8531
# Epoch 36/50
#  - 0s - loss: 723.6777
# Epoch 37/50
#  - 0s - loss: 693.6620
# Epoch 38/50
#  - 0s - loss: 664.1387
# Epoch 39/50
#  - 0s - loss: 635.7950
# Epoch 40/50
#  - 0s - loss: 608.0499
# Epoch 41/50
#  - 0s - loss: 581.1986
# Epoch 42/50
#  - 0s - loss: 555.6854
# Epoch 43/50
#  - 0s - loss: 531.0156
# Epoch 44/50
#  - 0s - loss: 507.9965
# Epoch 45/50
#  - 0s - loss: 485.3210
# Epoch 46/50
#  - 0s - loss: 464.4536
# Epoch 47/50
#  - 0s - loss: 444.4534
# Epoch 48/50
#  - 0s - loss: 425.9771
# Epoch 49/50
#  - 0s - loss: 408.6145
# Epoch 50/50
#  - 0s - loss: 392.0248
# Evaluate on test data
# 309/309 [==============================] - 2s 8ms/step
# test loss, test acc: 362.93694623928627
# Test set MSE for 23 cycle:362.9369441819258
# Epoch 1/50
#  - 6s - loss: 1573.8974
# Epoch 2/50
#  - 0s - loss: 1558.7494
# Epoch 3/50
#  - 0s - loss: 1543.6261
# Epoch 4/50
#  - 0s - loss: 1527.9018
# Epoch 5/50
#  - 0s - loss: 1511.9185
# Epoch 6/50
#  - 0s - loss: 1495.1218
# Epoch 7/50
#  - 0s - loss: 1477.5716
# Epoch 8/50
#  - 0s - loss: 1459.1897
# Epoch 9/50
#  - 0s - loss: 1439.9329
# Epoch 10/50
#  - 0s - loss: 1419.1853
# Epoch 11/50
#  - 0s - loss: 1397.7490
# Epoch 12/50
#  - 0s - loss: 1374.7420
# Epoch 13/50
#  - 0s - loss: 1350.5623
# Epoch 14/50
#  - 0s - loss: 1324.6141
# Epoch 15/50
#  - 0s - loss: 1297.1524
# Epoch 16/50
#  - 0s - loss: 1268.7378
# Epoch 17/50
#  - 0s - loss: 1238.3525
# Epoch 18/50
#  - 0s - loss: 1206.9347
# Epoch 19/50
#  - 0s - loss: 1173.6954
# Epoch 20/50
#  - 0s - loss: 1139.7987
# Epoch 21/50
#  - 0s - loss: 1104.5700
# Epoch 22/50
#  - 0s - loss: 1067.9793
# Epoch 23/50
#  - 0s - loss: 1030.9687
# Epoch 24/50
#  - 0s - loss: 992.8259
# Epoch 25/50
#  - 0s - loss: 954.4771
# Epoch 26/50
#  - 0s - loss: 916.0280
# Epoch 27/50
#  - 0s - loss: 878.0178
# Epoch 28/50
#  - 0s - loss: 839.3087
# Epoch 29/50
#  - 0s - loss: 801.2410
# Epoch 30/50
#  - 0s - loss: 764.4229
# Epoch 31/50
#  - 0s - loss: 727.1239
# Epoch 32/50
#  - 0s - loss: 691.5086
# Epoch 33/50
#  - 0s - loss: 656.5295
# Epoch 34/50
#  - 0s - loss: 623.1075
# Epoch 35/50
#  - 0s - loss: 590.1701
# Epoch 36/50
#  - 0s - loss: 559.4343
# Epoch 37/50
#  - 0s - loss: 529.6398
# Epoch 38/50
#  - 0s - loss: 501.0874
# Epoch 39/50
#  - 0s - loss: 474.3734
# Epoch 40/50
#  - 0s - loss: 449.1314
# Epoch 41/50
#  - 0s - loss: 425.1141
# Epoch 42/50
#  - 0s - loss: 403.0491
# Epoch 43/50
#  - 0s - loss: 382.0816
# Epoch 44/50
#  - 0s - loss: 362.8821
# Epoch 45/50
#  - 0s - loss: 344.6155
# Epoch 46/50
#  - 0s - loss: 328.1065
# Epoch 47/50
#  - 0s - loss: 312.8641
# Epoch 48/50
#  - 0s - loss: 299.0574
# Epoch 49/50
#  - 0s - loss: 286.2278
# Epoch 50/50
#  - 0s - loss: 274.9478
# Evaluate on test data
# 309/309 [==============================] - 3s 8ms/step
# test loss, test acc: 280.3026240574118
# Test set MSE for 24 cycle:280.30262641425634
# Epoch 1/50
#  - 6s - loss: 1590.9985
# Epoch 2/50
#  - 0s - loss: 1576.7490
# Epoch 3/50
#  - 0s - loss: 1562.8555
# Epoch 4/50
#  - 0s - loss: 1548.6631
# Epoch 5/50
#  - 0s - loss: 1534.1971
# Epoch 6/50
#  - 0s - loss: 1519.2078
# Epoch 7/50
#  - 0s - loss: 1503.5121
# Epoch 8/50
#  - 0s - loss: 1487.1862
# Epoch 9/50
#  - 0s - loss: 1470.0053
# Epoch 10/50
#  - 0s - loss: 1451.8372
# Epoch 11/50
#  - 0s - loss: 1432.9149
# Epoch 12/50
#  - 0s - loss: 1412.4677
# Epoch 13/50
#  - 0s - loss: 1390.5922
# Epoch 14/50
#  - 0s - loss: 1366.9853
# Epoch 15/50
#  - 0s - loss: 1342.1394
# Epoch 16/50
#  - 0s - loss: 1315.0960
# Epoch 17/50
#  - 0s - loss: 1286.5900
# Epoch 18/50
#  - 0s - loss: 1256.2516
# Epoch 19/50
#  - 0s - loss: 1225.0384
# Epoch 20/50
#  - 0s - loss: 1191.8718
# Epoch 21/50
#  - 0s - loss: 1157.7423
# Epoch 22/50
#  - 0s - loss: 1122.6724
# Epoch 23/50
#  - 1s - loss: 1087.4154
# Epoch 24/50
#  - 0s - loss: 1051.2119
# Epoch 25/50
#  - 0s - loss: 1014.6395
# Epoch 26/50
#  - 0s - loss: 977.6436
# Epoch 27/50
#  - 0s - loss: 941.0520
# Epoch 28/50
#  - 0s - loss: 904.2864
# Epoch 29/50
#  - 0s - loss: 868.1670
# Epoch 30/50
#  - 0s - loss: 832.1251
# Epoch 31/50
#  - 0s - loss: 796.4474
# Epoch 32/50
#  - 0s - loss: 762.3322
# Epoch 33/50
#  - 0s - loss: 728.1191
# Epoch 34/50
#  - 0s - loss: 695.4595
# Epoch 35/50
#  - 0s - loss: 663.4670
# Epoch 36/50
#  - 0s - loss: 632.4819
# Epoch 37/50
#  - 0s - loss: 602.8340
# Epoch 38/50
#  - 0s - loss: 574.4634
# Epoch 39/50
#  - 0s - loss: 546.8899
# Epoch 40/50
#  - 0s - loss: 520.9215
# Epoch 41/50
#  - 0s - loss: 495.9626
# Epoch 42/50
#  - 0s - loss: 472.4190
# Epoch 43/50
#  - 0s - loss: 450.2658
# Epoch 44/50
#  - 0s - loss: 428.8080
# Epoch 45/50
#  - 0s - loss: 409.6126
# Epoch 46/50
#  - 0s - loss: 391.1283
# Epoch 47/50
#  - 0s - loss: 374.0847
# Epoch 48/50
#  - 0s - loss: 358.2267
# Epoch 49/50
#  - 0s - loss: 343.4385
# Epoch 50/50
#  - 0s - loss: 329.3968
# Evaluate on test data
# ...
# Epoch 39/50
#  - 0s - loss: 674.9842
# Epoch 40/50
#  - 0s - loss: 649.0397
# Epoch 41/50
#  - 0s - loss: 624.1399
# Epoch 42/50
#  - 0s - loss: 599.8359
# Epoch 43/50
#  - 0s - loss: 576.3182
# Epoch 44/50
#  - 0s - loss: 553.6015
# Epoch 45/50
#  - 0s - loss: 531.7622
# Epoch 46/50
#  - 0s - loss: 510.4027
# Epoch 47/50
#  - 0s - loss: 490.6345
# Epoch 48/50
#  - 0s - loss: 470.9876
# Epoch 49/50
#  - 0s - loss: 452.5266
# Epoch 50/50
#  - 0s - loss: 434.9793
# Evaluate on test data
# 309/309 [==============================] - 3s 11ms/step
# test loss, test acc: 390.7882064276143
# Test set MSE for 42 cycle:390.78821047800614
# Epoch 1/50
#  - 8s - loss: 1544.6435
# Epoch 2/50
#  - 0s - loss: 1527.9851
# Epoch 3/50
#  - 0s - loss: 1511.2062
# Epoch 4/50
#  - 0s - loss: 1493.7887
# Epoch 5/50
#  - 0s - loss: 1476.0954
# Epoch 6/50
#  - 0s - loss: 1457.4064
# Epoch 7/50
#  - 0s - loss: 1438.1358
# Epoch 8/50
#  - 0s - loss: 1418.0985
# Epoch 9/50
#  - 0s - loss: 1397.0814
# Epoch 10/50
#  - 0s - loss: 1375.0851
# Epoch 11/50
#  - 0s - loss: 1352.0994
# Epoch 12/50
#  - 0s - loss: 1327.9706
# Epoch 13/50
#  - 0s - loss: 1302.9303
# Epoch 14/50
#  - 0s - loss: 1277.2262
# Epoch 15/50
#  - 0s - loss: 1250.5537
# Epoch 16/50
#  - 0s - loss: 1223.0234
# Epoch 17/50
#  - 0s - loss: 1194.7197
# Epoch 18/50
#  - 0s - loss: 1165.9273
# Epoch 19/50
#  - 0s - loss: 1136.1782
# Epoch 20/50
#  - 0s - loss: 1105.7686
# Epoch 21/50
#  - 0s - loss: 1075.1958
# Epoch 22/50
#  - 0s - loss: 1043.6249
# Epoch 23/50
#  - 0s - loss: 1011.9104
# Epoch 24/50
#  - 0s - loss: 979.5299
# Epoch 25/50
#  - 0s - loss: 946.9302
# Epoch 26/50
#  - 0s - loss: 914.2630
# Epoch 27/50
#  - 0s - loss: 880.6531
# Epoch 28/50
#  - 0s - loss: 847.0839
# Epoch 29/50
#  - 0s - loss: 813.4108
# Epoch 30/50
#  - 0s - loss: 779.4606
# Epoch 31/50
#  - 0s - loss: 745.9158
# Epoch 32/50
#  - 0s - loss: 712.7371
# Epoch 33/50
#  - 0s - loss: 679.1647
# Epoch 34/50
#  - 0s - loss: 646.5543
# Epoch 35/50
#  - 0s - loss: 614.4259
# Epoch 36/50
#  - 0s - loss: 584.0053
# Epoch 37/50
#  - 0s - loss: 553.9634
# Epoch 38/50
#  - 0s - loss: 525.6701
# Epoch 39/50
#  - 0s - loss: 498.6545
# Epoch 40/50
#  - 0s - loss: 472.8093
# Epoch 41/50
#  - 0s - loss: 449.1556
# Epoch 42/50
#  - 0s - loss: 426.5396
# Epoch 43/50
#  - 0s - loss: 405.4843
# Epoch 44/50
#  - 0s - loss: 385.8669
# Epoch 45/50
#  - 0s - loss: 367.2260
# Epoch 46/50
#  - 0s - loss: 350.4104
# Epoch 47/50
#  - 0s - loss: 334.7323
# Epoch 48/50
#  - 1s - loss: 320.1746
# Epoch 49/50
#  - 0s - loss: 307.2163
# Epoch 50/50
#  - 0s - loss: 295.4109
# Evaluate on test data
# 309/309 [==============================] - 4s 12ms/step
# test loss, test acc: 276.3757123731101
# Test set MSE for 43 cycle:276.3757235549969
# Epoch 1/50
#  - 8s - loss: 1575.7763
# Epoch 2/50
#  - 0s - loss: 1559.8841
# Epoch 3/50
#  - 0s - loss: 1543.3612
# Epoch 4/50
#  - 0s - loss: 1526.3330
# Epoch 5/50
#  - 0s - loss: 1508.4959
# Epoch 6/50
#  - 0s - loss: 1489.6993
# Epoch 7/50
#  - 0s - loss: 1469.5946
# Epoch 8/50
#  - 0s - loss: 1448.6745
# Epoch 9/50
#  - 0s - loss: 1426.4013
# Epoch 10/50
#  - 0s - loss: 1403.0699
# Epoch 11/50
#  - 0s - loss: 1378.4974
# Epoch 12/50
#  - 0s - loss: 1352.8908
# Epoch 13/50
#  - 0s - loss: 1325.8458
# Epoch 14/50
#  - 0s - loss: 1297.6823
# Epoch 15/50
#  - 0s - loss: 1268.2011
# Epoch 16/50
#  - 0s - loss: 1238.1640
# Epoch 17/50
#  - 0s - loss: 1206.5359
# Epoch 18/50
#  - 0s - loss: 1174.8479
# Epoch 19/50
#  - 0s - loss: 1142.3636
# Epoch 20/50
#  - 0s - loss: 1108.9846
# Epoch 21/50
#  - 0s - loss: 1075.6018
# Epoch 22/50
#  - 0s - loss: 1041.2658
# Epoch 23/50
#  - 0s - loss: 1006.9154
# Epoch 24/50
#  - 0s - loss: 972.7221
# Epoch 25/50
#  - 0s - loss: 938.4137
# Epoch 26/50
#  - 0s - loss: 904.3356
# Epoch 27/50
#  - 0s - loss: 870.5834
# Epoch 28/50
#  - 0s - loss: 837.8003
# Epoch 29/50
#  - 0s - loss: 804.9523
# Epoch 30/50
#  - 0s - loss: 773.8561
# Epoch 31/50
#  - 0s - loss: 742.5129
# Epoch 32/50
#  - 0s - loss: 712.7940
# Epoch 33/50
#  - 0s - loss: 683.8625
# Epoch 34/50
#  - 0s - loss: 655.5929
# Epoch 35/50
#  - 0s - loss: 628.0168
# Epoch 36/50
#  - 0s - loss: 602.1701
# Epoch 37/50
#  - 0s - loss: 577.0969
# Epoch 38/50
#  - 0s - loss: 552.9563
# Epoch 39/50
#  - 0s - loss: 530.1315
# Epoch 40/50
#  - 0s - loss: 507.9480
# Epoch 41/50
#  - 0s - loss: 486.8161
# Epoch 42/50
#  - 0s - loss: 466.2101
# Epoch 43/50
#  - 0s - loss: 446.7919
# Epoch 44/50
#  - 0s - loss: 428.4065
# Epoch 45/50
#  - 1s - loss: 410.7007
# Epoch 46/50
#  - 0s - loss: 393.9478
# Epoch 47/50
#  - 0s - loss: 377.6854
# Epoch 48/50
#  - 0s - loss: 362.8820
# Epoch 49/50
#  - 0s - loss: 348.3072
# Epoch 50/50
#  - 0s - loss: 334.9223
# Evaluate on test data
# 309/309 [==============================] - 3s 11ms/step
# test loss, test acc: 308.5179494715817
# Test set MSE for 44 cycle:308.51796294936315
# Epoch 1/50
#  - 8s - loss: 1527.6108
# Epoch 2/50
#  - 0s - loss: 1509.7181
# Epoch 3/50
#  - 0s - loss: 1490.7311
# Epoch 4/50
#  - 0s - loss: 1471.4385
# Epoch 5/50
#  - 0s - loss: 1451.2422
# Epoch 6/50
#  - 0s - loss: 1430.0872
# Epoch 7/50
#  - 0s - loss: 1407.8513
# Epoch 8/50
#  - 0s - loss: 1384.8450
# Epoch 9/50
#  - 0s - loss: 1360.6995
# Epoch 10/50
#  - 1s - loss: 1335.8473
# Epoch 11/50
#  - 0s - loss: 1309.3968
# Epoch 12/50
#  - 0s - loss: 1282.7124
# Epoch 13/50
#  - 0s - loss: 1253.9894
# Epoch 14/50
#  - 0s - loss: 1224.8329
# Epoch 15/50
#  - 0s - loss: 1194.7865
# Epoch 16/50
#  - 1s - loss: 1164.2391
# Epoch 17/50
#  - 0s - loss: 1132.6393
# Epoch 18/50
#  - 0s - loss: 1100.1800
# Epoch 19/50
#  - 0s - loss: 1067.4620
# Epoch 20/50
#  - 0s - loss: 1034.4946
# Epoch 21/50
#  - 0s - loss: 1000.6891
# Epoch 22/50
#  - 0s - loss: 967.0368
# Epoch 23/50
#  - 0s - loss: 932.4356
# Epoch 24/50
#  - 0s - loss: 898.4148
# Epoch 25/50
#  - 0s - loss: 863.9637
# Epoch 26/50
#  - 0s - loss: 829.4749
# Epoch 27/50
#  - 0s - loss: 795.1242
# Epoch 28/50
#  - 0s - loss: 761.4818
# Epoch 29/50
#  - 0s - loss: 727.8827
# Epoch 30/50
#  - 0s - loss: 695.5180
# Epoch 31/50
#  - 0s - loss: 663.5373
# Epoch 32/50
#  - 0s - loss: 632.6219
# Epoch 33/50
#  - 0s - loss: 602.7936
# Epoch 34/50
#  - 0s - loss: 573.9801
# Epoch 35/50
#  - 0s - loss: 547.2052
# Epoch 36/50
#  - 0s - loss: 521.5986
# Epoch 37/50
#  - 0s - loss: 497.4248
# Epoch 38/50
#  - 0s - loss: 475.0816
# Epoch 39/50
#  - 0s - loss: 453.5791
# Epoch 40/50
#  - 0s - loss: 433.9226
# Epoch 41/50
#  - 0s - loss: 415.6807
# Epoch 42/50
#  - 0s - loss: 398.5975
# Epoch 43/50
#  - 0s - loss: 383.0204
# Epoch 44/50
#  - 0s - loss: 368.6648
# Epoch 45/50
#  - 0s - loss: 355.5764
# Epoch 46/50
#  - 0s - loss: 343.2853
# Epoch 47/50
#  - 0s - loss: 331.9814
# Epoch 48/50
#  - 0s - loss: 321.6324
# Epoch 49/50
#  - 0s - loss: 312.3043
# Epoch 50/50
#  - 0s - loss: 303.7047
# Evaluate on test data
# 309/309 [==============================] - 4s 14ms/step
# test loss, test acc: 318.7207365066874
# Test set MSE for 45 cycle:318.7207366745299
# Epoch 1/50
#  - 8s - loss: 1570.4807
# Epoch 2/50
#  - 0s - loss: 1552.1657
# Epoch 3/50
#  - 0s - loss: 1533.4736
# Epoch 4/50
#  - 0s - loss: 1514.7961
# Epoch 5/50
#  - 0s - loss: 1495.4967
# Epoch 6/50
#  - 0s - loss: 1475.8501
# Epoch 7/50
#  - 0s - loss: 1455.2456
# Epoch 8/50
#  - 0s - loss: 1434.3177
# Epoch 9/50
#  - 0s - loss: 1412.2419
# Epoch 10/50
#  - 0s - loss: 1389.2125
# Epoch 11/50
#  - 0s - loss: 1365.5435
# Epoch 12/50
#  - 0s - loss: 1340.2826
# Epoch 13/50
#  - 0s - loss: 1314.3108
# Epoch 14/50
#  - 0s - loss: 1287.0280
# Epoch 15/50
#  - 0s - loss: 1258.7539
# Epoch 16/50
#  - 0s - loss: 1229.6616
# Epoch 17/50
#  - 0s - loss: 1199.2817
# Epoch 18/50
#  - 0s - loss: 1168.0233
# Epoch 19/50
#  - 0s - loss: 1135.9271
# Epoch 20/50
#  - 0s - loss: 1103.2140
# Epoch 21/50
#  - 0s - loss: 1070.1010
# Epoch 22/50
#  - 0s - loss: 1036.2215
# Epoch 23/50
#  - 0s - loss: 1002.8462
# Epoch 24/50
#  - 0s - loss: 967.9885
# Epoch 25/50
#  - 0s - loss: 933.9397
# Epoch 26/50
#  - 0s - loss: 899.4750
# Epoch 27/50
#  - 0s - loss: 866.1247
# Epoch 28/50
#  - 0s - loss: 832.0035
# Epoch 29/50
#  - 0s - loss: 798.5814
# Epoch 30/50
#  - 0s - loss: 765.2758
# Epoch 31/50
#  - 0s - loss: 733.0227
# Epoch 32/50
#  - 0s - loss: 701.0194
# Epoch 33/50
#  - 0s - loss: 669.9460
# Epoch 34/50
#  - 0s - loss: 639.8635
# Epoch 35/50
#  - 0s - loss: 610.6927
# Epoch 36/50
#  - 0s - loss: 581.6907
# Epoch 37/50
#  - 0s - loss: 553.9016
# Epoch 38/50
#  - 0s - loss: 527.3592
# Epoch 39/50
#  - 0s - loss: 501.5012
# Epoch 40/50
#  - 0s - loss: 477.1767
# Epoch 41/50
#  - 0s - loss: 453.4030
# Epoch 42/50
#  - 0s - loss: 430.8444
# Epoch 43/50
#  - 0s - loss: 409.9653
# Epoch 44/50
#  - 0s - loss: 389.7906
# Epoch 45/50
#  - 0s - loss: 370.7722
# Epoch 46/50
#  - 0s - loss: 353.5339
# Epoch 47/50
#  - 0s - loss: 336.8700
# Epoch 48/50
#  - 0s - loss: 322.1276
# Epoch 49/50
#  - 0s - loss: 307.9186
# Epoch 50/50
#  - 0s - loss: 294.5761
# Evaluate on test data
# 309/309 [==============================] - 3s 11ms/step
# test loss, test acc: 271.98877881491455
# Test set MSE for 46 cycle:271.9887782059967
# Epoch 1/50
#  - 8s - loss: 1598.2385
# Epoch 2/50
#  - 0s - loss: 1580.0056
# Epoch 3/50
#  - 0s - loss: 1562.3112
# Epoch 4/50
#  - 0s - loss: 1545.0592
# Epoch 5/50
#  - 0s - loss: 1527.8741
# Epoch 6/50
#  - 0s - loss: 1510.9961
# Epoch 7/50
#  - 0s - loss: 1493.8537
# Epoch 8/50
#  - 0s - loss: 1476.3739
# Epoch 9/50
#  - 0s - loss: 1458.4496
# Epoch 10/50
#  - 0s - loss: 1440.0694
# Epoch 11/50
#  - 0s - loss: 1421.1998
# Epoch 12/50
#  - 0s - loss: 1401.7691
# Epoch 13/50
#  - 0s - loss: 1381.8539
# Epoch 14/50
#  - 0s - loss: 1361.4436
# Epoch 15/50
#  - 0s - loss: 1339.9726
# Epoch 16/50
#  - 0s - loss: 1317.8668
# Epoch 17/50
#  - 0s - loss: 1295.5475
# Epoch 18/50
#  - 0s - loss: 1272.6665
# Epoch 19/50
#  - 0s - loss: 1249.2691
# Epoch 20/50
#  - 0s - loss: 1225.2799
# Epoch 21/50
#  - 0s - loss: 1200.4830
# Epoch 22/50
#  - 0s - loss: 1175.5295
# Epoch 23/50
#  - 0s - loss: 1149.7314
# Epoch 24/50
#  - 0s - loss: 1123.4799
# Epoch 25/50
#  - 0s - loss: 1097.3521
# Epoch 26/50
#  - 0s - loss: 1070.3531
# Epoch 27/50
#  - 0s - loss: 1043.4628
# Epoch 28/50
#  - 0s - loss: 1016.2709
# Epoch 29/50
#  - 0s - loss: 989.2274
# Epoch 30/50
#  - 0s - loss: 961.5863
# Epoch 31/50
#  - 0s - loss: 934.4096
# Epoch 32/50
#  - 0s - loss: 906.7230
# Epoch 33/50
#  - 0s - loss: 879.3545
# Epoch 34/50
#  - 0s - loss: 851.7842
# Epoch 35/50
#  - 0s - loss: 824.6239
# Epoch 36/50
#  - 0s - loss: 796.6919
# Epoch 37/50
#  - 0s - loss: 769.5611
# Epoch 38/50
#  - 0s - loss: 741.9547
# Epoch 39/50
#  - 0s - loss: 714.1884
# Epoch 40/50
#  - 0s - loss: 686.9997
# Epoch 41/50
#  - 0s - loss: 659.4875
# Epoch 42/50
#  - 0s - loss: 632.4262
# Epoch 43/50
#  - 0s - loss: 605.0412
# Epoch 44/50
#  - 0s - loss: 578.5613
# Epoch 45/50
#  - 0s - loss: 552.1342
# Epoch 46/50
#  - 0s - loss: 526.6290
# Epoch 47/50
#  - 0s - loss: 501.5334
# Epoch 48/50
#  - 0s - loss: 477.4193
# Epoch 49/50
#  - 0s - loss: 454.6070
# Epoch 50/50
#  - 0s - loss: 432.6099
# Evaluate on test data
# 309/309 [==============================] - 4s 14ms/step
# test loss, test acc: 403.73885170155745
# Test set MSE for 47 cycle:403.7388463787709
# Epoch 1/50
#  - 8s - loss: 1572.5625
# Epoch 2/50
#  - 0s - loss: 1558.0354
# Epoch 3/50
#  - 0s - loss: 1543.4025
# Epoch 4/50
#  - 0s - loss: 1528.2217
# Epoch 5/50
#  - 0s - loss: 1512.4840
# Epoch 6/50
#  - 0s - loss: 1496.0096
# Epoch 7/50
#  - 0s - loss: 1478.6754
# Epoch 8/50
#  - 0s - loss: 1460.1424
# Epoch 9/50
#  - 0s - loss: 1440.4579
# Epoch 10/50
#  - 0s - loss: 1419.1559
# Epoch 11/50
#  - 0s - loss: 1395.9804
# Epoch 12/50
#  - 0s - loss: 1370.8063
# Epoch 13/50
#  - 0s - loss: 1343.7391
# Epoch 14/50
#  - 0s - loss: 1314.4397
# Epoch 15/50
#  - 0s - loss: 1283.6889
# Epoch 16/50
#  - 0s - loss: 1250.8360
# Epoch 17/50
#  - 0s - loss: 1216.6587
# Epoch 18/50
#  - 0s - loss: 1181.0153
# Epoch 19/50
#  - 0s - loss: 1144.3871
# Epoch 20/50
#  - 0s - loss: 1106.4398
# Epoch 21/50
#  - 0s - loss: 1068.2523
# Epoch 22/50
#  - 0s - loss: 1029.7548
# Epoch 23/50
#  - 0s - loss: 990.6468
# Epoch 24/50
#  - 0s - loss: 951.0649
# Epoch 25/50
#  - 0s - loss: 912.4333
# Epoch 26/50
#  - 0s - loss: 873.5313
# Epoch 27/50
#  - 0s - loss: 835.8122
# Epoch 28/50
#  - 0s - loss: 797.7658
# Epoch 29/50
#  - 0s - loss: 760.9664
# Epoch 30/50
#  - 0s - loss: 724.4861
# Epoch 31/50
#  - 0s - loss: 689.7808
# Epoch 32/50
#  - 0s - loss: 655.9819
# Epoch 33/50
#  - 0s - loss: 623.0395
# Epoch 34/50
#  - 0s - loss: 592.0751
# Epoch 35/50
#  - 0s - loss: 561.5568
# Epoch 36/50
#  - 0s - loss: 533.3242
# Epoch 37/50
#  - 0s - loss: 505.9752
# Epoch 38/50
#  - 0s - loss: 480.2730
# Epoch 39/50
#  - 0s - loss: 456.4396
# Epoch 40/50
#  - 0s - loss: 433.9950
# Epoch 41/50
#  - 0s - loss: 412.7506
# Epoch 42/50
#  - 0s - loss: 392.9509
# Epoch 43/50
#  - 0s - loss: 374.8162
# Epoch 44/50
#  - 0s - loss: 357.8685
# Epoch 45/50
#  - 0s - loss: 342.5945
# Epoch 46/50
#  - 0s - loss: 327.8936
# Epoch 47/50
#  - 0s - loss: 315.3735
# Epoch 48/50
#  - 1s - loss: 302.9325
# Epoch 49/50
#  - 0s - loss: 292.4914
# Epoch 50/50
#  - 0s - loss: 282.3276
# Evaluate on test data
# 309/309 [==============================] - 3s 11ms/step
# test loss, test acc: 266.31237985555407
# Test set MSE for 48 cycle:266.31238495316455
# Epoch 1/50
#  - 8s - loss: 1562.1104
# Epoch 2/50
#  - 0s - loss: 1544.1587
# Epoch 3/50
#  - 0s - loss: 1525.9896
# Epoch 4/50
#  - 0s - loss: 1507.2705
# Epoch 5/50
#  - 0s - loss: 1487.8068
# Epoch 6/50
#  - 0s - loss: 1467.7837
# Epoch 7/50
#  - 0s - loss: 1447.1553
# Epoch 8/50
#  - 0s - loss: 1425.2740
# Epoch 9/50
#  - 0s - loss: 1402.7564
# Epoch 10/50
#  - 0s - loss: 1378.9283
# Epoch 11/50
#  - 0s - loss: 1354.6008
# Epoch 12/50
#  - 0s - loss: 1328.6059
# Epoch 13/50
#  - 0s - loss: 1301.9329
# Epoch 14/50
#  - 0s - loss: 1274.0898
# Epoch 15/50
#  - 0s - loss: 1245.4944
# Epoch 16/50
#  - 0s - loss: 1216.4276
# Epoch 17/50
#  - 0s - loss: 1185.6867
# Epoch 18/50
#  - 0s - loss: 1154.8314
# Epoch 19/50
#  - 0s - loss: 1123.5098
# Epoch 20/50
#  - 0s - loss: 1090.7054
# Epoch 21/50
#  - 0s - loss: 1058.1189
# Epoch 22/50
#  - 0s - loss: 1024.9617
# Epoch 23/50
#  - 0s - loss: 990.8416
# Epoch 24/50
#  - 0s - loss: 956.8006
# Epoch 25/50
#  - 0s - loss: 921.9982
# Epoch 26/50
#  - 0s - loss: 887.2715
# Epoch 27/50
#  - 0s - loss: 852.5208
# Epoch 28/50
#  - 0s - loss: 818.2983
# Epoch 29/50
#  - 0s - loss: 782.6411
# Epoch 30/50
#  - 0s - loss: 748.9721
# Epoch 31/50
#  - 0s - loss: 714.9993
# Epoch 32/50
#  - 0s - loss: 681.5699
# Epoch 33/50
#  - 0s - loss: 649.2980
# Epoch 34/50
#  - 0s - loss: 617.4393
# Epoch 35/50
#  - 0s - loss: 586.3829
# Epoch 36/50
#  - 0s - loss: 557.0063
# Epoch 37/50
#  - 0s - loss: 528.6884
# Epoch 38/50
#  - 0s - loss: 501.5805
# Epoch 39/50
#  - 0s - loss: 475.8396
# Epoch 40/50
#  - 0s - loss: 451.5599
# Epoch 41/50
#  - 0s - loss: 428.5349
# Epoch 42/50
#  - 0s - loss: 407.1690
# Epoch 43/50
#  - 0s - loss: 387.2785
# Epoch 44/50
#  - 0s - loss: 368.6746
# Epoch 45/50
#  - 0s - loss: 351.2526
# Epoch 46/50
#  - 0s - loss: 335.3269
# Epoch 47/50
#  - 0s - loss: 320.8766
# Epoch 48/50
#  - 0s - loss: 307.6817
# Epoch 49/50
#  - 0s - loss: 295.3937
# Epoch 50/50
#  - 0s - loss: 284.5005
# Evaluate on test data
# 309/309 [==============================] - 5s 15ms/step
# test loss, test acc: 271.2695559405972
# Test set MSE for 49 cycle:271.26955546860313
# Epoch 1/50
#  - 8s - loss: 1528.9686
# Epoch 2/50
#  - 0s - loss: 1512.6211
# Epoch 3/50
#  - 0s - loss: 1495.2547
# Epoch 4/50
#  - 0s - loss: 1476.7973
# Epoch 5/50
#  - 0s - loss: 1457.2437
# Epoch 6/50
#  - 0s - loss: 1436.5937
# Epoch 7/50
#  - 0s - loss: 1414.7911
# Epoch 8/50
#  - 0s - loss: 1391.7439
# Epoch 9/50
#  - 0s - loss: 1367.4564
# Epoch 10/50
#  - 0s - loss: 1342.0233
# Epoch 11/50
#  - 0s - loss: 1315.3061
# Epoch 12/50
#  - 0s - loss: 1287.3696
# Epoch 13/50
#  - 0s - loss: 1258.3177
# Epoch 14/50
#  - 0s - loss: 1228.6817
# Epoch 15/50
#  - 0s - loss: 1197.9319
# Epoch 16/50
#  - 0s - loss: 1166.8096
# Epoch 17/50
#  - 0s - loss: 1134.3685
# Epoch 18/50
#  - 0s - loss: 1101.4991
# Epoch 19/50
#  - 0s - loss: 1068.4423
# Epoch 20/50
#  - 0s - loss: 1034.3847
# Epoch 21/50
#  - 0s - loss: 1001.2958
# Epoch 22/50
#  - 0s - loss: 967.1250
# Epoch 23/50
#  - 0s - loss: 934.3193
# Epoch 24/50
#  - 0s - loss: 901.0213
# Epoch 25/50
#  - 0s - loss: 867.9708
# Epoch 26/50
#  - 0s - loss: 835.5502
# Epoch 27/50
#  - 0s - loss: 803.3376
# Epoch 28/50
#  - 0s - loss: 771.7502
# Epoch 29/50
#  - 0s - loss: 740.2943
# Epoch 30/50
#  - 0s - loss: 709.9541
# Epoch 31/50
#  - 0s - loss: 679.4306
# Epoch 32/50
#  - 0s - loss: 650.0298
# Epoch 33/50
#  - 0s - loss: 621.0011
# Epoch 34/50
#  - 0s - loss: 593.1971
# Epoch 35/50
#  - 0s - loss: 565.2469
# Epoch 36/50
#  - 0s - loss: 538.2803
# Epoch 37/50
#  - 0s - loss: 512.2604
# Epoch 38/50
#  - 1s - loss: 487.2040
# Epoch 39/50
#  - 0s - loss: 462.8638
# Epoch 40/50
#  - 0s - loss: 439.5275
# Epoch 41/50
#  - 0s - loss: 417.4212
# Epoch 42/50
#  - 0s - loss: 396.5364
# Epoch 43/50
#  - 0s - loss: 376.9221
# Epoch 44/50
#  - 0s - loss: 358.8008
# Epoch 45/50
#  - 0s - loss: 341.4288
# Epoch 46/50
#  - 0s - loss: 325.6549
# Epoch 47/50
#  - 0s - loss: 311.3869
# Epoch 48/50
#  - 0s - loss: 298.4409
# Epoch 49/50
#  - 0s - loss: 286.3799
# Epoch 50/50
#  - 0s - loss: 275.6171
# Evaluate on test data
# 309/309 [==============================] - 4s 11ms/step
# test loss, test acc: 267.13226392431164
# Test set MSE for 50 cycle:267.13226649559584

# %% [markdown]
# **Let's get the mean and the standard deviation of the mean sqaured errors from previous cycle**

# %%
mean_MSE = MSE[i].mean() #creating a variable reporting the mean value for the mean squared errors
std_MSE = MSE[i].std() #creating a variable reporting the standard value for the mean squared errors

# %%
print("The mean of the mean squared errors is {}, and the standard deviation for the mean squared value is {}".format(mean_MSE, std_MSE))
# Out:
# The mean of the mean squared errors is 267.13226649559584, and the standard deviation for the mean squared value is 0.0

# %% [markdown]
# **The mean value of the normalized data is quite large**
